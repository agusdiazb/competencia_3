# %% [markdown]
# ## Inicializacion

# %%
# limpio la memoria
Sys.time()
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
# [1] "2025-12-03 14:45:44 UTC"
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  658599 35.2 1454567    77.7 1233336  65.9
# Vcells 1222293  9.4 8388608    64.0 1975163  15.1

# %%
plocal <- list()

plocal$qcanaritos <- 5L
plocal$min_data_in_leaf <- 200L
plocal$learning_rate <- 1.0
plocal$gradient_bound <- 0.4

plocal$APO <- 1
plocal$ksemillerio <- 100

plocal$decaimiento <- 0.95 # <-- Parámetro de decaimiento
deflactor <- "IPC" # IPC , IPIM, UVA, ripte_indice, TC_BLUE, TC_OFICIAL, TCRM, tasa_i, tasa_r

# %%
PARAM <- list()
PARAM$experimento <- "TODO-202109"
PARAM$semilla_primigenia <- 100003 # <-- tu semilla favorita

# %%
setwd("/content/buckets/b1/exp")
experimento_folder <- PARAM$experimento
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %% [markdown]
# ## Preprocesamiento

# %% [markdown]
# ### Generacion de la clase_ternaria

# %%
Sys.time()
require( "data.table" )

# leo el dataset
dataset <- fread("~/datasets/competencia_02_crudo.csv.gz" )

dataset_nuevo_mes <- fread("~/datasets/competencia_03_crudo.csv.gz" )

# Unimos el nuevo mes (202109) al dataset existente
dataset <- rbindlist(list(dataset, dataset_nuevo_mes), use.names=TRUE, fill=TRUE)

# Eliminamos la tabla temporal para liberar memoria
rm(dataset_nuevo_mes)
gc()

# calculo el periodo0 consecutivo
dsimple <- dataset[, list(
  "pos" = .I,
  numero_de_cliente,
  periodo0 = as.integer(foto_mes/100)*12 +  foto_mes%%100 )
]


# ordeno
setorder( dsimple, numero_de_cliente, periodo0 )

# calculo topes
periodo_ultimo <- dsimple[, max(periodo0) ]
periodo_anteultimo <- periodo_ultimo - 1


# calculo los leads de orden 1 y 2
dsimple[, c("periodo1", "periodo2") :=
  shift(periodo0, n=1:2, fill=NA, type="lead"),  numero_de_cliente
]

# assign most common class values = "CONTINUA"
dsimple[ periodo0 < periodo_anteultimo, clase_ternaria := "CONTINUA" ]

# calculo BAJA+1
dsimple[ periodo0 < periodo_ultimo &
  ( is.na(periodo1) | periodo0 + 1 < periodo1 ),
  clase_ternaria := "BAJA+1"
]

# calculo BAJA+2
dsimple[ periodo0 < periodo_anteultimo & (periodo0+1 == periodo1 )
  & ( is.na(periodo2) | periodo0 + 2 < periodo2 ),
  clase_ternaria := "BAJA+2"
]

# pego el resultado en el dataset original y grabo
setorder( dsimple, pos )
dataset[, clase_ternaria := dsimple$clase_ternaria ]

rm(dsimple)
gc()
Sys.time()
# Out:
# [1] "2025-12-03 14:45:44 UTC"
# Loading required package: data.table
#        used      (Mb)   gc trigger (Mb)    max used   (Mb)
# Ncells    759020   40.6    1454567    77.7    1454567   77.7
# Vcells 555646410 4239.3 1481537192 11303.3 1296635483 9892.6
#        used      (Mb)   gc trigger (Mb)    max used   (Mb)
# Ncells    767901   41.1    1454567    77.7    1454567   77.7
# Vcells 560571721 4276.9 1481537192 11303.3 1296635483 9892.6
# [1] "2025-12-03 14:46:16 UTC"

# %%
setorder( dataset, foto_mes, clase_ternaria, numero_de_cliente)
dataset[, .N, list(foto_mes, clase_ternaria)]
# Out:
#    foto_mes clase_ternaria N
# 1  201901   BAJA+1            645
# 2  201901   BAJA+2            729
# 3  201901   CONTINUA       122899
# 4  201902   BAJA+1            733
# 5  201902   BAJA+2            707
# 6  201902   CONTINUA       123961
# 7  201903   BAJA+1            708
# 8  201903   BAJA+2            751
# 9  201903   CONTINUA       124508
# 10 201904   BAJA+1            756
# 11 201904   BAJA+2            514
# 12 201904   CONTINUA       125268
# 13 201905   BAJA+1            517
# 14 201905   BAJA+2            692
# 15 201905   CONTINUA       125993
# 16 201906   BAJA+1            696
# 17 201906   BAJA+2            608
# 18 201906   CONTINUA       127430
# 19 201907   BAJA+1            611
# 20 201907   BAJA+2            680
# 21 201907   CONTINUA       128977
# 22 201908   BAJA+1            683
# 23 201908   BAJA+2            577
# 24 201908   CONTINUA       130883
# 25 201909   BAJA+1            581
# 26 201909   BAJA+2            582
# 27 201909   CONTINUA       132594
# 28 201910   BAJA+1            594
# 29 201910   BAJA+2            618
# 30 201910   CONTINUA       134798
# ⋮  ⋮        ⋮              ⋮
# 67 202011   BAJA+1            456
# 68 202011   BAJA+2            616
# 69 202011   CONTINUA       159178
# 70 202012   BAJA+1            622
# 71 202012   BAJA+2            619
# 72 202012   CONTINUA       159756
# 73 202101   BAJA+1            622
# 74 202101   BAJA+2            825
# 75 202101   CONTINUA       160080
# 76 202102   BAJA+1            831
# 77 202102   BAJA+2           1032
# 78 202102   CONTINUA       160292
# 79 202103   BAJA+1           1039
# 80 202103   BAJA+2            951
# 81 202103   CONTINUA       161119
# 82 202104   BAJA+1            955
# 83 202104   BAJA+2           1130
# 84 202104   CONTINUA       161333
# 85 202105   BAJA+1           1134
# 86 202105   BAJA+2            842
# 87 202105   CONTINUA       161941
# 88 202106   BAJA+1            843
# 89 202106   BAJA+2           1134
# 90 202106   CONTINUA       162336
# 91 202107   BAJA+1           1137
# 92 202107   BAJA+2           1248
# 93 202107   CONTINUA       162211
# 94 202108   NA             163570
# 95 202108   BAJA+1           1252
# 96 202109   NA             165093

# %% [markdown]
# ### Eliminacion de Features

# %% [markdown]
# Completar a gusto LUEGO de realizar un analisis exploratorio de datos.

# %%
# Saco éstas variables
dataset[, mprestamos_personales := NULL ]
dataset[, cprestamos_personales := NULL ]
dataset[, Master_mfinanciacion_limite := NULL ] 
dataset[, Visa_mfinanciacion_limite := NULL ] 
ncol(dataset)
nrow(dataset)
# Out:
# [1] 151
# [1] 4883051

# %% [markdown]
# ### Data Quality

# %%
# Identificar las columnas numéricas a chequear
#    (Excluimos IDs y la propia foto_mes)
numeric_types <- c("integer", "numeric", "double", "integer64")
all_cols <- names(dataset)

# Obtenemos los nombres de las columnas que son numéricas
cols_a_chequear <- all_cols[sapply(dataset, function(x) class(x)[1] %in% numeric_types)]

# Quitamos las que no son features (ID, fecha)
cols_a_chequear <- setdiff(cols_a_chequear, c("numero_de_cliente", "foto_mes"))

# Calcular el porcentaje de ceros por mes
resumen_wide <- dataset[,
                        lapply(.SD, function(x) sum(x == 0, na.rm = TRUE) / .N),
                        by = foto_mes,
                        .SDcols = cols_a_chequear]

# Convertir (melt) la tabla a formato largo
resumen_long <- melt(resumen_wide,
                     id.vars = "foto_mes",
                     variable.name = "variable",
                     value.name = "porcentaje_ceros")

# Filtrar y crear la lista de problemas
#  Nos quedamos solo con los que son 100% ceros (porcentaje == 1)
lista_problemas <- resumen_long[porcentaje_ceros == 1,
                                .(foto_mes, variable)]

setorder(lista_problemas, foto_mes, variable)

# 5. Mostrar el resultado
print("Columnas que son 100% CERO en un mes:")
print(lista_problemas)
# Out:
# [1] "Columnas que son 100% CERO en un mes:"
#     foto_mes                           variable
#        <int>                             <fctr>
#  1:   201904  ctarjeta_visa_debitos_automaticos
#  2:   201904 mttarjeta_visa_debitos_automaticos
#  3:   201905                      mrentabilidad
#  4:   201905               mrentabilidad_annual
#  5:   201905                        mcomisiones
#  6:   201905                    mactivos_margen
#  7:   201905                    mpasivos_margen
#  8:   201905                  ccomisiones_otras
#  9:   201905                  mcomisiones_otras
# 10:   201910                      mrentabilidad
# 11:   201910               mrentabilidad_annual
# 12:   201910                        mcomisiones
# 13:   201910                    mactivos_margen
# 14:   201910                    mpasivos_margen
# 15:   201910        ccajeros_propios_descuentos
# 16:   201910        mcajeros_propios_descuentos
# 17:   201910           ctarjeta_visa_descuentos
# 18:   201910           mtarjeta_visa_descuentos
# 19:   201910         ctarjeta_master_descuentos
# 20:   201910         mtarjeta_master_descuentos
# 21:   201910                  ccomisiones_otras
# 22:   201910                  mcomisiones_otras
# 23:   201910         chomebanking_transacciones
# 24:   202002        ccajeros_propios_descuentos
# 25:   202002        mcajeros_propios_descuentos
# 26:   202002           ctarjeta_visa_descuentos
# 27:   202002           mtarjeta_visa_descuentos
# 28:   202002         ctarjeta_master_descuentos
# 29:   202002         mtarjeta_master_descuentos
# 30:   202006                     active_quarter
# 31:   202006                           internet
# 32:   202006                      mrentabilidad
# 33:   202006               mrentabilidad_annual
# 34:   202006                        mcomisiones
# 35:   202006                    mactivos_margen
# 36:   202006                    mpasivos_margen
# 37:   202006                     mcuentas_saldo
# 38:   202006      ctarjeta_debito_transacciones
# 39:   202006                      mautoservicio
# 40:   202006        ctarjeta_visa_transacciones
# 41:   202006              mtarjeta_visa_consumo
# 42:   202006      ctarjeta_master_transacciones
# 43:   202006            mtarjeta_master_consumo
# 44:   202006        ccajeros_propios_descuentos
# 45:   202006        mcajeros_propios_descuentos
# 46:   202006           ctarjeta_visa_descuentos
# 47:   202006           mtarjeta_visa_descuentos
# 48:   202006         ctarjeta_master_descuentos
# 49:   202006         mtarjeta_master_descuentos
# 50:   202006                  ccomisiones_otras
# 51:   202006                  mcomisiones_otras
# 52:   202006           cextraccion_autoservicio
# 53:   202006           mextraccion_autoservicio
# 54:   202006               ccheques_depositados
# 55:   202006               mcheques_depositados
# 56:   202006                  ccheques_emitidos
# 57:   202006                  mcheques_emitidos
# 58:   202006    ccheques_depositados_rechazados
# 59:   202006    mcheques_depositados_rechazados
# 60:   202006       ccheques_emitidos_rechazados
# 61:   202006       mcheques_emitidos_rechazados
# 62:   202006                        tcallcenter
# 63:   202006          ccallcenter_transacciones
# 64:   202006                       thomebanking
# 65:   202006         chomebanking_transacciones
# 66:   202006               ccajas_transacciones
# 67:   202006                   ccajas_consultas
# 68:   202006                   ccajas_depositos
# 69:   202006                ccajas_extracciones
# 70:   202006                       ccajas_otras
# 71:   202006                           catm_trx
# 72:   202006                               matm
# 73:   202006                     catm_trx_other
# 74:   202006                         matm_other
# 75:   202006                        tmobile_app
# 76:   202006                    cmobile_app_trx
# 77:   202009        ccajeros_propios_descuentos
# 78:   202009        mcajeros_propios_descuentos
# 79:   202009           ctarjeta_visa_descuentos
# 80:   202009           mtarjeta_visa_descuentos
# 81:   202009         ctarjeta_master_descuentos
# 82:   202009         mtarjeta_master_descuentos
# 83:   202010        ccajeros_propios_descuentos
# 84:   202010        mcajeros_propios_descuentos
# 85:   202010           ctarjeta_visa_descuentos
# 86:   202010           mtarjeta_visa_descuentos
# 87:   202010         ctarjeta_master_descuentos
# 88:   202010         mtarjeta_master_descuentos
# 89:   202102        ccajeros_propios_descuentos
# 90:   202102        mcajeros_propios_descuentos
# 91:   202102           ctarjeta_visa_descuentos
# 92:   202102           mtarjeta_visa_descuentos
# 93:   202102         ctarjeta_master_descuentos
# 94:   202102         mtarjeta_master_descuentos
# 95:   202105                   ccajas_depositos
#     foto_mes                           variable

# %%
# Asumimos que 'dataset' y 'lista_problemas' existen

cat("\nIniciando transformación a NA...\n")


for(i in 1:nrow(lista_problemas)) {

  # Obtenemos el mes y el nombre de la variable
  f <- lista_problemas$foto_mes[i]
  v <- as.character(lista_problemas$variable[i]) # Nombre de la columna como string

  # Determinamos el tipo de NA (Integer o Double)
  na_value <- if (class(dataset[[v]])[1] == "integer") {
      NA_integer_
    } else {
      NA_real_
    }

  dataset[foto_mes == f, (v) := na_value]

}

cat("¡Transformación completa!\n")
# Out:
# Iniciando transformación a NA...
# ¡Transformación completa!

# %% [markdown]
# ### Data Drifting

# %% [markdown]
# ### Payroll

# %%
library(dplyr)
library(tidyr)
library(ggplot2)

# --- Variables de interés ---
# vars_a_graficar <- c("cpayroll_trx", "mpayroll", "mcaja_ahorro", "mcuenta_corriente")
vars_a_graficar <- c("cpayroll_trx", "mpayroll")

# --- 1️⃣ Calcular el promedio mensual solo para las variables deseadas ---
mean_long <- dataset %>%
  select(foto_mes, all_of(vars_a_graficar)) %>%
  group_by(foto_mes) %>%
  summarise(across(everything(), ~mean(.x, na.rm = TRUE))) %>%
  pivot_longer(
    cols = -foto_mes,
    names_to = "variable",
    values_to = "mean_value"
  ) %>%
  mutate(fecha = as.Date(paste0(foto_mes, "01"), format = "%Y%m%d")) %>%
  ungroup()

# --- 2️⃣ Graficar todas las variables juntas (una por panel) ---
ggplot(mean_long, aes(x = fecha, y = mean_value, color = variable)) +
  geom_line(size = 0.8, show.legend = FALSE) +
  facet_wrap(~variable, scales = "free_y", ncol = 2) +
  labs(
    title = "Evolución mensual del promedio por variable",
    x = "Mes",
    y = "Valor medio"
  ) +
  theme_minimal(base_size = 13) +
  theme(plot.title = element_text(face = "bold", hjust = 0.5))
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:data.table’:
#
#     between, first, last
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Warning message:
# “Using `size` aesthetic for lines was deprecated in ggplot2 3.4.0.
# ℹ Please use `linewidth` instead.”
# plot without title

# %%
# suavizado de picos en payroll, caja de ahorro y cuenta corriente. 

library(data.table)

Sys.time()

dataset[, cpayroll_trx := as.numeric(cpayroll_trx)]

# vars_a_suavizar <- c("cpayroll_trx", "mpayroll", "mcaja_ahorro", "mcuenta_corriente")
vars_a_suavizar <- c("cpayroll_trx", "mpayroll")
umbral_aumento <- 1.5

# Definimos los meses específicos donde queremos aplicar el suavizado
meses_de_interes <- c(201906, 201912, 202006, 202012, 202106)

setorder(dataset, numero_de_cliente, foto_mes)

for (v in vars_a_suavizar) {
  cat("Suavizando:", v, "\n")
  
  # 1. Creamos lag y lead (esto debe hacerse siempre para todos los meses)
  dataset[, `:=`(
    lag = shift(get(v), 1, type="lag"),
    lead = shift(get(v), 1, type="lead")
  ), by = numero_de_cliente]
  
  # 2. Aplicamos la corrección solo si se cumplen TRES condiciones:
  #    a) Es un pico (valor actual >= 1.5 * lag)
  #    b) Tenemos lag y lead disponibles
  #    c) La fila corresponde a uno de los meses de interés (Junio o Diciembre)
  dataset[get(v) >= umbral_aumento * lag & 
          !is.na(lag) & 
          !is.na(lead) &
          foto_mes %in% meses_de_interes, # <-- NUEVA CONDICIÓN
          (v) := (lag + lead) / 2]
  
  # 3. Eliminamos las columnas temporales
  dataset[, c("lag", "lead") := NULL]
}

gc()
Sys.time()
cat("✔ Suavizado de picos en meses específicos completado.\n")
# Out:
# [1] "2025-12-03 14:46:27 UTC"
# Suavizando: cpayroll_trx
# Suavizando: mpayroll
#        used      (Mb)   gc trigger (Mb)    max used   (Mb)
# Ncells   1529301   81.7    3011210   160.9    3011210  160.9
# Vcells 547254994 4175.3 1481537192 11303.3 1296635483 9892.6
# [1] "2025-12-03 14:46:59 UTC"
# ✔ Suavizado de picos en meses específicos completado.

# %%
library(dplyr)
library(tidyr)
library(ggplot2)

# --- Variables de interés ---
# vars_a_graficar <- c("cpayroll_trx", "mpayroll", "mcaja_ahorro", "mcuenta_corriente")
vars_a_graficar <- c("cpayroll_trx", "mpayroll")

# --- 1️⃣ Calcular el promedio mensual solo para las variables deseadas ---
mean_long <- dataset %>%
  select(foto_mes, all_of(vars_a_graficar)) %>%
  group_by(foto_mes) %>%
  summarise(across(everything(), ~mean(.x, na.rm = TRUE))) %>%
  pivot_longer(
    cols = -foto_mes,
    names_to = "variable",
    values_to = "mean_value"
  ) %>%
  mutate(fecha = as.Date(paste0(foto_mes, "01"), format = "%Y%m%d")) %>%
  ungroup()

# --- 2️⃣ Graficar todas las variables juntas (una por panel) ---
ggplot(mean_long, aes(x = fecha, y = mean_value, color = variable)) +
  geom_line(size = 0.8, show.legend = FALSE) +
  facet_wrap(~variable, scales = "free_y", ncol = 2) +
  labs(
    title = "Evolución mensual del promedio por variable",
    x = "Mes",
    y = "Valor medio"
  ) +
  theme_minimal(base_size = 13) +
  theme(plot.title = element_text(face = "bold", hjust = 0.5))
# Out:
# plot without title

# %% [markdown]
# #### Cargamos los índices

# %%
require(data.table)

indices_externos <- data.table(
  foto_mes = c(201901, 201902, 201903, 201904, 201905, 201906, 201907, 201908, 201909, 201910, 201911, 201912, 202001, 202002, 202003, 202004, 202005, 202006, 202007, 202008, 202009, 202010, 202011, 202012, 202101, 202102, 202103, 202104, 202105, 202106, 202107, 202108),
  TC_BLUE = c("37,5", "39", "43,65", "46", "46", "43,8", "45,2", "63", "61,25", "69", "69,25", "78,5", "78", "78,5", "83,5", "118", "125", "126", "136", "135", "146", "169", "155", "166", "153", "146", "141", "150", "157", "168", "180,5", "182"),
  TC_OFICIAL = c("38,28", "40,14", "44,4", "45,36", "46,1", "43,7", "45,02", "62,04", "59,82", "63,23", "62,93", "62,99", "63,03", "64,26", "66,58", "69,16", "70,76", "74,07", "76,39", "78,36", "80,63", "83,89", "86,72", "89,87", "92,7", "95,12", "97,69", "98,9", "100,09", "101,17", "102,06", "103,14"),
  TCRM = c("116,5734916", "116,5625812", "119,8157416", "120,2150629", "119,4975567", "114,8101224", "109,8715912", "127,7565287", "130,6961531", "129,7797576", "126,9467229", "123,5951113", "120,8372653", "118,9226283", "114,5040182", "111,5867304", "111,7626924", "116,6307121", "117,9781145", "118,9579865", "119,6485855", "118,1736932", "119,6199112", "123,235859", "122,8366223", "122,3839332", "119,0439564", "116,7635839", "117,2617246", "116,9865438", "113,7702507", "111,9430182"),
  UVA = c("32,03", "32,86", "33,97", "35,42", "36,89", "38,03", "39,2", "40,16", "41,26", "43,43", "45,42", "47,16", "49,05", "50,49", "51,62", "52,95", "54,24", "55,06", "56,09", "57,17", "58,52", "60,16", "61,94", "64,32", "66,54", "69,04", "71,92", "74,87", "78,07", "81,13", "83,82", "86,42"),
  IPC = c("189,6101", "196,7501", "205,9571", "213,0517", "219,5691", "225,537", "230,494", "239,6077", "253,7102", "262,0661", "273,2158", "283,4442", "289,8299", "295,666", "305,5515", "310,1243", "314,9087", "321,9738", "328,2014", "337,0632", "346,6207", "359,657", "371,0211", "385,8826", "401,5071", "415,8595", "435,8657", "453,6503", "468,725", "483,6049", "498,0987", "510,3942"),
  IPIM = c("279", "288,4", "300,2", "314", "329,5", "334,9", "335,2", "372,8", "388,3", "402,3", "424", "439,7", "446,3", "451,3", "455,6", "449,7", "451,3", "467,8", "484,4", "504,2", "522,9", "547,3", "570,1", "595,2", "628,3", "666,5", "692,4", "725,5", "748,8", "772,3", "789,5", "809,4"),
  ripte_indice = c("4042", "4198,76", "4444,6", "4533,03", "4676,25", "4753,19", "4948,27", "5039,93", "5199,08", "5467,59", "5554,15", "5666,48", "6066,07", "6445,13", "6500,72", "6510,18", "6521,87", "6670,93", "6908,52", "6945,86", "7076,47", "7401,81", "7495,03", "7643,41", "7784,1", "8263,33", "8665,19", "9201,59", "9311,61", "9660,13", "10089,96", "10326,11"),
  tasa_i = c("3,71", "3,09", "3,81", "4,45", "4,42", "3,96", "4,14", "4,84", "4,91", "4,06", "3,68", "3,29", "2,83", "2,65", "2,30", "1,54", "2,21", "2,47", "2,43", "2,47", "2,47", "2,65", "2,81", "2,85", "2,85", "2,80", "2,84", "2,84", "2,84", "2,84", "2,84", "2,85"),
  tasa_r = c("0,79", "-0,68", "-0,85", "1,01", "1,28", "1,23", "1,89", "0,81", "-0,94", "0,73", "-0,59", "-0,40", "0,52", "0,64", "-0,97", "0,04", "0,70", "0,27", "0,52", "-0,23", "-0,32", "-1,11", "-0,38", "-1,10", "-1,11", "-0,77", "-1,87", "-1,21", "-0,44", "-0,35", "-0,15", "0,34")
)

# Trabajamos el formato
indices_externos[, foto_mes := as.integer(foto_mes)]

# Reemplazar la coma por el punto en todas las columnas excepto 'foto_mes'
columnas_numericas <- names(indices_externos)[-1]

indices_externos[, (columnas_numericas) := lapply(.SD, function(x) as.numeric(gsub(",", ".", x))),
                 .SDcols = columnas_numericas]

# convertir a tasa
cols_tasas <- c("tasa_i", "tasa_r")
indices_externos[, (cols_tasas) := lapply(.SD, function(x) x / 100), .SDcols = cols_tasas]

# Verificar la estructura de la tabla
str(indices_externos)
# Out:
# Classes ‘data.table’ and 'data.frame':	32 obs. of  10 variables:
#  $ foto_mes    : int  201901 201902 201903 201904 201905 201906 201907 201908 201909 201910 ...
#  $ TC_BLUE     : num  37.5 39 43.6 46 46 ...
#  $ TC_OFICIAL  : num  38.3 40.1 44.4 45.4 46.1 ...
#  $ TCRM        : num  117 117 120 120 119 ...
#  $ UVA         : num  32 32.9 34 35.4 36.9 ...
#  $ IPC         : num  190 197 206 213 220 ...
#  $ IPIM        : num  279 288 300 314 330 ...
#  $ ripte_indice: num  4042 4199 4445 4533 4676 ...
#  $ tasa_i      : num  0.0371 0.0309 0.0381 0.0445 0.0442 0.0396 0.0414 0.0484 0.0491 0.0406 ...
#  $ tasa_r      : num  0.0079 -0.0068 -0.0085 0.0101 0.0128 0.0123 0.0189 0.0081 -0.0094 0.0073 ...
#  - attr(*, ".internal.selfref")=<externalptr>

# %%
require("data.table")

#' @title Deflacta columnas monetarias SOBREESCRIBIENDO las originales
#' @description Modifica las columnas monetarias (ej: 'mrentabilidad')
#'              directamente con su valor deflactado.
#'
#' @param dt El data.table principal (ej: 'dataset') que se modificará.
#' @param dt_indices El data.table que contiene todos los índices (ej: 'indices_externos').
#' @param criterio_deflacion El nombre de la columna a usar (ej: "IPC", "TCRM", "tasa_i").
#' @param incluir_dolarizadas TRUE o FALSE. Si es TRUE, ajusta pesos Y dólares.
#'                            Si es FALSE, ajusta SÓLO pesos.
#' @param mes_base Un integer (YYYYMM). Mes base para normalizar (ej: 201901).
#'
#' @return El data.table 'dt' modificado por referencia (no es necesario reasignarlo).

deflactar_dataset <- function(dt,
                                       dt_indices,
                                       criterio_deflacion,
                                       incluir_dolarizadas = FALSE,
                                       mes_base = 201901) {

  cat(paste0("Iniciando deflación según Criterio: ", criterio_deflacion, "\n"))

  # --- 1. Definir Lógicas y Columnas ---

  # Grupo 1: Variables en PESOS
  columnas_pesos <- c(
    "mrentabilidad", "mrentabilidad_annual", "mcomisiones", "mactivos_margen",
    "mpasivos_margen", "mcuentas_saldo", "mcuenta_corriente", "mcaja_ahorro",
    "mcuenta_corriente_adicional", "mcaja_ahorro_adicional",
    "mprestamos_personales", "mprestamos_prendarios", "mprestamos_hipotecarios",
    "mplazo_fijo_pesos", "minversion1_pesos", "minversion2",
    "mpayroll", "mpayroll2", "mcuenta_debitos_automaticos",
    "mtarjeta_visa_consumo", "mtarjeta_master_consumo",
    "mttarjeta_visa_debitos_automaticos", "mttarjeta_master_debitos_automaticos",
    "mpagodeservicios", "mpagomiscuentas", "mtransferencias_recibidas",
    "mtransferencias_emitidas", "mextraccion_autoservicio", "mcheques_depositados",
    "mcheques_emitidos", "mcheques_depositados_rechazados", "mcheques_emitidos_rechazados",
    "matm", "matm_other", "mautoservicio",
    "mcomisiones_mantenimiento", "mcomisiones_otras", "mforex_buy", "mforex_sell",
    "mcajeros_propios_descuentos", "mtarjeta_visa_descuentos", "mtarjeta_master_descuentos",
    "Master_mfinanciacion_limite", "Master_msaldototal", "Master_msaldopesos",
    "Master_mconsumospesos", "Master_mlimitecompra", "Master_madelantopesos",
    "Master_mpagado", "Master_mpagospesos", "Master_mconsumototal", "Master_mpagominimo",
    "Visa_mfinanciacion_limite", "Visa_msaldototal", "Visa_msaldopesos",
    "Visa_mconsumospesos", "Visa_mlimitecompra", "Visa_madelantopesos",
    "Visa_mpagado", "Visa_mpagospesos", "Visa_mconsumototal", "Visa_mpagominimo"
  )

  # Grupo 2: Variables DOLARIZADAS
  columnas_dolares <- c(
    "mcaja_ahorro_dolares", "mplazo_fijo_dolares", "minversion1_dolares",
    "Master_msaldodolares", "Master_mconsumosdolares", "Master_madelantodolares",
    "Master_mpagosdolares",
    "Visa_msaldodolares", "Visa_mconsumosdolares", "Visa_madelantodolares",
    "Visa_mpagosdolares"
  )

  # Grupos de lógicas (actualizados a tu tabla final)
  grupo_indices <- c("IPC", "IPIM", "UVA", "ripte_indice") # Se fueron CER e indice_salarios
  grupo_tc <- c("TC_BLUE", "TC_OFICIAL", "TCRM") # Se fue TC_MAYORISTA, TC_MINORISTA
  grupo_tasas <- c("tasa_i", "tasa_r") # Nombres actualizados

  # --- 2. Validar Entradas ---
  if (!criterio_deflacion %in% names(dt_indices)) {
     stop(paste("La columna de criterio '", criterio_deflacion, "' NO existe en 'indices_externos'."))
  }

  # --- 3. Preparar el Índice Normalizado ---
  dt_indice_temporal <- dt_indices[, .(foto_mes, INDICE_TEMP = get(criterio_deflacion))]
  setorder(dt_indice_temporal, foto_mes)
  valor_base <- dt_indice_temporal[foto_mes == mes_base, INDICE_TEMP]
  if (length(valor_base) == 0 | is.na(valor_base)) {
    stop(paste("El 'mes_base'", mes_base, "no se encontró o es NA en el índice."))
  }

  if (criterio_deflacion %in% grupo_indices) {
    cat("... Aplicando Lógica de ÍNDICE (Base 1.0)\n")
    dt_indice_temporal[, indice_normalizado := INDICE_TEMP / valor_base]
  } else if (criterio_deflacion %in% grupo_tasas) {
    cat("... Aplicando Lógica de TASA DE INTERÉS\n")
    dt_indice_temporal[, factor := 1 + INDICE_TEMP]
    dt_indice_temporal[, indice_compuesto := cumprod(factor)]
    valor_base_compuesto <- dt_indice_temporal[foto_mes == mes_base, indice_compuesto]
    dt_indice_temporal[, indice_normalizado := indice_compuesto / valor_base_compuesto]
  } else if (criterio_deflacion %in% grupo_tc) {
    cat("... Aplicando Lógica de TIPO DE CAMBIO\n")
    dt_indice_temporal[, indice_normalizado := INDICE_TEMP]
  } else {
    warning(paste("Criterio '", criterio_deflacion, "' no está en un grupo predefinido. Se usará la Lógica de ÍNDICE por defecto."))
    dt_indice_temporal[, indice_normalizado := INDICE_TEMP / valor_base]
  }

  dt_indice_para_merge <- dt_indice_temporal[, .(foto_mes, indice_normalizado)]

  # --- 4. Unir el índice al dataset principal (Modifica 'dt' por referencia) ---
  dt[dt_indice_para_merge, on = "foto_mes", indice_normalizado := i.indice_normalizado]

  # --- 5. Seleccionar columnas a deflactar ---
  cols_a_deflactar_final <- columnas_pesos
  if (incluir_dolarizadas) {
    cols_a_deflactar_final <- c(cols_a_deflactar_final, columnas_dolares)
  }
  cols_a_deflactar_final <- intersect(cols_a_deflactar_final, names(dt))

  if (length(cols_a_deflactar_final) == 0) {
    cat("Advertencia: Ninguna columna a deflactar fue encontrada. No se hizo nada.\n")
    dt[, indice_normalizado := NULL] # Limpiar la columna de índice
    return(dt)
  }

  # --- 6. Aplicar la deflación (SOBRESCRITURA) ---
  #     (ej: mrentabilidad = mrentabilidad / indice_normalizado)
  dt[, (cols_a_deflactar_final) := lapply(.SD, function(x) {
              x / indice_normalizado
            }), .SDcols = cols_a_deflactar_final]

  # --- 7. Limpiar columna de índice ---
  dt[, indice_normalizado := NULL]

  cat("Deflación completada.", length(cols_a_deflactar_final), "columnas fueron SOBREESCRITAS.\n")

  # Limpieza de memoria
  rm(dt_indice_temporal, dt_indice_para_merge, cols_a_deflactar_final,
     columnas_pesos, columnas_dolares, grupo_indices, grupo_tc, grupo_tasas)
  gc()

  return(dt)
}

# %% [markdown]
# #### Aplicamos una metodología

# %%
# (En la celda de Data Drifting)
deflactar_dataset(
  dt = dataset,
  dt_indices = indices_externos,
  criterio_deflacion = deflactor, #IPC , IPIM, UVA, ripte_indice, TC_BLUE, TC_OFICIAL, TCRM, tasa_i, tasa_r
  incluir_dolarizadas = TRUE,  # si es true afecta las columnas en dólares
  mes_base = 201901  #mes al que lleva el valor
)
# Out:
# Iniciando deflación según Criterio: IPC
# ... Aplicando Lógica de ÍNDICE (Base 1.0)
# Deflación completada. 70 columnas fueron SOBREESCRITAS.

# %% [markdown]
# # Rankings

# %%
require(data.table)

#' @title Rankea columnas monetarias por mes (SOBREESCRIBIENDO)
#' @description Normaliza las columnas monetarias en un rango de [-1, 1]
#'              agrupando por foto_mes y tratando positivos y negativos
#'              por separado.
#'
#' @param p_dataset El data.table a modificar.

rank_normalizar_por_mes_monetarias <- function(p_dataset) {

  # 1. Define el vector con los nombres BASE de las columnas monetarias
  columnas_monetarias_base <- c(
    "mrentabilidad", "mrentabilidad_annual", "mcomisiones", "mactivos_margen",
    "mpasivos_margen", "mcuenta_corriente_adicional", "mcuenta_corriente",
    "mcaja_ahorro", "mcaja_ahorro_adicional", "mcaja_ahorro_dolares",
    "mcuentas_saldo", "mautoservicio", "mtarjeta_visa_consumo",
    "mtarjeta_master_consumo", "mprestamos_personales", "mprestamos_prendarios",
    "mprestamos_hipotecarios", "mplazo_fijo_dolares", "mplazo_fijo_pesos",
    "minversion1_pesos", "minversion1_dolares", "minversion2", "mpayroll",
    "mpayroll2", "mcuenta_debitos_automaticos", "mtarjeta_visa_debitos_automaticos",
    "mttarjeta_master_debitos_automaticos", "mpagodeservicios", "mpagomiscuentas",
    "mcajeros_propios_descuentos", "mtarjeta_visa_descuentos",
    "mtarjeta_master_descuentos", "mcomisiones_mantenimiento", "mcomisiones_otras",
    "mforex_buy", "mforex_sell", "mtransferencias_recibidas", "mtransferencias_emitidas",
    "mextraccion_autoservicio", "mcheques_depositados", "mcheques_emitidos",
    "mcheques_depositados_rechazados", "mcheques_emitidos_rechazados", "matm",
    "matm_other", "Master_mfinanciacion_limite", "Master_msaldototal",
    "Master_msaldopesos", "Master_msaldodolares", "Master_mconsumospesos",
    "Master_mconsumosdolares", "Master_mlimitecompra", "Master_madelantopesos",
    "Master_madelantodolares", "Master_mpagado", "Master_mpagospesos",
    "Master_mpagosdolares", "Master_mconsumototal", "Master_mpagominimo",
    "Visa_mfinanciacion_limite", "Visa_msaldototal", "Visa_msaldopesos",
    "Visa_msaldodolares", "Visa_mconsumospesos", "Visa_mconsumosdolares",
    "Visa_mlimitecompra", "Visa_madelantopesos", "Visa_madelantodolares",
    "Visa_mpagado", "Visa_mpagospesos", "Visa_mpagosdolares", "Visa_mconsumototal",
    "Visa_mpagominimo"
  )

  # 2. Selecciona solo las columnas que realmente existen en el dataset
  columnas_a_rankear <- intersect(columnas_monetarias_base, names(p_dataset))


  cat("Columnas a rankear por mes (sobrescribiendo):", length(columnas_a_rankear), "\n")
  if (length(columnas_a_rankear) == 0) {
    cat("Advertencia: Ninguna de las columnas monetarias especificadas se encontró en el dataset.\n")
    return(invisible(p_dataset))
  }

  for (col in columnas_a_rankear) {

    p_dataset[, (col) := {
      v <- .SD[[1]]
      r <- numeric(length(v))

      pos_idx <- which(v > 0)
      neg_idx <- which(v < 0)

      if (length(pos_idx) > 0) {
        r[pos_idx] <- frank(v[pos_idx], ties.method = "average") / length(pos_idx)
      }
      if (length(neg_idx) > 0) {
        r[neg_idx] <- -frank(-v[neg_idx], ties.method = "average") / length(neg_idx)
      }

      r[v == 0] <- 0

      # Segunda normalización para asegurar el rango [-1, 1]
      max_r_pos <- max(r[pos_idx], 0, na.rm = TRUE)
      min_r_neg <- min(r[neg_idx], 0, na.rm = TRUE)

      if (max_r_pos > 0) r[pos_idx] <- r[pos_idx] / max_r_pos
      if (min_r_neg < 0) r[neg_idx] <- r[neg_idx] / abs(min_r_neg)

      .(r)
    }, by = foto_mes, .SDcols = col]
  }



  cat("Rankeo completado. Las columnas fueron sobrescritas.\n")
  gc()
  invisible(p_dataset)
}

# %%
# # aplico la función
rank_normalizar_por_mes_monetarias(dataset)

# %% [markdown]
# ### Feature Engineering Intra-Mes

# %% [markdown]
# Crear variables nuevas a partir de las existentes dentro del mismo registro, **sin** ir a buscar información histórica.
# <br> El siguiente código es un mínimo ejemplo, agregar nuevos features a gusto

# %%
# el mes 1,2, ..12 , podria servir para detectar estacionalidad
dataset[, kmes := foto_mes %% 100]

# creo un ctr_quarter que tenga en cuenta cuando
# los clientes hace 3 menos meses que estan
# ya que seria injusto considerar las transacciones medidas en menor tiempo
dataset[, ctrx_quarter_normalizado := as.numeric(ctrx_quarter) ]
dataset[cliente_antiguedad == 1, ctrx_quarter_normalizado := ctrx_quarter * 5.0]
dataset[cliente_antiguedad == 2, ctrx_quarter_normalizado := ctrx_quarter * 2.0]
dataset[cliente_antiguedad == 3, ctrx_quarter_normalizado := ctrx_quarter * 1.2]

# variable extraida de una tesis de maestria de Irlanda, se perdió el link
dataset[, mpayroll_sobre_edad := mpayroll / cliente_edad]

Sys.time()
# Out:
# [1] "2025-12-03 14:47:02 UTC"

# %% [markdown]
# ### Feature Engineering Historico

# %%
if( !require("Rcpp")) install.packages("Rcpp", repos = "http://cran.us.r-project.org")
require("Rcpp")
# Out:
# Loading required package: Rcpp

# %%
# se calculan para los 6 meses previos el minimo, maximo y
#  tendencia calculada con cuadrados minimos
# la formula de calculo de la tendencia puede verse en
#  https://stats.libretexts.org/Bookshelves/Introductory_Statistics/Book%3A_Introductory_Statistics_(Shafer_and_Zhang)/10%3A_Correlation_and_Regression/10.04%3A_The_Least_Squares_Regression_Line
# para la maxíma velocidad esta funcion esta escrita en lenguaje C,
# y no en la porqueria de R o Python

cppFunction("NumericVector fhistC(NumericVector pcolumna, IntegerVector pdesde )
{
  /* Aqui se cargan los valores para la regresion */
  double  x[100] ;
  double  y[100] ;

  int n = pcolumna.size();
  NumericVector out( 5*n );

  for(int i = 0; i < n; i++)
  {
    //lag
    if( pdesde[i]-1 < i )  out[ i + 4*n ]  =  pcolumna[i-1] ;
    else                   out[ i + 4*n ]  =  NA_REAL ;


    int  libre    = 0 ;
    int  xvalor   = 1 ;

    for( int j= pdesde[i]-1;  j<=i; j++ )
    {
       double a = pcolumna[j] ;

       if( !R_IsNA( a ) )
       {
          y[ libre ]= a ;
          x[ libre ]= xvalor ;
          libre++ ;
       }

       xvalor++ ;
    }

    /* Si hay al menos dos valores */
    if( libre > 1 )
    {
      double  xsum  = x[0] ;
      double  ysum  = y[0] ;
      double  xysum = xsum * ysum ;
      double  xxsum = xsum * xsum ;
      double  vmin  = y[0] ;
      double  vmax  = y[0] ;

      for( int h=1; h<libre; h++)
      {
        xsum  += x[h] ;
        ysum  += y[h] ;
        xysum += x[h]*y[h] ;
        xxsum += x[h]*x[h] ;

        if( y[h] < vmin )  vmin = y[h] ;
        if( y[h] > vmax )  vmax = y[h] ;
      }

      out[ i ]  =  (libre*xysum - xsum*ysum)/(libre*xxsum -xsum*xsum) ;
      out[ i + n ]    =  vmin ;
      out[ i + 2*n ]  =  vmax ;
      out[ i + 3*n ]  =  ysum / libre ;
    }
    else
    {
      out[ i       ]  =  NA_REAL ;
      out[ i + n   ]  =  NA_REAL ;
      out[ i + 2*n ]  =  NA_REAL ;
      out[ i + 3*n ]  =  NA_REAL ;
    }
  }

  return  out;
}")

# %%
# calcula la tendencia de las variables cols de los ultimos 6 meses
# la tendencia es la pendiente de la recta que ajusta por cuadrados minimos
# La funcionalidad de ratioavg es autoria de  Daiana Sparta,  UAustral  2021

TendenciaYmuchomas <- function(
    dataset, cols, ventana = 6, tendencia = TRUE,
    minimo = TRUE, maximo = TRUE, promedio = TRUE,
    ratioavg = FALSE, ratiomax = FALSE) {
  gc(verbose= FALSE)
  # Esta es la cantidad de meses que utilizo para la historia
  ventana_regresion <- ventana

  last <- nrow(dataset)

  # creo el vector_desde que indica cada ventana
  # de esta forma se acelera el procesamiento ya que lo hago una sola vez
  vector_ids <- dataset[ , numero_de_cliente ]

  vector_desde <- seq(
    -ventana_regresion + 2,
    nrow(dataset) - ventana_regresion + 1
  )

  vector_desde[1:ventana_regresion] <- 1

  for (i in 2:last) {
    if (vector_ids[i - 1] != vector_ids[i]) {
      vector_desde[i] <- i
    }
  }
  for (i in 2:last) {
    if (vector_desde[i] < vector_desde[i - 1]) {
      vector_desde[i] <- vector_desde[i - 1]
    }
  }

  for (campo in cols) {
    nueva_col <- fhistC(dataset[, get(campo)], vector_desde)

    if (tendencia) {
      dataset[, paste0(campo, "_tend", ventana) :=
        nueva_col[(0 * last + 1):(1 * last)]]
    }

    if (minimo) {
      dataset[, paste0(campo, "_min", ventana) :=
        nueva_col[(1 * last + 1):(2 * last)]]
    }

    if (maximo) {
      dataset[, paste0(campo, "_max", ventana) :=
        nueva_col[(2 * last + 1):(3 * last)]]
    }

    if (promedio) {
      dataset[, paste0(campo, "_avg", ventana) :=
        nueva_col[(3 * last + 1):(4 * last)]]
    }

    if (ratioavg) {
      dataset[, paste0(campo, "_ratioavg", ventana) :=
        get(campo) / nueva_col[(3 * last + 1):(4 * last)]]
    }

    if (ratiomax) {
      dataset[, paste0(campo, "_ratiomax", ventana) :=
        get(campo) / nueva_col[(2 * last + 1):(3 * last)]]
    }
  }
}

# %%
# Feature Engineering Historico
# Creacion de LAGs
setorder(dataset, numero_de_cliente, foto_mes)

# todo es lagueable, menos la primary key y la clase
cols_lagueables <- copy( setdiff(
  colnames(dataset),
  c("numero_de_cliente", "foto_mes", "clase_ternaria")
))

# https://rdrr.io/cran/data.table/man/shift.html

# lags de orden 1
dataset[,
  paste0(cols_lagueables, "_lag1") := shift(.SD, 1, NA, "lag"),
  by= numero_de_cliente,
  .SDcols= cols_lagueables
]

# lags de orden 2
dataset[,
  paste0(cols_lagueables, "_lag2") := shift(.SD, 2, NA, "lag"),
  by= numero_de_cliente,
  .SDcols= cols_lagueables
]

# lags de orden 3
dataset[,
  paste0(cols_lagueables, "_lag3") := shift(.SD, 3, NA, "lag"),
  by= numero_de_cliente,
  .SDcols= cols_lagueables
]

# lags de orden 6
dataset[,
  paste0(cols_lagueables, "_lag6") := shift(.SD, 6, NA, "lag"),
  by= numero_de_cliente,
  .SDcols= cols_lagueables
]

# lags de orden 12
dataset[,
  paste0(cols_lagueables, "_lag12") := shift(.SD, 12, NA, "lag"),
  by= numero_de_cliente,
  .SDcols= cols_lagueables
]

# agrego los delta lags
for (vcol in cols_lagueables)
{
  dataset[, paste0(vcol, "_delta1") := get(vcol) - get(paste0(vcol, "_lag1"))]
  dataset[, paste0(vcol, "_delta2") := get(vcol) - get(paste0(vcol, "_lag2"))]
  dataset[, paste0(vcol, "_delta3") := get(vcol) - get(paste0(vcol, "_lag3"))]
  dataset[, paste0(vcol, "_delta6") := get(vcol) - get(paste0(vcol, "_lag6"))]
  dataset[, paste0(vcol, "_delta12") := get(vcol) - get(paste0(vcol, "_lag12"))]
}

Sys.time()
# Out:
# [1] "2025-12-03 14:52:04 UTC"

# %%
# parametros de Feature Engineering Historico de Tendencias
PARAM$FE_hist$Tendencias$run <- TRUE
PARAM$FE_hist$Tendencias$ventana <- 6
PARAM$FE_hist$Tendencias$tendencia <- FALSE
PARAM$FE_hist$Tendencias$minimo <- FALSE
PARAM$FE_hist$Tendencias$maximo <- FALSE
PARAM$FE_hist$Tendencias$promedio <- TRUE
PARAM$FE_hist$Tendencias$ratioavg <- FALSE
PARAM$FE_hist$Tendencias$ratiomax <- FALSE

# %%
# aqui se agregan las tendencias de los ultimos 6 meses

cols_lagueables <- intersect(cols_lagueables, colnames(dataset))
setorder(dataset, numero_de_cliente, foto_mes)

if( PARAM$FE_hist$Tendencias$run) {
    TendenciaYmuchomas(dataset,
    cols = cols_lagueables,
    ventana = PARAM$FE_hist$Tendencias$ventana, # 6 meses de historia
    tendencia = PARAM$FE_hist$Tendencias$tendencia,
    minimo = PARAM$FE_hist$Tendencias$minimo,
    maximo = PARAM$FE_hist$Tendencias$maximo,
    promedio = PARAM$FE_hist$Tendencias$promedio,
    ratioavg = PARAM$FE_hist$Tendencias$ratioavg,
    ratiomax = PARAM$FE_hist$Tendencias$ratiomax
  )
}

ncol(dataset)
Sys.time()
# Out:
# [1] 1966
# [1] "2025-12-03 14:53:43 UTC"

# %%
ncol(dataset)
colnames(dataset)
# Out:
# [1] 2047
#    [1] "numero_de_cliente"
#    [2] "foto_mes"
#    [3] "active_quarter"
#    [4] "cliente_vip"
#    [5] "internet"
#    [6] "cliente_edad"
#    [7] "cliente_antiguedad"
#    [8] "mrentabilidad"
#    [9] "mrentabilidad_annual"
#   [10] "mcomisiones"
#   [11] "mactivos_margen"
#   [12] "mpasivos_margen"
#   [13] "cproductos"
#   [14] "tcuentas"
#   [15] "ccuenta_corriente"
#   [16] "mcuenta_corriente_adicional"
#   [17] "mcuenta_corriente"
#   [18] "ccaja_ahorro"
#   [19] "mcaja_ahorro"
#   [20] "mcaja_ahorro_adicional"
#   [21] "mcaja_ahorro_dolares"
#   [22] "cdescubierto_preacordado"
#   [23] "mcuentas_saldo"
#   [24] "ctarjeta_debito"
#   [25] "ctarjeta_debito_transacciones"
#   [26] "mautoservicio"
#   [27] "ctarjeta_visa"
#   [28] "ctarjeta_visa_transacciones"
#   [29] "mtarjeta_visa_consumo"
#   [30] "ctarjeta_master"
#   [31] "ctarjeta_master_transacciones"
#   [32] "mtarjeta_master_consumo"
#   [33] "cprestamos_prendarios"
#   [34] "mprestamos_prendarios"
#   [35] "cprestamos_hipotecarios"
#   [36] "mprestamos_hipotecarios"
#   [37] "cplazo_fijo"
#   [38] "mplazo_fijo_dolares"
#   [39] "mplazo_fijo_pesos"
#   [40] "cinversion1"
#   [41] "minversion1_pesos"
#   [42] "minversion1_dolares"
#   [43] "cinversion2"
#   [44] "minversion2"
#   [45] "cseguro_vida"
#   [46] "cseguro_auto"
#   [47] "cseguro_vivienda"
#   [48] "cseguro_accidentes_personales"
#   [49] "ccaja_seguridad"
#   [50] "cpayroll_trx"
#   [51] "mpayroll"
#   [52] "mpayroll2"
#   [53] "cpayroll2_trx"
#   [54] "ccuenta_debitos_automaticos"
#   [55] "mcuenta_debitos_automaticos"
#   [56] "ctarjeta_visa_debitos_automaticos"
#   [57] "mttarjeta_visa_debitos_automaticos"
#   [58] "ctarjeta_master_debitos_automaticos"
#   [59] "mttarjeta_master_debitos_automaticos"
#   [60] "cpagodeservicios"
#   [61] "mpagodeservicios"
#   [62] "cpagomiscuentas"
#   [63] "mpagomiscuentas"
#   [64] "ccajeros_propios_descuentos"
#   [65] "mcajeros_propios_descuentos"
#   [66] "ctarjeta_visa_descuentos"
#   [67] "mtarjeta_visa_descuentos"
#   [68] "ctarjeta_master_descuentos"
#   [69] "mtarjeta_master_descuentos"
#   [70] "ccomisiones_mantenimiento"
#   [71] "mcomisiones_mantenimiento"
#   [72] "ccomisiones_otras"
#   [73] "mcomisiones_otras"
#   [74] "cforex"
#   [75] "cforex_buy"
#   [76] "mforex_buy"
#   [77] "cforex_sell"
#   [78] "mforex_sell"
#   [79] "ctransferencias_recibidas"
#   [80] "mtransferencias_recibidas"
#   [81] "ctransferencias_emitidas"
#   [82] "mtransferencias_emitidas"
#   [83] "cextraccion_autoservicio"
#   [84] "mextraccion_autoservicio"
#   [85] "ccheques_depositados"
#   [86] "mcheques_depositados"
#   [87] "ccheques_emitidos"
#   [88] "mcheques_emitidos"
#   [89] "ccheques_depositados_rechazados"
#   [90] "mcheques_depositados_rechazados"
#   [91] "ccheques_emitidos_rechazados"
#   [92] "mcheques_emitidos_rechazados"
#   [93] "tcallcenter"
#   [94] "ccallcenter_transacciones"
#   [95] "thomebanking"
#   [96] "chomebanking_transacciones"
#   [97] "ccajas_transacciones"
#   [98] "ccajas_consultas"
#   [99] "ccajas_depositos"
#  [100] "ccajas_extracciones"
#  [101] "ccajas_otras"
#  [102] "catm_trx"
#  [103] "matm"
#  [104] "catm_trx_other"
#  [105] "matm_other"
#  [106] "ctrx_quarter"
#  [107] "tmobile_app"
#  [108] "cmobile_app_trx"
#  [109] "Master_delinquency"
#  [110] "Master_status"
#  [111] "Master_Fvencimiento"
#  [112] "Master_Finiciomora"
#  [113] "Master_msaldototal"
#  [114] "Master_msaldopesos"
#  [115] "Master_msaldodolares"
#  [116] "Master_mconsumospesos"
#  [117] "Master_mconsumosdolares"
#  [118] "Master_mlimitecompra"
#  [119] "Master_madelantopesos"
#  [120] "Master_madelantodolares"
#  [121] "Master_fultimo_cierre"
#  [122] "Master_mpagado"
#  [123] "Master_mpagospesos"
#  [124] "Master_mpagosdolares"
#  [125] "Master_fechaalta"
#  [126] "Master_mconsumototal"
#  [127] "Master_cconsumos"
#  [128] "Master_cadelantosefectivo"
#  [129] "Master_mpagominimo"
#  [130] "Visa_delinquency"
#  [131] "Visa_status"
#  [132] "Visa_Fvencimiento"
#  [133] "Visa_Finiciomora"
#  [134] "Visa_msaldototal"
#  [135] "Visa_msaldopesos"
#  [136] "Visa_msaldodolares"
#  [137] "Visa_mconsumospesos"
#  [138] "Visa_mconsumosdolares"
#  [139] "Visa_mlimitecompra"
#  [140] "Visa_madelantopesos"
#  [141] "Visa_madelantodolares"
#  [142] "Visa_fultimo_cierre"
#  [143] "Visa_mpagado"
#  [144] "Visa_mpagospesos"
#  [145] "Visa_mpagosdolares"
#  [146] "Visa_fechaalta"
#  [147] "Visa_mconsumototal"
#  [148] "Visa_cconsumos"
#  [149] "Visa_cadelantosefectivo"
#  [150] "Visa_mpagominimo"
#  [151] "clase_ternaria"
#  [152] "kmes"
#  [153] "ctrx_quarter_normalizado"
#  [154] "mpayroll_sobre_edad"
#  [155] "active_quarter_lag1"
#  [156] "cliente_vip_lag1"
#  [157] "internet_lag1"
#  [158] "cliente_edad_lag1"
#  [159] "cliente_antiguedad_lag1"
#  [160] "mrentabilidad_lag1"
#  [161] "mrentabilidad_annual_lag1"
#  [162] "mcomisiones_lag1"
#  [163] "mactivos_margen_lag1"
#  [164] "mpasivos_margen_lag1"
#  [165] "cproductos_lag1"
#  [166] "tcuentas_lag1"
#  [167] "ccuenta_corriente_lag1"
#  [168] "mcuenta_corriente_adicional_lag1"
#  [169] "mcuenta_corriente_lag1"
#  [170] "ccaja_ahorro_lag1"
#  [171] "mcaja_ahorro_lag1"
#  [172] "mcaja_ahorro_adicional_lag1"
#  [173] "mcaja_ahorro_dolares_lag1"
#  [174] "cdescubierto_preacordado_lag1"
#  [175] "mcuentas_saldo_lag1"
#  [176] "ctarjeta_debito_lag1"
#  [177] "ctarjeta_debito_transacciones_lag1"
#  [178] "mautoservicio_lag1"
#  [179] "ctarjeta_visa_lag1"
#  [180] "ctarjeta_visa_transacciones_lag1"
#  [181] "mtarjeta_visa_consumo_lag1"
#  [182] "ctarjeta_master_lag1"
#  [183] "ctarjeta_master_transacciones_lag1"
#  [184] "mtarjeta_master_consumo_lag1"
#  [185] "cprestamos_prendarios_lag1"
#  [186] "mprestamos_prendarios_lag1"
#  [187] "cprestamos_hipotecarios_lag1"
#  [188] "mprestamos_hipotecarios_lag1"
#  [189] "cplazo_fijo_lag1"
#  [190] "mplazo_fijo_dolares_lag1"
#  [191] "mplazo_fijo_pesos_lag1"
#  [192] "cinversion1_lag1"
#  [193] "minversion1_pesos_lag1"
#  [194] "minversion1_dolares_lag1"
#  [195] "cinversion2_lag1"
#  [196] "minversion2_lag1"
#  [197] "cseguro_vida_lag1"
#  [198] "cseguro_auto_lag1"
#  [199] "cseguro_vivienda_lag1"
#  [200] "cseguro_accidentes_personales_lag1"
#  [201] "ccaja_seguridad_lag1"
#  [202] "cpayroll_trx_lag1"
#  [203] "mpayroll_lag1"
#  [204] "mpayroll2_lag1"
#  [205] "cpayroll2_trx_lag1"
#  [206] "ccuenta_debitos_automaticos_lag1"
#  [207] "mcuenta_debitos_automaticos_lag1"
#  [208] "ctarjeta_visa_debitos_automaticos_lag1"
#  [209] "mttarjeta_visa_debitos_automaticos_lag1"
#  [210] "ctarjeta_master_debitos_automaticos_lag1"
#  [211] "mttarjeta_master_debitos_automaticos_lag1"
#  [212] "cpagodeservicios_lag1"
#  [213] "mpagodeservicios_lag1"
#  [214] "cpagomiscuentas_lag1"
#  [215] "mpagomiscuentas_lag1"
#  [216] "ccajeros_propios_descuentos_lag1"
#  [217] "mcajeros_propios_descuentos_lag1"
#  [218] "ctarjeta_visa_descuentos_lag1"
#  [219] "mtarjeta_visa_descuentos_lag1"
#  [220] "ctarjeta_master_descuentos_lag1"
#  [221] "mtarjeta_master_descuentos_lag1"
#  [222] "ccomisiones_mantenimiento_lag1"
#  [223] "mcomisiones_mantenimiento_lag1"
#  [224] "ccomisiones_otras_lag1"
#  [225] "mcomisiones_otras_lag1"
#  [226] "cforex_lag1"
#  [227] "cforex_buy_lag1"
#  [228] "mforex_buy_lag1"
#  [229] "cforex_sell_lag1"
#  [230] "mforex_sell_lag1"
#  [231] "ctransferencias_recibidas_lag1"
#  [232] "mtransferencias_recibidas_lag1"
#  [233] "ctransferencias_emitidas_lag1"
#  [234] "mtransferencias_emitidas_lag1"
#  [235] "cextraccion_autoservicio_lag1"
#  [236] "mextraccion_autoservicio_lag1"
#  [237] "ccheques_depositados_lag1"
#  [238] "mcheques_depositados_lag1"
#  [239] "ccheques_emitidos_lag1"
#  [240] "mcheques_emitidos_lag1"
#  [241] "ccheques_depositados_rechazados_lag1"
#  [242] "mcheques_depositados_rechazados_lag1"
#  [243] "ccheques_emitidos_rechazados_lag1"
#  [244] "mcheques_emitidos_rechazados_lag1"
#  [245] "tcallcenter_lag1"
#  [246] "ccallcenter_transacciones_lag1"
#  [247] "thomebanking_lag1"
#  [248] "chomebanking_transacciones_lag1"
#  [249] "ccajas_transacciones_lag1"
#  [250] "ccajas_consultas_lag1"
#  [251] "ccajas_depositos_lag1"
#  [252] "ccajas_extracciones_lag1"
#  [253] "ccajas_otras_lag1"
#  [254] "catm_trx_lag1"
#  [255] "matm_lag1"
#  [256] "catm_trx_other_lag1"
#  [257] "matm_other_lag1"
#  [258] "ctrx_quarter_lag1"
#  [259] "tmobile_app_lag1"
#  [260] "cmobile_app_trx_lag1"
#  [261] "Master_delinquency_lag1"
#  [262] "Master_status_lag1"
#  [263] "Master_Fvencimiento_lag1"
#  [264] "Master_Finiciomora_lag1"
#  [265] "Master_msaldototal_lag1"
#  [266] "Master_msaldopesos_lag1"
#  [267] "Master_msaldodolares_lag1"
#  [268] "Master_mconsumospesos_lag1"
#  [269] "Master_mconsumosdolares_lag1"
#  [270] "Master_mlimitecompra_lag1"
#  [271] "Master_madelantopesos_lag1"
#  [272] "Master_madelantodolares_lag1"
#  [273] "Master_fultimo_cierre_lag1"
#  [274] "Master_mpagado_lag1"
#  [275] "Master_mpagospesos_lag1"
#  [276] "Master_mpagosdolares_lag1"
#  [277] "Master_fechaalta_lag1"
#  [278] "Master_mconsumototal_lag1"
#  [279] "Master_cconsumos_lag1"
#  [280] "Master_cadelantosefectivo_lag1"
#  [281] "Master_mpagominimo_lag1"
#  [282] "Visa_delinquency_lag1"
#  [283] "Visa_status_lag1"
#  [284] "Visa_Fvencimiento_lag1"
#  [285] "Visa_Finiciomora_lag1"
#  [286] "Visa_msaldototal_lag1"
#  [287] "Visa_msaldopesos_lag1"
#  [288] "Visa_msaldodolares_lag1"
#  [289] "Visa_mconsumospesos_lag1"
#  [290] "Visa_mconsumosdolares_lag1"
#  [291] "Visa_mlimitecompra_lag1"
#  [292] "Visa_madelantopesos_lag1"
#  [293] "Visa_madelantodolares_lag1"
#  [294] "Visa_fultimo_cierre_lag1"
#  [295] "Visa_mpagado_lag1"
#  [296] "Visa_mpagospesos_lag1"
#  [297] "Visa_mpagosdolares_lag1"
#  [298] "Visa_fechaalta_lag1"
#  [299] "Visa_mconsumototal_lag1"
#  [300] "Visa_cconsumos_lag1"
#  [301] "Visa_cadelantosefectivo_lag1"
#  [302] "Visa_mpagominimo_lag1"
#  [303] "kmes_lag1"
#  [304] "ctrx_quarter_normalizado_lag1"
#  [305] "mpayroll_sobre_edad_lag1"
#  [306] "active_quarter_lag2"
#  [307] "cliente_vip_lag2"
#  [308] "internet_lag2"
#  [309] "cliente_edad_lag2"
#  [310] "cliente_antiguedad_lag2"
#  [311] "mrentabilidad_lag2"
#  [312] "mrentabilidad_annual_lag2"
#  [313] "mcomisiones_lag2"
#  [314] "mactivos_margen_lag2"
#  [315] "mpasivos_margen_lag2"
#  [316] "cproductos_lag2"
#  [317] "tcuentas_lag2"
#  [318] "ccuenta_corriente_lag2"
#  [319] "mcuenta_corriente_adicional_lag2"
#  [320] "mcuenta_corriente_lag2"
#  [321] "ccaja_ahorro_lag2"
#  [322] "mcaja_ahorro_lag2"
#  [323] "mcaja_ahorro_adicional_lag2"
#  [324] "mcaja_ahorro_dolares_lag2"
#  [325] "cdescubierto_preacordado_lag2"
#  [326] "mcuentas_saldo_lag2"
#  [327] "ctarjeta_debito_lag2"
#  [328] "ctarjeta_debito_transacciones_lag2"
#  [329] "mautoservicio_lag2"
#  [330] "ctarjeta_visa_lag2"
#  [331] "ctarjeta_visa_transacciones_lag2"
#  [332] "mtarjeta_visa_consumo_lag2"
#  [333] "ctarjeta_master_lag2"
#  [334] "ctarjeta_master_transacciones_lag2"
#  [335] "mtarjeta_master_consumo_lag2"
#  [336] "cprestamos_prendarios_lag2"
#  [337] "mprestamos_prendarios_lag2"
#  [338] "cprestamos_hipotecarios_lag2"
#  [339] "mprestamos_hipotecarios_lag2"
#  [340] "cplazo_fijo_lag2"
#  [341] "mplazo_fijo_dolares_lag2"
#  [342] "mplazo_fijo_pesos_lag2"
#  [343] "cinversion1_lag2"
#  [344] "minversion1_pesos_lag2"
#  [345] "minversion1_dolares_lag2"
#  [346] "cinversion2_lag2"
#  [347] "minversion2_lag2"
#  [348] "cseguro_vida_lag2"
#  [349] "cseguro_auto_lag2"
#  [350] "cseguro_vivienda_lag2"
#  [351] "cseguro_accidentes_personales_lag2"
#  [352] "ccaja_seguridad_lag2"
#  [353] "cpayroll_trx_lag2"
#  [354] "mpayroll_lag2"
#  [355] "mpayroll2_lag2"
#  [356] "cpayroll2_trx_lag2"
#  [357] "ccuenta_debitos_automaticos_lag2"
#  [358] "mcuenta_debitos_automaticos_lag2"
#  [359] "ctarjeta_visa_debitos_automaticos_lag2"
#  [360] "mttarjeta_visa_debitos_automaticos_lag2"
#  [361] "ctarjeta_master_debitos_automaticos_lag2"
#  [362] "mttarjeta_master_debitos_automaticos_lag2"
#  [363] "cpagodeservicios_lag2"
#  [364] "mpagodeservicios_lag2"
#  [365] "cpagomiscuentas_lag2"
#  [366] "mpagomiscuentas_lag2"
#  [367] "ccajeros_propios_descuentos_lag2"
#  [368] "mcajeros_propios_descuentos_lag2"
#  [369] "ctarjeta_visa_descuentos_lag2"
#  [370] "mtarjeta_visa_descuentos_lag2"
#  [371] "ctarjeta_master_descuentos_lag2"
#  [372] "mtarjeta_master_descuentos_lag2"
#  [373] "ccomisiones_mantenimiento_lag2"
#  [374] "mcomisiones_mantenimiento_lag2"
#  [375] "ccomisiones_otras_lag2"
#  [376] "mcomisiones_otras_lag2"
#  [377] "cforex_lag2"
#  [378] "cforex_buy_lag2"
#  [379] "mforex_buy_lag2"
#  [380] "cforex_sell_lag2"
#  [381] "mforex_sell_lag2"
#  [382] "ctransferencias_recibidas_lag2"
#  [383] "mtransferencias_recibidas_lag2"
#  [384] "ctransferencias_emitidas_lag2"
#  [385] "mtransferencias_emitidas_lag2"
#  [386] "cextraccion_autoservicio_lag2"
#  [387] "mextraccion_autoservicio_lag2"
#  [388] "ccheques_depositados_lag2"
#  [389] "mcheques_depositados_lag2"
#  [390] "ccheques_emitidos_lag2"
#  [391] "mcheques_emitidos_lag2"
#  [392] "ccheques_depositados_rechazados_lag2"
#  [393] "mcheques_depositados_rechazados_lag2"
#  [394] "ccheques_emitidos_rechazados_lag2"
#  [395] "mcheques_emitidos_rechazados_lag2"
#  [396] "tcallcenter_lag2"
#  [397] "ccallcenter_transacciones_lag2"
#  [398] "thomebanking_lag2"
#  [399] "chomebanking_transacciones_lag2"
#  [400] "ccajas_transacciones_lag2"
#  [401] "ccajas_consultas_lag2"
#  [402] "ccajas_depositos_lag2"
#  [403] "ccajas_extracciones_lag2"
#  [404] "ccajas_otras_lag2"
#  [405] "catm_trx_lag2"
#  [406] "matm_lag2"
#  [407] "catm_trx_other_lag2"
#  [408] "matm_other_lag2"
#  [409] "ctrx_quarter_lag2"
#  [410] "tmobile_app_lag2"
#  [411] "cmobile_app_trx_lag2"
#  [412] "Master_delinquency_lag2"
#  [413] "Master_status_lag2"
#  [414] "Master_Fvencimiento_lag2"
#  [415] "Master_Finiciomora_lag2"
#  [416] "Master_msaldototal_lag2"
#  [417] "Master_msaldopesos_lag2"
#  [418] "Master_msaldodolares_lag2"
#  [419] "Master_mconsumospesos_lag2"
#  [420] "Master_mconsumosdolares_lag2"
#  [421] "Master_mlimitecompra_lag2"
#  [422] "Master_madelantopesos_lag2"
#  [423] "Master_madelantodolares_lag2"
#  [424] "Master_fultimo_cierre_lag2"
#  [425] "Master_mpagado_lag2"
#  [426] "Master_mpagospesos_lag2"
#  [427] "Master_mpagosdolares_lag2"
#  [428] "Master_fechaalta_lag2"
#  [429] "Master_mconsumototal_lag2"
#  [430] "Master_cconsumos_lag2"
#  [431] "Master_cadelantosefectivo_lag2"
#  [432] "Master_mpagominimo_lag2"
#  [433] "Visa_delinquency_lag2"
#  [434] "Visa_status_lag2"
#  [435] "Visa_Fvencimiento_lag2"
#  [436] "Visa_Finiciomora_lag2"
#  [437] "Visa_msaldototal_lag2"
#  [438] "Visa_msaldopesos_lag2"
#  [439] "Visa_msaldodolares_lag2"
#  [440] "Visa_mconsumospesos_lag2"
#  [441] "Visa_mconsumosdolares_lag2"
#  [442] "Visa_mlimitecompra_lag2"
#  [443] "Visa_madelantopesos_lag2"
#  [444] "Visa_madelantodolares_lag2"
#  [445] "Visa_fultimo_cierre_lag2"
#  [446] "Visa_mpagado_lag2"
#  [447] "Visa_mpagospesos_lag2"
#  [448] "Visa_mpagosdolares_lag2"
#  [449] "Visa_fechaalta_lag2"
#  [450] "Visa_mconsumototal_lag2"
#  [451] "Visa_cconsumos_lag2"
#  [452] "Visa_cadelantosefectivo_lag2"
#  [453] "Visa_mpagominimo_lag2"
#  [454] "kmes_lag2"
#  [455] "ctrx_quarter_normalizado_lag2"
#  [456] "mpayroll_sobre_edad_lag2"
#  [457] "active_quarter_lag3"
#  [458] "cliente_vip_lag3"
#  [459] "internet_lag3"
#  [460] "cliente_edad_lag3"
#  [461] "cliente_antiguedad_lag3"
#  [462] "mrentabilidad_lag3"
#  [463] "mrentabilidad_annual_lag3"
#  [464] "mcomisiones_lag3"
#  [465] "mactivos_margen_lag3"
#  [466] "mpasivos_margen_lag3"
#  [467] "cproductos_lag3"
#  [468] "tcuentas_lag3"
#  [469] "ccuenta_corriente_lag3"
#  [470] "mcuenta_corriente_adicional_lag3"
#  [471] "mcuenta_corriente_lag3"
#  [472] "ccaja_ahorro_lag3"
#  [473] "mcaja_ahorro_lag3"
#  [474] "mcaja_ahorro_adicional_lag3"
#  [475] "mcaja_ahorro_dolares_lag3"
#  [476] "cdescubierto_preacordado_lag3"
#  [477] "mcuentas_saldo_lag3"
#  [478] "ctarjeta_debito_lag3"
#  [479] "ctarjeta_debito_transacciones_lag3"
#  [480] "mautoservicio_lag3"
#  [481] "ctarjeta_visa_lag3"
#  [482] "ctarjeta_visa_transacciones_lag3"
#  [483] "mtarjeta_visa_consumo_lag3"
#  [484] "ctarjeta_master_lag3"
#  [485] "ctarjeta_master_transacciones_lag3"
#  [486] "mtarjeta_master_consumo_lag3"
#  [487] "cprestamos_prendarios_lag3"
#  [488] "mprestamos_prendarios_lag3"
#  [489] "cprestamos_hipotecarios_lag3"
#  [490] "mprestamos_hipotecarios_lag3"
#  [491] "cplazo_fijo_lag3"
#  [492] "mplazo_fijo_dolares_lag3"
#  [493] "mplazo_fijo_pesos_lag3"
#  [494] "cinversion1_lag3"
#  [495] "minversion1_pesos_lag3"
#  [496] "minversion1_dolares_lag3"
#  [497] "cinversion2_lag3"
#  [498] "minversion2_lag3"
#  [499] "cseguro_vida_lag3"
#  [500] "cseguro_auto_lag3"
#  [501] "cseguro_vivienda_lag3"
#  [502] "cseguro_accidentes_personales_lag3"
#  [503] "ccaja_seguridad_lag3"
#  [504] "cpayroll_trx_lag3"
#  [505] "mpayroll_lag3"
#  [506] "mpayroll2_lag3"
#  [507] "cpayroll2_trx_lag3"
#  [508] "ccuenta_debitos_automaticos_lag3"
#  [509] "mcuenta_debitos_automaticos_lag3"
#  [510] "ctarjeta_visa_debitos_automaticos_lag3"
#  [511] "mttarjeta_visa_debitos_automaticos_lag3"
#  [512] "ctarjeta_master_debitos_automaticos_lag3"
#  [513] "mttarjeta_master_debitos_automaticos_lag3"
#  [514] "cpagodeservicios_lag3"
#  [515] "mpagodeservicios_lag3"
#  [516] "cpagomiscuentas_lag3"
#  [517] "mpagomiscuentas_lag3"
#  [518] "ccajeros_propios_descuentos_lag3"
#  [519] "mcajeros_propios_descuentos_lag3"
#  [520] "ctarjeta_visa_descuentos_lag3"
#  [521] "mtarjeta_visa_descuentos_lag3"
#  [522] "ctarjeta_master_descuentos_lag3"
#  [523] "mtarjeta_master_descuentos_lag3"
#  [524] "ccomisiones_mantenimiento_lag3"
#  [525] "mcomisiones_mantenimiento_lag3"
#  [526] "ccomisiones_otras_lag3"
#  [527] "mcomisiones_otras_lag3"
#  [528] "cforex_lag3"
#  [529] "cforex_buy_lag3"
#  [530] "mforex_buy_lag3"
#  [531] "cforex_sell_lag3"
#  [532] "mforex_sell_lag3"
#  [533] "ctransferencias_recibidas_lag3"
#  [534] "mtransferencias_recibidas_lag3"
#  [535] "ctransferencias_emitidas_lag3"
#  [536] "mtransferencias_emitidas_lag3"
#  [537] "cextraccion_autoservicio_lag3"
#  [538] "mextraccion_autoservicio_lag3"
#  [539] "ccheques_depositados_lag3"
#  [540] "mcheques_depositados_lag3"
#  [541] "ccheques_emitidos_lag3"
#  [542] "mcheques_emitidos_lag3"
#  [543] "ccheques_depositados_rechazados_lag3"
#  [544] "mcheques_depositados_rechazados_lag3"
#  [545] "ccheques_emitidos_rechazados_lag3"
#  [546] "mcheques_emitidos_rechazados_lag3"
#  [547] "tcallcenter_lag3"
#  [548] "ccallcenter_transacciones_lag3"
#  [549] "thomebanking_lag3"
#  [550] "chomebanking_transacciones_lag3"
#  [551] "ccajas_transacciones_lag3"
#  [552] "ccajas_consultas_lag3"
#  [553] "ccajas_depositos_lag3"
#  [554] "ccajas_extracciones_lag3"
#  [555] "ccajas_otras_lag3"
#  [556] "catm_trx_lag3"
#  [557] "matm_lag3"
#  [558] "catm_trx_other_lag3"
#  [559] "matm_other_lag3"
#  [560] "ctrx_quarter_lag3"
#  [561] "tmobile_app_lag3"
#  [562] "cmobile_app_trx_lag3"
#  [563] "Master_delinquency_lag3"
#  [564] "Master_status_lag3"
#  [565] "Master_Fvencimiento_lag3"
#  [566] "Master_Finiciomora_lag3"
#  [567] "Master_msaldototal_lag3"
#  [568] "Master_msaldopesos_lag3"
#  [569] "Master_msaldodolares_lag3"
#  [570] "Master_mconsumospesos_lag3"
#  [571] "Master_mconsumosdolares_lag3"
#  [572] "Master_mlimitecompra_lag3"
#  [573] "Master_madelantopesos_lag3"
#  [574] "Master_madelantodolares_lag3"
#  [575] "Master_fultimo_cierre_lag3"
#  [576] "Master_mpagado_lag3"
#  [577] "Master_mpagospesos_lag3"
#  [578] "Master_mpagosdolares_lag3"
#  [579] "Master_fechaalta_lag3"
#  [580] "Master_mconsumototal_lag3"
#  [581] "Master_cconsumos_lag3"
#  [582] "Master_cadelantosefectivo_lag3"
#  [583] "Master_mpagominimo_lag3"
#  [584] "Visa_delinquency_lag3"
#  [585] "Visa_status_lag3"
#  [586] "Visa_Fvencimiento_lag3"
#  [587] "Visa_Finiciomora_lag3"
#  [588] "Visa_msaldototal_lag3"
#  [589] "Visa_msaldopesos_lag3"
#  [590] "Visa_msaldodolares_lag3"
#  [591] "Visa_mconsumospesos_lag3"
#  [592] "Visa_mconsumosdolares_lag3"
#  [593] "Visa_mlimitecompra_lag3"
#  [594] "Visa_madelantopesos_lag3"
#  [595] "Visa_madelantodolares_lag3"
#  [596] "Visa_fultimo_cierre_lag3"
#  [597] "Visa_mpagado_lag3"
#  [598] "Visa_mpagospesos_lag3"
#  [599] "Visa_mpagosdolares_lag3"
#  [600] "Visa_fechaalta_lag3"
#  [601] "Visa_mconsumototal_lag3"
#  [602] "Visa_cconsumos_lag3"
#  [603] "Visa_cadelantosefectivo_lag3"
#  [604] "Visa_mpagominimo_lag3"
#  [605] "kmes_lag3"
#  [606] "ctrx_quarter_normalizado_lag3"
#  [607] "mpayroll_sobre_edad_lag3"
#  [608] "active_quarter_lag6"
#  [609] "cliente_vip_lag6"
#  [610] "internet_lag6"
#  [611] "cliente_edad_lag6"
#  [612] "cliente_antiguedad_lag6"
#  [613] "mrentabilidad_lag6"
#  [614] "mrentabilidad_annual_lag6"
#  [615] "mcomisiones_lag6"
#  [616] "mactivos_margen_lag6"
#  [617] "mpasivos_margen_lag6"
#  [618] "cproductos_lag6"
#  [619] "tcuentas_lag6"
#  [620] "ccuenta_corriente_lag6"
#  [621] "mcuenta_corriente_adicional_lag6"
#  [622] "mcuenta_corriente_lag6"
#  [623] "ccaja_ahorro_lag6"
#  [624] "mcaja_ahorro_lag6"
#  [625] "mcaja_ahorro_adicional_lag6"
#  [626] "mcaja_ahorro_dolares_lag6"
#  [627] "cdescubierto_preacordado_lag6"
#  [628] "mcuentas_saldo_lag6"
#  [629] "ctarjeta_debito_lag6"
#  [630] "ctarjeta_debito_transacciones_lag6"
#  [631] "mautoservicio_lag6"
#  [632] "ctarjeta_visa_lag6"
#  [633] "ctarjeta_visa_transacciones_lag6"
#  [634] "mtarjeta_visa_consumo_lag6"
#  [635] "ctarjeta_master_lag6"
#  [636] "ctarjeta_master_transacciones_lag6"
#  [637] "mtarjeta_master_consumo_lag6"
#  [638] "cprestamos_prendarios_lag6"
#  [639] "mprestamos_prendarios_lag6"
#  [640] "cprestamos_hipotecarios_lag6"
#  [641] "mprestamos_hipotecarios_lag6"
#  [642] "cplazo_fijo_lag6"
#  [643] "mplazo_fijo_dolares_lag6"
#  [644] "mplazo_fijo_pesos_lag6"
#  [645] "cinversion1_lag6"
#  [646] "minversion1_pesos_lag6"
#  [647] "minversion1_dolares_lag6"
#  [648] "cinversion2_lag6"
#  [649] "minversion2_lag6"
#  [650] "cseguro_vida_lag6"
#  [651] "cseguro_auto_lag6"
#  [652] "cseguro_vivienda_lag6"
#  [653] "cseguro_accidentes_personales_lag6"
#  [654] "ccaja_seguridad_lag6"
#  [655] "cpayroll_trx_lag6"
#  [656] "mpayroll_lag6"
#  [657] "mpayroll2_lag6"
#  [658] "cpayroll2_trx_lag6"
#  [659] "ccuenta_debitos_automaticos_lag6"
#  [660] "mcuenta_debitos_automaticos_lag6"
#  [661] "ctarjeta_visa_debitos_automaticos_lag6"
#  [662] "mttarjeta_visa_debitos_automaticos_lag6"
#  [663] "ctarjeta_master_debitos_automaticos_lag6"
#  [664] "mttarjeta_master_debitos_automaticos_lag6"
#  [665] "cpagodeservicios_lag6"
#  [666] "mpagodeservicios_lag6"
#  [667] "cpagomiscuentas_lag6"
#  [668] "mpagomiscuentas_lag6"
#  [669] "ccajeros_propios_descuentos_lag6"
#  [670] "mcajeros_propios_descuentos_lag6"
#  [671] "ctarjeta_visa_descuentos_lag6"
#  [672] "mtarjeta_visa_descuentos_lag6"
#  [673] "ctarjeta_master_descuentos_lag6"
#  [674] "mtarjeta_master_descuentos_lag6"
#  [675] "ccomisiones_mantenimiento_lag6"
#  [676] "mcomisiones_mantenimiento_lag6"
#  [677] "ccomisiones_otras_lag6"
#  [678] "mcomisiones_otras_lag6"
#  [679] "cforex_lag6"
#  [680] "cforex_buy_lag6"
#  [681] "mforex_buy_lag6"
#  [682] "cforex_sell_lag6"
#  [683] "mforex_sell_lag6"
#  [684] "ctransferencias_recibidas_lag6"
#  [685] "mtransferencias_recibidas_lag6"
#  [686] "ctransferencias_emitidas_lag6"
#  [687] "mtransferencias_emitidas_lag6"
#  [688] "cextraccion_autoservicio_lag6"
#  [689] "mextraccion_autoservicio_lag6"
#  [690] "ccheques_depositados_lag6"
#  [691] "mcheques_depositados_lag6"
#  [692] "ccheques_emitidos_lag6"
#  [693] "mcheques_emitidos_lag6"
#  [694] "ccheques_depositados_rechazados_lag6"
#  [695] "mcheques_depositados_rechazados_lag6"
#  [696] "ccheques_emitidos_rechazados_lag6"
#  [697] "mcheques_emitidos_rechazados_lag6"
#  [698] "tcallcenter_lag6"
#  [699] "ccallcenter_transacciones_lag6"
#  [700] "thomebanking_lag6"
#  [701] "chomebanking_transacciones_lag6"
#  [702] "ccajas_transacciones_lag6"
#  [703] "ccajas_consultas_lag6"
#  [704] "ccajas_depositos_lag6"
#  [705] "ccajas_extracciones_lag6"
#  [706] "ccajas_otras_lag6"
#  [707] "catm_trx_lag6"
#  [708] "matm_lag6"
#  [709] "catm_trx_other_lag6"
#  [710] "matm_other_lag6"
#  [711] "ctrx_quarter_lag6"
#  [712] "tmobile_app_lag6"
#  [713] "cmobile_app_trx_lag6"
#  [714] "Master_delinquency_lag6"
#  [715] "Master_status_lag6"
#  [716] "Master_Fvencimiento_lag6"
#  [717] "Master_Finiciomora_lag6"
#  [718] "Master_msaldototal_lag6"
#  [719] "Master_msaldopesos_lag6"
#  [720] "Master_msaldodolares_lag6"
#  [721] "Master_mconsumospesos_lag6"
#  [722] "Master_mconsumosdolares_lag6"
#  [723] "Master_mlimitecompra_lag6"
#  [724] "Master_madelantopesos_lag6"
#  [725] "Master_madelantodolares_lag6"
#  [726] "Master_fultimo_cierre_lag6"
#  [727] "Master_mpagado_lag6"
#  [728] "Master_mpagospesos_lag6"
#  [729] "Master_mpagosdolares_lag6"
#  [730] "Master_fechaalta_lag6"
#  [731] "Master_mconsumototal_lag6"
#  [732] "Master_cconsumos_lag6"
#  [733] "Master_cadelantosefectivo_lag6"
#  [734] "Master_mpagominimo_lag6"
#  [735] "Visa_delinquency_lag6"
#  [736] "Visa_status_lag6"
#  [737] "Visa_Fvencimiento_lag6"
#  [738] "Visa_Finiciomora_lag6"
#  [739] "Visa_msaldototal_lag6"
#  [740] "Visa_msaldopesos_lag6"
#  [741] "Visa_msaldodolares_lag6"
#  [742] "Visa_mconsumospesos_lag6"
#  [743] "Visa_mconsumosdolares_lag6"
#  [744] "Visa_mlimitecompra_lag6"
#  [745] "Visa_madelantopesos_lag6"
#  [746] "Visa_madelantodolares_lag6"
#  [747] "Visa_fultimo_cierre_lag6"
#  [748] "Visa_mpagado_lag6"
#  [749] "Visa_mpagospesos_lag6"
#  [750] "Visa_mpagosdolares_lag6"
#  [751] "Visa_fechaalta_lag6"
#  [752] "Visa_mconsumototal_lag6"
#  [753] "Visa_cconsumos_lag6"
#  [754] "Visa_cadelantosefectivo_lag6"
#  [755] "Visa_mpagominimo_lag6"
#  [756] "kmes_lag6"
#  [757] "ctrx_quarter_normalizado_lag6"
#  [758] "mpayroll_sobre_edad_lag6"
#  [759] "active_quarter_lag12"
#  [760] "cliente_vip_lag12"
#  [761] "internet_lag12"
#  [762] "cliente_edad_lag12"
#  [763] "cliente_antiguedad_lag12"
#  [764] "mrentabilidad_lag12"
#  [765] "mrentabilidad_annual_lag12"
#  [766] "mcomisiones_lag12"
#  [767] "mactivos_margen_lag12"
#  [768] "mpasivos_margen_lag12"
#  [769] "cproductos_lag12"
#  [770] "tcuentas_lag12"
#  [771] "ccuenta_corriente_lag12"
#  [772] "mcuenta_corriente_adicional_lag12"
#  [773] "mcuenta_corriente_lag12"
#  [774] "ccaja_ahorro_lag12"
#  [775] "mcaja_ahorro_lag12"
#  [776] "mcaja_ahorro_adicional_lag12"
#  [777] "mcaja_ahorro_dolares_lag12"
#  [778] "cdescubierto_preacordado_lag12"
#  [779] "mcuentas_saldo_lag12"
#  [780] "ctarjeta_debito_lag12"
#  [781] "ctarjeta_debito_transacciones_lag12"
#  [782] "mautoservicio_lag12"
#  [783] "ctarjeta_visa_lag12"
#  [784] "ctarjeta_visa_transacciones_lag12"
#  [785] "mtarjeta_visa_consumo_lag12"
#  [786] "ctarjeta_master_lag12"
#  [787] "ctarjeta_master_transacciones_lag12"
#  [788] "mtarjeta_master_consumo_lag12"
#  [789] "cprestamos_prendarios_lag12"
#  [790] "mprestamos_prendarios_lag12"
#  [791] "cprestamos_hipotecarios_lag12"
#  [792] "mprestamos_hipotecarios_lag12"
#  [793] "cplazo_fijo_lag12"
#  [794] "mplazo_fijo_dolares_lag12"
#  [795] "mplazo_fijo_pesos_lag12"
#  [796] "cinversion1_lag12"
#  [797] "minversion1_pesos_lag12"
#  [798] "minversion1_dolares_lag12"
#  [799] "cinversion2_lag12"
#  [800] "minversion2_lag12"
#  [801] "cseguro_vida_lag12"
#  [802] "cseguro_auto_lag12"
#  [803] "cseguro_vivienda_lag12"
#  [804] "cseguro_accidentes_personales_lag12"
#  [805] "ccaja_seguridad_lag12"
#  [806] "cpayroll_trx_lag12"
#  [807] "mpayroll_lag12"
#  [808] "mpayroll2_lag12"
#  [809] "cpayroll2_trx_lag12"
#  [810] "ccuenta_debitos_automaticos_lag12"
#  [811] "mcuenta_debitos_automaticos_lag12"
#  [812] "ctarjeta_visa_debitos_automaticos_lag12"
#  [813] "mttarjeta_visa_debitos_automaticos_lag12"
#  [814] "ctarjeta_master_debitos_automaticos_lag12"
#  [815] "mttarjeta_master_debitos_automaticos_lag12"
#  [816] "cpagodeservicios_lag12"
#  [817] "mpagodeservicios_lag12"
#  [818] "cpagomiscuentas_lag12"
#  [819] "mpagomiscuentas_lag12"
#  [820] "ccajeros_propios_descuentos_lag12"
#  [821] "mcajeros_propios_descuentos_lag12"
#  [822] "ctarjeta_visa_descuentos_lag12"
#  [823] "mtarjeta_visa_descuentos_lag12"
#  [824] "ctarjeta_master_descuentos_lag12"
#  [825] "mtarjeta_master_descuentos_lag12"
#  [826] "ccomisiones_mantenimiento_lag12"
#  [827] "mcomisiones_mantenimiento_lag12"
#  [828] "ccomisiones_otras_lag12"
#  [829] "mcomisiones_otras_lag12"
#  [830] "cforex_lag12"
#  [831] "cforex_buy_lag12"
#  [832] "mforex_buy_lag12"
#  [833] "cforex_sell_lag12"
#  [834] "mforex_sell_lag12"
#  [835] "ctransferencias_recibidas_lag12"
#  [836] "mtransferencias_recibidas_lag12"
#  [837] "ctransferencias_emitidas_lag12"
#  [838] "mtransferencias_emitidas_lag12"
#  [839] "cextraccion_autoservicio_lag12"
#  [840] "mextraccion_autoservicio_lag12"
#  [841] "ccheques_depositados_lag12"
#  [842] "mcheques_depositados_lag12"
#  [843] "ccheques_emitidos_lag12"
#  [844] "mcheques_emitidos_lag12"
#  [845] "ccheques_depositados_rechazados_lag12"
#  [846] "mcheques_depositados_rechazados_lag12"
#  [847] "ccheques_emitidos_rechazados_lag12"
#  [848] "mcheques_emitidos_rechazados_lag12"
#  [849] "tcallcenter_lag12"
#  [850] "ccallcenter_transacciones_lag12"
#  [851] "thomebanking_lag12"
#  [852] "chomebanking_transacciones_lag12"
#  [853] "ccajas_transacciones_lag12"
#  [854] "ccajas_consultas_lag12"
#  [855] "ccajas_depositos_lag12"
#  [856] "ccajas_extracciones_lag12"
# ...
# [1762] "mpayroll_ratioavg6"
# [1763] "mpayroll2_avg6"
# [1764] "mpayroll2_ratioavg6"
# [1765] "cpayroll2_trx_avg6"
# [1766] "cpayroll2_trx_ratioavg6"
# [1767] "ccuenta_debitos_automaticos_avg6"
# [1768] "ccuenta_debitos_automaticos_ratioavg6"
# [1769] "mcuenta_debitos_automaticos_avg6"
# [1770] "mcuenta_debitos_automaticos_ratioavg6"
# [1771] "ctarjeta_visa_debitos_automaticos_avg6"
# [1772] "ctarjeta_visa_debitos_automaticos_ratioavg6"
# [1773] "mttarjeta_visa_debitos_automaticos_avg6"
# [1774] "mttarjeta_visa_debitos_automaticos_ratioavg6"
# [1775] "ctarjeta_master_debitos_automaticos_avg6"
# [1776] "ctarjeta_master_debitos_automaticos_ratioavg6"
# [1777] "mttarjeta_master_debitos_automaticos_avg6"
# [1778] "mttarjeta_master_debitos_automaticos_ratioavg6"
# [1779] "cpagodeservicios_avg6"
# [1780] "cpagodeservicios_ratioavg6"
# [1781] "mpagodeservicios_avg6"
# [1782] "mpagodeservicios_ratioavg6"
# [1783] "cpagomiscuentas_avg6"
# [1784] "cpagomiscuentas_ratioavg6"
# [1785] "mpagomiscuentas_avg6"
# [1786] "mpagomiscuentas_ratioavg6"
# [1787] "ccajeros_propios_descuentos_avg6"
# [1788] "ccajeros_propios_descuentos_ratioavg6"
# [1789] "mcajeros_propios_descuentos_avg6"
# [1790] "mcajeros_propios_descuentos_ratioavg6"
# [1791] "ctarjeta_visa_descuentos_avg6"
# [1792] "ctarjeta_visa_descuentos_ratioavg6"
# [1793] "mtarjeta_visa_descuentos_avg6"
# [1794] "mtarjeta_visa_descuentos_ratioavg6"
# [1795] "ctarjeta_master_descuentos_avg6"
# [1796] "ctarjeta_master_descuentos_ratioavg6"
# [1797] "mtarjeta_master_descuentos_avg6"
# [1798] "mtarjeta_master_descuentos_ratioavg6"
# [1799] "ccomisiones_mantenimiento_avg6"
# [1800] "ccomisiones_mantenimiento_ratioavg6"
# [1801] "mcomisiones_mantenimiento_avg6"
# [1802] "mcomisiones_mantenimiento_ratioavg6"
# [1803] "ccomisiones_otras_avg6"
# [1804] "ccomisiones_otras_ratioavg6"
# [1805] "mcomisiones_otras_avg6"
# [1806] "mcomisiones_otras_ratioavg6"
# [1807] "cforex_avg6"
# [1808] "cforex_ratioavg6"
# [1809] "cforex_buy_avg6"
# [1810] "cforex_buy_ratioavg6"
# [1811] "mforex_buy_avg6"
# [1812] "mforex_buy_ratioavg6"
# [1813] "cforex_sell_avg6"
# [1814] "cforex_sell_ratioavg6"
# [1815] "mforex_sell_avg6"
# [1816] "mforex_sell_ratioavg6"
# [1817] "ctransferencias_recibidas_avg6"
# [1818] "ctransferencias_recibidas_ratioavg6"
# [1819] "mtransferencias_recibidas_avg6"
# [1820] "mtransferencias_recibidas_ratioavg6"
# [1821] "ctransferencias_emitidas_avg6"
# [1822] "ctransferencias_emitidas_ratioavg6"
# [1823] "mtransferencias_emitidas_avg6"
# [1824] "mtransferencias_emitidas_ratioavg6"
# [1825] "cextraccion_autoservicio_avg6"
# [1826] "cextraccion_autoservicio_ratioavg6"
# [1827] "mextraccion_autoservicio_avg6"
# [1828] "mextraccion_autoservicio_ratioavg6"
# [1829] "ccheques_depositados_avg6"
# [1830] "ccheques_depositados_ratioavg6"
# [1831] "mcheques_depositados_avg6"
# [1832] "mcheques_depositados_ratioavg6"
# [1833] "ccheques_emitidos_avg6"
# [1834] "ccheques_emitidos_ratioavg6"
# [1835] "mcheques_emitidos_avg6"
# [1836] "mcheques_emitidos_ratioavg6"
# [1837] "ccheques_depositados_rechazados_avg6"
# [1838] "ccheques_depositados_rechazados_ratioavg6"
# [1839] "mcheques_depositados_rechazados_avg6"
# [1840] "mcheques_depositados_rechazados_ratioavg6"
# [1841] "ccheques_emitidos_rechazados_avg6"
# [1842] "ccheques_emitidos_rechazados_ratioavg6"
# [1843] "mcheques_emitidos_rechazados_avg6"
# [1844] "mcheques_emitidos_rechazados_ratioavg6"
# [1845] "tcallcenter_avg6"
# [1846] "tcallcenter_ratioavg6"
# [1847] "ccallcenter_transacciones_avg6"
# [1848] "ccallcenter_transacciones_ratioavg6"
# [1849] "thomebanking_avg6"
# [1850] "thomebanking_ratioavg6"
# [1851] "chomebanking_transacciones_avg6"
# [1852] "chomebanking_transacciones_ratioavg6"
# [1853] "ccajas_transacciones_avg6"
# [1854] "ccajas_transacciones_ratioavg6"
# [1855] "ccajas_consultas_avg6"
# [1856] "ccajas_consultas_ratioavg6"
# [1857] "ccajas_depositos_avg6"
# [1858] "ccajas_depositos_ratioavg6"
# [1859] "ccajas_extracciones_avg6"
# [1860] "ccajas_extracciones_ratioavg6"
# [1861] "ccajas_otras_avg6"
# [1862] "ccajas_otras_ratioavg6"
# [1863] "catm_trx_avg6"
# [1864] "catm_trx_ratioavg6"
# [1865] "matm_avg6"
# [1866] "matm_ratioavg6"
# [1867] "catm_trx_other_avg6"
# [1868] "catm_trx_other_ratioavg6"
# [1869] "matm_other_avg6"
# [1870] "matm_other_ratioavg6"
# [1871] "ctrx_quarter_avg6"
# [1872] "ctrx_quarter_ratioavg6"
# [1873] "tmobile_app_avg6"
# [1874] "tmobile_app_ratioavg6"
# [1875] "cmobile_app_trx_avg6"
# [1876] "cmobile_app_trx_ratioavg6"
# [1877] "Master_delinquency_avg6"
# [1878] "Master_delinquency_ratioavg6"
# [1879] "Master_status_avg6"
# [1880] "Master_status_ratioavg6"
# [1881] "Master_Fvencimiento_avg6"
# [1882] "Master_Fvencimiento_ratioavg6"
# [1883] "Master_Finiciomora_avg6"
# [1884] "Master_Finiciomora_ratioavg6"
# [1885] "Master_msaldototal_avg6"
# [1886] "Master_msaldototal_ratioavg6"
# [1887] "Master_msaldopesos_avg6"
# [1888] "Master_msaldopesos_ratioavg6"
# [1889] "Master_msaldodolares_avg6"
# [1890] "Master_msaldodolares_ratioavg6"
# [1891] "Master_mconsumospesos_avg6"
# [1892] "Master_mconsumospesos_ratioavg6"
# [1893] "Master_mconsumosdolares_avg6"
# [1894] "Master_mconsumosdolares_ratioavg6"
# [1895] "Master_mlimitecompra_avg6"
# [1896] "Master_mlimitecompra_ratioavg6"
# [1897] "Master_madelantopesos_avg6"
# [1898] "Master_madelantopesos_ratioavg6"
# [1899] "Master_madelantodolares_avg6"
# [1900] "Master_madelantodolares_ratioavg6"
# [1901] "Master_fultimo_cierre_avg6"
# [1902] "Master_fultimo_cierre_ratioavg6"
# [1903] "Master_mpagado_avg6"
# [1904] "Master_mpagado_ratioavg6"
# [1905] "Master_mpagospesos_avg6"
# [1906] "Master_mpagospesos_ratioavg6"
# [1907] "Master_mpagosdolares_avg6"
# [1908] "Master_mpagosdolares_ratioavg6"
# [1909] "Master_fechaalta_avg6"
# [1910] "Master_fechaalta_ratioavg6"
# [1911] "Master_mconsumototal_avg6"
# [1912] "Master_mconsumototal_ratioavg6"
# [1913] "Master_cconsumos_avg6"
# [1914] "Master_cconsumos_ratioavg6"
# [1915] "Master_cadelantosefectivo_avg6"
# [1916] "Master_cadelantosefectivo_ratioavg6"
# [1917] "Master_mpagominimo_avg6"
# [1918] "Master_mpagominimo_ratioavg6"
# [1919] "Visa_delinquency_avg6"
# [1920] "Visa_delinquency_ratioavg6"
# [1921] "Visa_status_avg6"
# [1922] "Visa_status_ratioavg6"
# [1923] "Visa_Fvencimiento_avg6"
# [1924] "Visa_Fvencimiento_ratioavg6"
# [1925] "Visa_Finiciomora_avg6"
# [1926] "Visa_Finiciomora_ratioavg6"
# [1927] "Visa_msaldototal_avg6"
# [1928] "Visa_msaldototal_ratioavg6"
# [1929] "Visa_msaldopesos_avg6"
# [1930] "Visa_msaldopesos_ratioavg6"
# [1931] "Visa_msaldodolares_avg6"
# [1932] "Visa_msaldodolares_ratioavg6"
# [1933] "Visa_mconsumospesos_avg6"
# [1934] "Visa_mconsumospesos_ratioavg6"
# [1935] "Visa_mconsumosdolares_avg6"
# [1936] "Visa_mconsumosdolares_ratioavg6"
# [1937] "Visa_mlimitecompra_avg6"
# [1938] "Visa_mlimitecompra_ratioavg6"
# [1939] "Visa_madelantopesos_avg6"
# [1940] "Visa_madelantopesos_ratioavg6"
# [1941] "Visa_madelantodolares_avg6"
# [1942] "Visa_madelantodolares_ratioavg6"
# [1943] "Visa_fultimo_cierre_avg6"
# [1944] "Visa_fultimo_cierre_ratioavg6"
# [1945] "Visa_mpagado_avg6"
# [1946] "Visa_mpagado_ratioavg6"
# [1947] "Visa_mpagospesos_avg6"
# [1948] "Visa_mpagospesos_ratioavg6"
# [1949] "Visa_mpagosdolares_avg6"
# [1950] "Visa_mpagosdolares_ratioavg6"
# [1951] "Visa_fechaalta_avg6"
# [1952] "Visa_fechaalta_ratioavg6"
# [1953] "Visa_mconsumototal_avg6"
# [1954] "Visa_mconsumototal_ratioavg6"
# [1955] "Visa_cconsumos_avg6"
# [1956] "Visa_cconsumos_ratioavg6"
# [1957] "Visa_cadelantosefectivo_avg6"
# [1958] "Visa_cadelantosefectivo_ratioavg6"
# [1959] "Visa_mpagominimo_avg6"
# [1960] "Visa_mpagominimo_ratioavg6"
# [1961] "kmes_avg6"
# [1962] "kmes_ratioavg6"
# [1963] "ctrx_quarter_normalizado_avg6"
# [1964] "ctrx_quarter_normalizado_ratioavg6"
# [1965] "mpayroll_sobre_edad_avg6"
# [1966] "mpayroll_sobre_edad_ratioavg6"
# [1967] "entrenamiento"
# [1968] "rf_001_001"
# [1969] "rf_001_002"
# [1970] "rf_002_001"
# [1971] "rf_002_000"
# [1972] "rf_002_002"
# [1973] "rf_003_003"
# [1974] "rf_003_001"
# [1975] "rf_004_001"
# [1976] "rf_004_002"
# [1977] "rf_005_001"
# [1978] "rf_006_001"
# [1979] "rf_007_003"
# [1980] "rf_007_001"
# [1981] "rf_008_001"
# [1982] "rf_009_001"
# [1983] "rf_010_001"
# [1984] "rf_011_003"
# [1985] "rf_011_001"
# [1986] "rf_011_000"
# [1987] "rf_011_002"
# [1988] "rf_012_003"
# [1989] "rf_012_001"
# [1990] "rf_013_001"
# [1991] "rf_013_000"
# [1992] "rf_013_002"
# [1993] "rf_014_001"
# [1994] "rf_015_003"
# [1995] "rf_015_000"
# [1996] "rf_015_002"
# [1997] "rf_016_001"
# [1998] "rf_017_001"
# [1999] "rf_017_002"
# [2000] "rf_018_003"
# [2001] "rf_018_001"
# [2002] "rf_019_001"
# [2003] "rf_020_001"
# [2004] "rf_020_000"
# [2005] "rf_020_002"
# [2006] "rf_001_003"
# [2007] "rf_002_003"
# [2008] "rf_003_000"
# [2009] "rf_003_002"
# [2010] "rf_005_002"
# [2011] "rf_005_000"
# [2012] "rf_005_003"
# [2013] "rf_006_002"
# [2014] "rf_006_003"
# [2015] "rf_007_000"
# [2016] "rf_007_002"
# [2017] "rf_008_002"
# [2018] "rf_010_002"
# [2019] "rf_010_003"
# [2020] "rf_014_000"
# [2021] "rf_014_002"
# [2022] "rf_015_001"
# [2023] "rf_016_002"
# [2024] "rf_018_002"
# [2025] "rf_019_002"
# [2026] "rf_019_000"
# [2027] "rf_020_003"
# [2028] "rf_012_002"
# [2029] "rf_013_003"
# [2030] "rf_014_003"
# [2031] "rf_016_003"
# [2032] "rf_016_000"
# [2033] "rf_017_003"
# [2034] "rf_019_003"
# [2035] "rf_004_003"
# [2036] "rf_010_000"
# [2037] "rf_006_000"
# [2038] "rf_008_000"
# [2039] "rf_008_003"
# [2040] "rf_009_002"
# [2041] "rf_009_000"
# [2042] "rf_009_003"
# [2043] "rf_001_000"
# [2044] "rf_004_000"
# [2045] "rf_012_000"
# [2046] "rf_017_000"
# [2047] "rf_018_000"

# %% [markdown]
# ## Modelado

# %% [markdown]
# No hay modelado, no se hace optimizacion de hiperparametros.

# %% [markdown]
# ## Produccion

# %% [markdown]
# Las decisiones que se toman para la construccion del modelo final son:
# * Los positvos son  POS={"BAJA+1", "BAJA+2"}, esta es una meticulosa decisión.
# * Se entrena en los treinta meses del intervalo [201901, 202104]
# * Se realiza undersampling al 5%
# * Se utilizan los hiperparámetros optimos encontrados en la Bayesian Optimization
#    * Se escala min_data_in_leaf

# %% [markdown]
# ### Final Training Strategy

# %%
PARAM$train_final$future <- c(202109)

PARAM$train_final$training <- c(
  201901, 201902, 201903, 201904, 201905, 201906,
  201907, 201908, 201909, 201910, 201911, 201912,
  202001, 202002, 202003, 202004, 202005,
  202007, 202008, 202009, 202010, 202011, 202012,
  202101, 202102, 202103, 202104, 202105, 202106, 202107
)

PARAM$train_final$undersampling <- 0.05

# %%
# se filtran los meses donde se entrena el modelo final
dataset_train_final <- dataset[foto_mes %in% PARAM$train_final$training]

# %% [markdown]
# Weight

# %%
# Función auxiliar para convertir foto_mes (YYYYMM) a periodo entero (P)
to_periodo <- function(fm) as.integer(fm / 100) * 12 + fm %% 100 # 

# 1. Identificar el periodo máximo de entrenamiento (el mes más reciente)
ultimo_mes_train <- max(PARAM$train_final$training) 
periodo_max <- to_periodo(ultimo_mes_train)

# 2. Calcular la antiguedad (0 para el mes actual, 1 para el anterior, etc.)
decaimiento <- plocal$decaimiento
dataset_train_final[, periodo_actual := to_periodo(foto_mes)]
dataset_train_final[, antiguedad := periodo_max - periodo_actual]
dataset_train_final[, row_weight := decaimiento^antiguedad] # <--- El peso decae exponencialmente
dataset_train_final[, c("periodo_actual", "antiguedad") := NULL]

# %%
# canaritos
PARAM$train_final$lgbm$qcanaritos <- plocal$qcanaritos

cols0 <- copy(colnames(dataset_train_final))
filas <- nrow(dataset_train_final)

# 1. Fijar la semilla justo antes de generar canaritos
set.seed( PARAM$semilla_primigenia ) 

# 2. Creación de canaritos (Ahora reproducible)
if( PARAM$train_final$lgbm$qcanaritos > 0 ) {
  for( i in seq(PARAM$train_final$lgbm$qcanaritos) ){
    dataset_train_final[, paste0("canarito_",i) := runif( filas) ]
  }

  # las columnas canaritos mandatoriamente van al comienzo del dataset
  cols_canaritos <- copy( setdiff( colnames(dataset_train_final), cols0 ) )
  setcolorder( dataset_train_final, c( cols_canaritos, cols0 ) )
}

Sys.time()
# Out:
# [1] "2025-12-03 14:58:48 UTC"

# %% [markdown]
# #### Registros cambio las proporciones de POS/NEG

# %%
# Undersampling, van todos los "BAJA+1" y "BAJA+2" y solo algunos "CONTINIA"

set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset_train_final[, azar := runif(nrow(dataset_train_final))]
dataset_train_final[, training := 0L]

dataset_train_final[
  (azar <= PARAM$train_final$undersampling | clase_ternaria %in% c("BAJA+1", "BAJA+2")),
  training := 1L
]

dataset_train_final[, azar:= NULL] # elimino la columna azar

# %% [markdown]
# ### Target Engineering

# %%
# paso la clase a binaria que tome valores {0,1}  enteros
#  BAJA+1 y BAJA+2  son  1,   CONTINUA es 0
#  a partir de ahora ya NO puedo cortar  por prob(BAJA+2) > 1/40

dataset_train_final[,
  clase01 := ifelse(clase_ternaria %in% c("BAJA+2","BAJA+1"), 1L, 0L)
]

# %% [markdown]
# ### Final Models

# %% [markdown]
# Aqui SIEMPRE voy a hacer un semillerio, independientemente de si en la Bayesian Optimization calculé un semillerio en cada iteración.
# <br> Entreno un LightGBM para cada semilla,  y guardo el modelo dentro de la carpeta  **modelitos**
# <br> Intencionalmente en una primera etapá se generan los modelos y graban, y en una segunda etapa se leen eso modelos y se aplican a los datos del futuro

# %% [markdown]
# APO controla cuantas veces se repite el modelo, que se usa para promediar ganancias y reportar en la Pseudo Competencia algo razonable
# <br> El modelo puede ser un LightGBM simple (ksemillerio==1)  o un Ensemble Semillerio( ksemillerio > 1 )
# <br> Lamentablmente APO necesita utilizar muchas semillas, y eso demanda TIEMPO de corrida

# %%
PARAM$train_final$lgbm$param_completo <-  list(
  boosting= "gbdt",
  objective= "binary",
  metric= "custom",
  first_metric_only= FALSE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  force_row_wise= TRUE,
  verbosity= -100,

  seed= PARAM$semilla_primigenia,

  max_bin= 31L,
  min_data_in_leaf= plocal$min_data_in_leaf,  #este ya es el valor default de LightGBM

  num_iterations= 64L, # dejo libre la cantidad de arboles, zLightGBM se detiene solo
  num_leaves= 9999L, # dejo libre la cantidad de hojas, zLightGBM sabe cuando no hacer un split
  learning_rate= plocal$learning_rate,  # se lo deja en 1.0 para que si el score esta por debajo de gradient_bound no se lo escale

  feature_fraction= 0.50, # un valor equilibrado, habra que probar alternativas ...

  canaritos= PARAM$train_final$lgbm$qcanaritos, # fundamental en zLightGBM, aqui esta el control del overfitting
  gradient_bound= plocal$gradient_bound   # default de zLightGBM
)

Sys.time()
# Out:
# [1] "2025-12-03 14:58:48 UTC"

# %%
# Semillerio Final
PARAM$train_final$APO <- plocal$APO
PARAM$train_final$ksemillerio  <- plocal$ksemillerio

PARAM$train_final$cortes <- c(8000, 8500, 9000, 9500, 10000, 10500, 11000, 11500, 12000)

# %%
# detach("package:lightgbm", unload= TRUE)

# %%
if( !require("zlightgbm") ) install.packages("https://storage.googleapis.com/open-courses/dmeyf2025-e4a2/zlightgbm_4.6.0.99.tar.gz", repos= NULL, type= "source")
require("zlightgbm")
# Out:
# Loading required package: zlightgbm
#
# Registered S3 methods overwritten by 'zlightgbm':
#   method                 from
#   dimnames<-.lgb.Dataset lightgbm
#   dim.lgb.Dataset        lightgbm
#   dimnames.lgb.Dataset   lightgbm
#   predict.lgb.Booster    lightgbm
#   print.lgb.Booster      lightgbm
#   summary.lgb.Booster    lightgbm
#
#
# Attaching package: ‘zlightgbm’
#
#
# The following objects are masked from ‘package:lightgbm’:
#
#     get_field, getLGBMthreads, lgb.configure_fast_predict,
#     lgb.convert_with_rules, lgb.cv, lgb.Dataset, lgb.Dataset.construct,
#     lgb.Dataset.create.valid, lgb.Dataset.save,
#     lgb.Dataset.set.categorical, lgb.Dataset.set.reference,
#     lgb.drop_serialized, lgb.dump, lgb.get.eval.result, lgb.importance,
#     lgb.interprete, lgb.load, lgb.make_serializable, lgb.model.dt.tree,
#     lgb.plot.importance, lgb.plot.interpretation, lgb.restore_handle,
#     lgb.save, lgb.slice.Dataset, lgb.train, lightgbm, set_field,
#     setLGBMthreads

# %%
if(!require("primes")) install.packages("primes")
require("primes")
# Out:
# Loading required package: primes

# %%
primos <- generate_primes(min = 100000, max = 1000000)
set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
PARAM$train_final$semillas <- sample(primos)[seq( PARAM$train_final$APO*PARAM$train_final$ksemillerio )]
PARAM$train_final$semillas
# Out:
#   [1] 696323 757751 538397 735733 585019 278819 571381 121063 143357 503233
#  [11] 261523 607363 250643 941099 908419 231947 442979 229423 320329 252173
#  [21] 420569 389029 202667 842419 393103 326063 582299 517277 861797 402487
#  [31] 703499 982117 175781 619687 815671 835909 918647 280541 641101 167627
#  [41] 621871 262543 210131 280939 811123 555257 575651 629341 595201 316493
#  [51] 923599 853211 285629 522569 533543 854149 733189 196991 794741 647963
#  [61] 198977 750917 769789 240319 307669 787187 467063 947707 919769 340369
#  [71] 268123 811897 503543 136559 887533 199151 464003 131543 330661 888361
#  [81] 754973 567569 511289 845921 831167 599629 106013 536423 370883 140221
#  [91] 682511 207517 481417 956569 786061 511591 881351 327251 163193 253907

# %%
# Excluimos la columna 'row_weight' para que no sea usada como feature
campos_buenos <- setdiff( colnames(dataset_train_final), c( "clase_ternaria", "clase01", "training", "azar", "row_weight") )

# %%
# Extraemos el vector de pesos antes de crear el dataset
vector_pesos <- dataset_train_final[training == 1L, row_weight]

# %%
# dejo los datos en formato LightGBM
dtrain_final <- lgb.Dataset(
  data= data.matrix(dataset_train_final[training == 1L, campos_buenos, with= FALSE]),
  label= dataset_train_final[training == 1L, clase01],
  weight= vector_pesos, # <-- Aplicación del weight
  free_raw_data= FALSE
)
dataset_train_final[, row_weight := NULL] # <-- Limpieza de la columna weight

cat("filas", nrow(dtrain_final), "columnas", ncol(dtrain_final), "\n")
Sys.time()
# Out:
# filas 258280 columnas 2051
# [1] "2025-12-03 14:58:57 UTC"

# %%
# genero los modelitos
dir.create( "modelitos", showWarnings= FALSE)

param_completo <- copy( PARAM$train_final$lgbm$param_completo)

for( sem in PARAM$train_final$semillas ) {

  arch_modelo <- paste0("./modelitos/mod_", sem, ".txt")
  if( !file.exists( arch_modelo ) )
  {
    param_completo$seed <- sem

    modelito <- lgb.train(
      data= dtrain_final,
      param= param_completo
    )

    lgb.save( modelito, filename= arch_modelo)
    rm(modelito)
    gc()
  }
}

Sys.time()
# Out:
# [1] "2025-12-03 16:52:08 UTC"

# %% [markdown]
# ### Scoring

# %% [markdown]
# Se hace el predict() del modelo en los datos del futuro

# %%
dfuture <- dataset[foto_mes %in% PARAM$train_final$future ]

cols0 <- copy(colnames(dfuture))
filas <- nrow(dfuture)

if( PARAM$train_final$lgbm$qcanaritos > 0 ) {
  for( i in seq(PARAM$train_final$lgbm$qcanaritos) ){
    dfuture[, paste0("canarito_",i) := runif( filas) ]
  }

  # las columnas canaritos mandatoriamente van al comienzo del dataset
  cols_canaritos <- copy( setdiff( colnames(dfuture), cols0 ) )
  setcolorder( dfuture, c( cols_canaritos, cols0 ) )
}

# %%
# dataset de future, donde en este caso estoy haciendo testing

mfuture <- data.matrix(dfuture[, campos_buenos, with= FALSE])

dfuture[, ganancia := ifelse(clase_ternaria=="BAJA+2", 780000, -20000)]

# %%
# mganancias <- matrix( nrow=PARAM$train_final$APO, ncol= length(PARAM$train_final$cortes) )

if( file.exists("prediccion.txt") )
  file.remove("prediccion.txt")

# %%
# aplico el modelo a los datos del future

for( vapo in seq(PARAM$train_final$APO) ) {
  # inicializacion en CERO
  vpred_acum <- rep(0.0, nrow(dfuture))
  qacumulados <- 0

  desde <- 1 + (vapo-1)*PARAM$train_final$ksemillerio
  hasta <- desde + PARAM$train_final$ksemillerio - 1
  semillas <- PARAM$train_final$semillas[desde:hasta]

  for( sem in semillas ) {

    arch_modelo <- paste0("./modelitos/mod_", sem, ".txt")
    if( file.exists( arch_modelo ) )
    {
      modelo_final <- lgb.load(arch_modelo) # leo del disco
      # hago el predict() y acumulo
      vpred_acum <- vpred_acum + predict(modelo_final, mfuture)
      qacumulados <- qacumulados + 1
      rm(modelo_final)
      gc()
    }
  }

  if( qacumulados > 0 ) {
    vpred_acum <- vpred_acum / qacumulados  # paso a probabildiad
    # tabla de prediccion, puede ser util para futuros ensembles
    #  ya que le modelo ganador va a ser un ensemble de LightGBMs

    tb_prediccion <- dfuture[, list(numero_de_cliente, foto_mes, ganancia)]
    tb_prediccion[, meta_modelo := vapo]
    tb_prediccion[, prob := vpred_acum ]
    setorder( tb_prediccion, -prob )
    # tb_prediccion[, gan_acum := cumsum(ganancia)]
    # tb_prediccion[, ganancia := NULL ]

    # # acumulo las ganancias
    # for( icor in seq(length(PARAM$train_final$cortes)) ){
    #   mganancias[ vapo, icor ] <- tb_prediccion[ PARAM$train_final$cortes[icor], gan_acum ]
    # }

    # grabo las probabilidades del modelo
    fwrite(tb_prediccion,
      file= "prediccion.txt",
      sep= "\t",
      append= TRUE
    )

    rm(tb_prediccion)
    gc()
  }
}

Sys.time()
# Out:
# [1] "2025-12-03 16:57:13 UTC"

# %%
Sys.time()
# Out:
# [1] "2025-12-03 16:57:13 UTC"
