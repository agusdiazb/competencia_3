# %% [markdown]
# # Wokflow  **TEST** con Full Bayesiana

# %% [markdown]
# ## Inicializacion

# %%
# limpio la memoria
Sys.time()
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
# [1] "2025-11-30 22:02:02 UTC"
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  658715 35.2 1454567    77.7 1233617  65.9
# Vcells 1222625  9.4 8388608    64.0 1975163  15.1

# %%
plocal <- list()

plocal$qcanaritos <- 5L
plocal$min_data_in_leaf <- 200L
plocal$learning_rate <- 1.0
plocal$gradient_bound <- 0.4

plocal$APO <- 5
plocal$ksemillerio <- 100

plocal$decaimiento <- 0.95 # <-- Parámetro de decaimiento
deflactor <- "IPC" # IPC , IPIM, UVA, ripte_indice, TC_BLUE, TC_OFICIAL, TCRM, tasa_i, tasa_r

# %%
PARAM <- list()
PARAM$experimento <- "FINAL-202109"
PARAM$semilla_primigenia <- 990013 # <-- tu semilla favorita

# %%
setwd("/content/buckets/b1/exp")
experimento_folder <- PARAM$experimento
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %% [markdown]
# ## Preprocesamiento

# %% [markdown]
# ### Generacion de la clase_ternaria

# %%
Sys.time()
require( "data.table" )

# leo el dataset
dataset <- fread("~/datasets/competencia_02_crudo.csv.gz" )

dataset_nuevo_mes <- fread("~/datasets/competencia_03_crudo.csv.gz" )

# Unimos el nuevo mes (202109) al dataset existente
dataset <- rbindlist(list(dataset, dataset_nuevo_mes), use.names=TRUE, fill=TRUE)

# Eliminamos la tabla temporal para liberar memoria
rm(dataset_nuevo_mes)
gc()

# calculo el periodo0 consecutivo
dsimple <- dataset[, list(
  "pos" = .I,
  numero_de_cliente,
  periodo0 = as.integer(foto_mes/100)*12 +  foto_mes%%100 )
]


# ordeno
setorder( dsimple, numero_de_cliente, periodo0 )

# calculo topes
periodo_ultimo <- dsimple[, max(periodo0) ]
periodo_anteultimo <- periodo_ultimo - 1


# calculo los leads de orden 1 y 2
dsimple[, c("periodo1", "periodo2") :=
  shift(periodo0, n=1:2, fill=NA, type="lead"),  numero_de_cliente
]

# assign most common class values = "CONTINUA"
dsimple[ periodo0 < periodo_anteultimo, clase_ternaria := "CONTINUA" ]

# calculo BAJA+1
dsimple[ periodo0 < periodo_ultimo &
  ( is.na(periodo1) | periodo0 + 1 < periodo1 ),
  clase_ternaria := "BAJA+1"
]

# calculo BAJA+2
dsimple[ periodo0 < periodo_anteultimo & (periodo0+1 == periodo1 )
  & ( is.na(periodo2) | periodo0 + 2 < periodo2 ),
  clase_ternaria := "BAJA+2"
]

# pego el resultado en el dataset original y grabo
setorder( dsimple, pos )
dataset[, clase_ternaria := dsimple$clase_ternaria ]

rm(dsimple)
gc()
Sys.time()
# Out:
# [1] "2025-11-30 22:02:02 UTC"
# Loading required package: data.table
#        used      (Mb)   gc trigger (Mb)    max used   (Mb)
# Ncells    759126   40.6    1454567    77.7    1454567   77.7
# Vcells 555646743 4239.3 1481537591 11303.3 1296635900 9892.6
#        used      (Mb)   gc trigger (Mb)    max used   (Mb)
# Ncells    768007   41.1    1454567    77.7    1454567   77.7
# Vcells 560572054 4276.9 1481537591 11303.3 1296635900 9892.6
# [1] "2025-11-30 22:02:34 UTC"

# %%
setorder( dataset, foto_mes, clase_ternaria, numero_de_cliente)
dataset[, .N, list(foto_mes, clase_ternaria)]
# Out:
#    foto_mes clase_ternaria N
# 1  201901   BAJA+1            645
# 2  201901   BAJA+2            729
# 3  201901   CONTINUA       122899
# 4  201902   BAJA+1            733
# 5  201902   BAJA+2            707
# 6  201902   CONTINUA       123961
# 7  201903   BAJA+1            708
# 8  201903   BAJA+2            751
# 9  201903   CONTINUA       124508
# 10 201904   BAJA+1            756
# 11 201904   BAJA+2            514
# 12 201904   CONTINUA       125268
# 13 201905   BAJA+1            517
# 14 201905   BAJA+2            692
# 15 201905   CONTINUA       125993
# 16 201906   BAJA+1            696
# 17 201906   BAJA+2            608
# 18 201906   CONTINUA       127430
# 19 201907   BAJA+1            611
# 20 201907   BAJA+2            680
# 21 201907   CONTINUA       128977
# 22 201908   BAJA+1            683
# 23 201908   BAJA+2            577
# 24 201908   CONTINUA       130883
# 25 201909   BAJA+1            581
# 26 201909   BAJA+2            582
# 27 201909   CONTINUA       132594
# 28 201910   BAJA+1            594
# 29 201910   BAJA+2            618
# 30 201910   CONTINUA       134798
# ⋮  ⋮        ⋮              ⋮
# 67 202011   BAJA+1            456
# 68 202011   BAJA+2            616
# 69 202011   CONTINUA       159178
# 70 202012   BAJA+1            622
# 71 202012   BAJA+2            619
# 72 202012   CONTINUA       159756
# 73 202101   BAJA+1            622
# 74 202101   BAJA+2            825
# 75 202101   CONTINUA       160080
# 76 202102   BAJA+1            831
# 77 202102   BAJA+2           1032
# 78 202102   CONTINUA       160292
# 79 202103   BAJA+1           1039
# 80 202103   BAJA+2            951
# 81 202103   CONTINUA       161119
# 82 202104   BAJA+1            955
# 83 202104   BAJA+2           1130
# 84 202104   CONTINUA       161333
# 85 202105   BAJA+1           1134
# 86 202105   BAJA+2            842
# 87 202105   CONTINUA       161941
# 88 202106   BAJA+1            843
# 89 202106   BAJA+2           1134
# 90 202106   CONTINUA       162336
# 91 202107   BAJA+1           1137
# 92 202107   BAJA+2           1248
# 93 202107   CONTINUA       162211
# 94 202108   NA             163570
# 95 202108   BAJA+1           1252
# 96 202109   NA             165093

# %% [markdown]
# ### Eliminacion de Features

# %% [markdown]
# Completar a gusto LUEGO de realizar un analisis exploratorio de datos.

# %%
# Saco éstas variables
dataset[, mprestamos_personales := NULL ]
dataset[, cprestamos_personales := NULL ]
dataset[, Master_mfinanciacion_limite := NULL ] 
dataset[, Visa_mfinanciacion_limite := NULL ] 
ncol(dataset)
nrow(dataset)
# Out:
# [1] 153
# [1] 4883051

# %% [markdown]
# ### Data Quality

# %%
# Identificar las columnas numéricas a chequear
#    (Excluimos IDs y la propia foto_mes)
numeric_types <- c("integer", "numeric", "double", "integer64")
all_cols <- names(dataset)

# Obtenemos los nombres de las columnas que son numéricas
cols_a_chequear <- all_cols[sapply(dataset, function(x) class(x)[1] %in% numeric_types)]

# Quitamos las que no son features (ID, fecha)
cols_a_chequear <- setdiff(cols_a_chequear, c("numero_de_cliente", "foto_mes"))

# Calcular el porcentaje de ceros por mes
resumen_wide <- dataset[,
                        lapply(.SD, function(x) sum(x == 0, na.rm = TRUE) / .N),
                        by = foto_mes,
                        .SDcols = cols_a_chequear]

# Convertir (melt) la tabla a formato largo
resumen_long <- melt(resumen_wide,
                     id.vars = "foto_mes",
                     variable.name = "variable",
                     value.name = "porcentaje_ceros")

# Filtrar y crear la lista de problemas
#  Nos quedamos solo con los que son 100% ceros (porcentaje == 1)
lista_problemas <- resumen_long[porcentaje_ceros == 1,
                                .(foto_mes, variable)]

setorder(lista_problemas, foto_mes, variable)

# 5. Mostrar el resultado
print("Columnas que son 100% CERO en un mes:")
print(lista_problemas)
# Out:
# [1] "Columnas que son 100% CERO en un mes:"
#     foto_mes                           variable
#        <int>                             <fctr>
#  1:   201904  ctarjeta_visa_debitos_automaticos
#  2:   201904 mttarjeta_visa_debitos_automaticos
#  3:   201905                      mrentabilidad
#  4:   201905               mrentabilidad_annual
#  5:   201905                        mcomisiones
#  6:   201905                    mactivos_margen
#  7:   201905                    mpasivos_margen
#  8:   201905                  ccomisiones_otras
#  9:   201905                  mcomisiones_otras
# 10:   201910                      mrentabilidad
# 11:   201910               mrentabilidad_annual
# 12:   201910                        mcomisiones
# 13:   201910                    mactivos_margen
# 14:   201910                    mpasivos_margen
# 15:   201910        ccajeros_propios_descuentos
# 16:   201910        mcajeros_propios_descuentos
# 17:   201910           ctarjeta_visa_descuentos
# 18:   201910           mtarjeta_visa_descuentos
# 19:   201910         ctarjeta_master_descuentos
# 20:   201910         mtarjeta_master_descuentos
# 21:   201910                  ccomisiones_otras
# 22:   201910                  mcomisiones_otras
# 23:   201910         chomebanking_transacciones
# 24:   202002        ccajeros_propios_descuentos
# 25:   202002        mcajeros_propios_descuentos
# 26:   202002           ctarjeta_visa_descuentos
# 27:   202002           mtarjeta_visa_descuentos
# 28:   202002         ctarjeta_master_descuentos
# 29:   202002         mtarjeta_master_descuentos
# 30:   202006                     active_quarter
# 31:   202006                           internet
# 32:   202006                      mrentabilidad
# 33:   202006               mrentabilidad_annual
# 34:   202006                        mcomisiones
# 35:   202006                    mactivos_margen
# 36:   202006                    mpasivos_margen
# 37:   202006                     mcuentas_saldo
# 38:   202006      ctarjeta_debito_transacciones
# 39:   202006                      mautoservicio
# 40:   202006        ctarjeta_visa_transacciones
# 41:   202006              mtarjeta_visa_consumo
# 42:   202006      ctarjeta_master_transacciones
# 43:   202006            mtarjeta_master_consumo
# 44:   202006        ccajeros_propios_descuentos
# 45:   202006        mcajeros_propios_descuentos
# 46:   202006           ctarjeta_visa_descuentos
# 47:   202006           mtarjeta_visa_descuentos
# 48:   202006         ctarjeta_master_descuentos
# 49:   202006         mtarjeta_master_descuentos
# 50:   202006                  ccomisiones_otras
# 51:   202006                  mcomisiones_otras
# 52:   202006           cextraccion_autoservicio
# 53:   202006           mextraccion_autoservicio
# 54:   202006               ccheques_depositados
# 55:   202006               mcheques_depositados
# 56:   202006                  ccheques_emitidos
# 57:   202006                  mcheques_emitidos
# 58:   202006    ccheques_depositados_rechazados
# 59:   202006    mcheques_depositados_rechazados
# 60:   202006       ccheques_emitidos_rechazados
# 61:   202006       mcheques_emitidos_rechazados
# 62:   202006                        tcallcenter
# 63:   202006          ccallcenter_transacciones
# 64:   202006                       thomebanking
# 65:   202006         chomebanking_transacciones
# 66:   202006               ccajas_transacciones
# 67:   202006                   ccajas_consultas
# 68:   202006                   ccajas_depositos
# 69:   202006                ccajas_extracciones
# 70:   202006                       ccajas_otras
# 71:   202006                           catm_trx
# 72:   202006                               matm
# 73:   202006                     catm_trx_other
# 74:   202006                         matm_other
# 75:   202006                        tmobile_app
# 76:   202006                    cmobile_app_trx
# 77:   202009        ccajeros_propios_descuentos
# 78:   202009        mcajeros_propios_descuentos
# 79:   202009           ctarjeta_visa_descuentos
# 80:   202009           mtarjeta_visa_descuentos
# 81:   202009         ctarjeta_master_descuentos
# 82:   202009         mtarjeta_master_descuentos
# 83:   202010        ccajeros_propios_descuentos
# 84:   202010        mcajeros_propios_descuentos
# 85:   202010           ctarjeta_visa_descuentos
# 86:   202010           mtarjeta_visa_descuentos
# 87:   202010         ctarjeta_master_descuentos
# 88:   202010         mtarjeta_master_descuentos
# 89:   202102        ccajeros_propios_descuentos
# 90:   202102        mcajeros_propios_descuentos
# 91:   202102           ctarjeta_visa_descuentos
# 92:   202102           mtarjeta_visa_descuentos
# 93:   202102         ctarjeta_master_descuentos
# 94:   202102         mtarjeta_master_descuentos
# 95:   202105                   ccajas_depositos
#     foto_mes                           variable

# %%
# Asumimos que 'dataset' y 'lista_problemas' existen

cat("\nIniciando transformación a NA...\n")


for(i in 1:nrow(lista_problemas)) {

  # Obtenemos el mes y el nombre de la variable
  f <- lista_problemas$foto_mes[i]
  v <- as.character(lista_problemas$variable[i]) # Nombre de la columna como string

  # Determinamos el tipo de NA (Integer o Double)
  na_value <- if (class(dataset[[v]])[1] == "integer") {
      NA_integer_
    } else {
      NA_real_
    }

  dataset[foto_mes == f, (v) := na_value]

}

cat("¡Transformación completa!\n")
# Out:
# Iniciando transformación a NA...
# ¡Transformación completa!

# %% [markdown]
# ### Variables rotas

# %%
# Variables rotas
# Saco meses previos al 'quiebre'
dataset[foto_mes < 201912, cpagodeservicios := NA]
dataset[foto_mes < 201912, mpagodeservicios := NA]
dataset[foto_mes < 201912, cpagomiscuentas := NA]
dataset[foto_mes < 201912, mpagomiscuentas := NA]

dataset[foto_mes < 202010, tmobile_app := NA]
dataset[foto_mes < 202010, cmobile_app_trx := NA]

dataset[foto_mes < 202010, internet := NA]

# %%
library(dplyr)
library(tidyr)
library(ggplot2)

# --- Variables de interés ---
vars_a_graficar <- c("internet", "cpagodeservicios", "mpagodeservicios", "cpagomiscuentas", "mpagomiscuentas", "tmobile_app", "cmobile_app_trx")

# --- 1️⃣ Calcular el promedio mensual solo para las variables deseadas ---
mean_long <- dataset %>%
  select(foto_mes, all_of(vars_a_graficar)) %>%
  group_by(foto_mes) %>%
  summarise(across(everything(), ~mean(.x, na.rm = TRUE))) %>%
  pivot_longer(
    cols = -foto_mes,
    names_to = "variable",
    values_to = "mean_value"
  ) %>%
  mutate(fecha = as.Date(paste0(foto_mes, "01"), format = "%Y%m%d")) %>%
  ungroup()

# --- 2️⃣ Graficar todas las variables juntas (una por panel) ---
ggplot(mean_long, aes(x = fecha, y = mean_value, color = variable)) +
  geom_line(size = 0.8, show.legend = FALSE) +
  facet_wrap(~variable, scales = "free_y", ncol = 2) +
  labs(
    title = "Evolución mensual del promedio por variable",
    x = "Mes",
    y = "Valor medio"
  ) +
  theme_minimal(base_size = 13) +
  theme(plot.title = element_text(face = "bold", hjust = 0.5))

# %% [markdown]
# ### Data Drifting

# %% [markdown]
# ### Payroll

# %%
library(dplyr)
library(tidyr)
library(ggplot2)

# --- Variables de interés ---
# vars_a_graficar <- c("cpayroll_trx", "mpayroll", "mcaja_ahorro", "mcuenta_corriente")
vars_a_graficar <- c("cpayroll_trx", "mpayroll")

# --- 1️⃣ Calcular el promedio mensual solo para las variables deseadas ---
mean_long <- dataset %>%
  select(foto_mes, all_of(vars_a_graficar)) %>%
  group_by(foto_mes) %>%
  summarise(across(everything(), ~mean(.x, na.rm = TRUE))) %>%
  pivot_longer(
    cols = -foto_mes,
    names_to = "variable",
    values_to = "mean_value"
  ) %>%
  mutate(fecha = as.Date(paste0(foto_mes, "01"), format = "%Y%m%d")) %>%
  ungroup()

# --- 2️⃣ Graficar todas las variables juntas (una por panel) ---
ggplot(mean_long, aes(x = fecha, y = mean_value, color = variable)) +
  geom_line(size = 0.8, show.legend = FALSE) +
  facet_wrap(~variable, scales = "free_y", ncol = 2) +
  labs(
    title = "Evolución mensual del promedio por variable",
    x = "Mes",
    y = "Valor medio"
  ) +
  theme_minimal(base_size = 13) +
  theme(plot.title = element_text(face = "bold", hjust = 0.5))
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:data.table’:
#
#     between, first, last
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Warning message:
# “Using `size` aesthetic for lines was deprecated in ggplot2 3.4.0.
# ℹ Please use `linewidth` instead.”
# plot without title

# %%
# suavizado de picos en payroll, caja de ahorro y cuenta corriente. 

library(data.table)

Sys.time()

dataset[, cpayroll_trx := as.numeric(cpayroll_trx)]

# vars_a_suavizar <- c("cpayroll_trx", "mpayroll", "mcaja_ahorro", "mcuenta_corriente")
vars_a_suavizar <- c("cpayroll_trx", "mpayroll")
umbral_aumento <- 1.5

# Definimos los meses específicos donde queremos aplicar el suavizado
meses_de_interes <- c(201906, 201912, 202006, 202012, 202106)

setorder(dataset, numero_de_cliente, foto_mes)

for (v in vars_a_suavizar) {
  cat("Suavizando:", v, "\n")
  
  # 1. Creamos lag y lead (esto debe hacerse siempre para todos los meses)
  dataset[, `:=`(
    lag = shift(get(v), 1, type="lag"),
    lead = shift(get(v), 1, type="lead")
  ), by = numero_de_cliente]
  
  # 2. Aplicamos la corrección solo si se cumplen TRES condiciones:
  #    a) Es un pico (valor actual >= 1.5 * lag)
  #    b) Tenemos lag y lead disponibles
  #    c) La fila corresponde a uno de los meses de interés (Junio o Diciembre)
  dataset[get(v) >= umbral_aumento * lag & 
          !is.na(lag) & 
          !is.na(lead) &
          foto_mes %in% meses_de_interes, # <-- NUEVA CONDICIÓN
          (v) := (lag + lead) / 2]
  
  # 3. Eliminamos las columnas temporales
  dataset[, c("lag", "lead") := NULL]
}

gc()
Sys.time()
cat("✔ Suavizado de picos en meses específicos completado.\n")

# %%
library(dplyr)
library(tidyr)
library(ggplot2)

# --- Variables de interés ---
# vars_a_graficar <- c("cpayroll_trx", "mpayroll", "mcaja_ahorro", "mcuenta_corriente")
vars_a_graficar <- c("cpayroll_trx", "mpayroll")

# --- 1️⃣ Calcular el promedio mensual solo para las variables deseadas ---
mean_long <- dataset %>%
  select(foto_mes, all_of(vars_a_graficar)) %>%
  group_by(foto_mes) %>%
  summarise(across(everything(), ~mean(.x, na.rm = TRUE))) %>%
  pivot_longer(
    cols = -foto_mes,
    names_to = "variable",
    values_to = "mean_value"
  ) %>%
  mutate(fecha = as.Date(paste0(foto_mes, "01"), format = "%Y%m%d")) %>%
  ungroup()

# --- 2️⃣ Graficar todas las variables juntas (una por panel) ---
ggplot(mean_long, aes(x = fecha, y = mean_value, color = variable)) +
  geom_line(size = 0.8, show.legend = FALSE) +
  facet_wrap(~variable, scales = "free_y", ncol = 2) +
  labs(
    title = "Evolución mensual del promedio por variable",
    x = "Mes",
    y = "Valor medio"
  ) +
  theme_minimal(base_size = 13) +
  theme(plot.title = element_text(face = "bold", hjust = 0.5))

# %% [markdown]
# #### Cargamos los índices

# %%
require(data.table)

indices_externos <- data.table(
  foto_mes = c(201901, 201902, 201903, 201904, 201905, 201906, 201907, 201908, 201909, 201910, 201911, 201912, 202001, 202002, 202003, 202004, 202005, 202006, 202007, 202008, 202009, 202010, 202011, 202012, 202101, 202102, 202103, 202104, 202105, 202106, 202107, 202108),
  TC_BLUE = c("37,5", "39", "43,65", "46", "46", "43,8", "45,2", "63", "61,25", "69", "69,25", "78,5", "78", "78,5", "83,5", "118", "125", "126", "136", "135", "146", "169", "155", "166", "153", "146", "141", "150", "157", "168", "180,5", "182"),
  TC_OFICIAL = c("38,28", "40,14", "44,4", "45,36", "46,1", "43,7", "45,02", "62,04", "59,82", "63,23", "62,93", "62,99", "63,03", "64,26", "66,58", "69,16", "70,76", "74,07", "76,39", "78,36", "80,63", "83,89", "86,72", "89,87", "92,7", "95,12", "97,69", "98,9", "100,09", "101,17", "102,06", "103,14"),
  TCRM = c("116,5734916", "116,5625812", "119,8157416", "120,2150629", "119,4975567", "114,8101224", "109,8715912", "127,7565287", "130,6961531", "129,7797576", "126,9467229", "123,5951113", "120,8372653", "118,9226283", "114,5040182", "111,5867304", "111,7626924", "116,6307121", "117,9781145", "118,9579865", "119,6485855", "118,1736932", "119,6199112", "123,235859", "122,8366223", "122,3839332", "119,0439564", "116,7635839", "117,2617246", "116,9865438", "113,7702507", "111,9430182"),
  UVA = c("32,03", "32,86", "33,97", "35,42", "36,89", "38,03", "39,2", "40,16", "41,26", "43,43", "45,42", "47,16", "49,05", "50,49", "51,62", "52,95", "54,24", "55,06", "56,09", "57,17", "58,52", "60,16", "61,94", "64,32", "66,54", "69,04", "71,92", "74,87", "78,07", "81,13", "83,82", "86,42"),
  IPC = c("189,6101", "196,7501", "205,9571", "213,0517", "219,5691", "225,537", "230,494", "239,6077", "253,7102", "262,0661", "273,2158", "283,4442", "289,8299", "295,666", "305,5515", "310,1243", "314,9087", "321,9738", "328,2014", "337,0632", "346,6207", "359,657", "371,0211", "385,8826", "401,5071", "415,8595", "435,8657", "453,6503", "468,725", "483,6049", "498,0987", "510,3942"),
  IPIM = c("279", "288,4", "300,2", "314", "329,5", "334,9", "335,2", "372,8", "388,3", "402,3", "424", "439,7", "446,3", "451,3", "455,6", "449,7", "451,3", "467,8", "484,4", "504,2", "522,9", "547,3", "570,1", "595,2", "628,3", "666,5", "692,4", "725,5", "748,8", "772,3", "789,5", "809,4"),
  ripte_indice = c("4042", "4198,76", "4444,6", "4533,03", "4676,25", "4753,19", "4948,27", "5039,93", "5199,08", "5467,59", "5554,15", "5666,48", "6066,07", "6445,13", "6500,72", "6510,18", "6521,87", "6670,93", "6908,52", "6945,86", "7076,47", "7401,81", "7495,03", "7643,41", "7784,1", "8263,33", "8665,19", "9201,59", "9311,61", "9660,13", "10089,96", "10326,11"),
  tasa_i = c("3,71", "3,09", "3,81", "4,45", "4,42", "3,96", "4,14", "4,84", "4,91", "4,06", "3,68", "3,29", "2,83", "2,65", "2,30", "1,54", "2,21", "2,47", "2,43", "2,47", "2,47", "2,65", "2,81", "2,85", "2,85", "2,80", "2,84", "2,84", "2,84", "2,84", "2,84", "2,85"),
  tasa_r = c("0,79", "-0,68", "-0,85", "1,01", "1,28", "1,23", "1,89", "0,81", "-0,94", "0,73", "-0,59", "-0,40", "0,52", "0,64", "-0,97", "0,04", "0,70", "0,27", "0,52", "-0,23", "-0,32", "-1,11", "-0,38", "-1,10", "-1,11", "-0,77", "-1,87", "-1,21", "-0,44", "-0,35", "-0,15", "0,34")
)

# Trabajamos el formato
indices_externos[, foto_mes := as.integer(foto_mes)]

# Reemplazar la coma por el punto en todas las columnas excepto 'foto_mes'
columnas_numericas <- names(indices_externos)[-1]

indices_externos[, (columnas_numericas) := lapply(.SD, function(x) as.numeric(gsub(",", ".", x))),
                 .SDcols = columnas_numericas]

# convertir a tasa
cols_tasas <- c("tasa_i", "tasa_r")
indices_externos[, (cols_tasas) := lapply(.SD, function(x) x / 100), .SDcols = cols_tasas]

# Verificar la estructura de la tabla
str(indices_externos)
# Out:
# Classes ‘data.table’ and 'data.frame':	32 obs. of  10 variables:
#  $ foto_mes    : int  201901 201902 201903 201904 201905 201906 201907 201908 201909 201910 ...
#  $ TC_BLUE     : num  37.5 39 43.6 46 46 ...
#  $ TC_OFICIAL  : num  38.3 40.1 44.4 45.4 46.1 ...
#  $ TCRM        : num  117 117 120 120 119 ...
#  $ UVA         : num  32 32.9 34 35.4 36.9 ...
#  $ IPC         : num  190 197 206 213 220 ...
#  $ IPIM        : num  279 288 300 314 330 ...
#  $ ripte_indice: num  4042 4199 4445 4533 4676 ...
#  $ tasa_i      : num  0.0371 0.0309 0.0381 0.0445 0.0442 0.0396 0.0414 0.0484 0.0491 0.0406 ...
#  $ tasa_r      : num  0.0079 -0.0068 -0.0085 0.0101 0.0128 0.0123 0.0189 0.0081 -0.0094 0.0073 ...
#  - attr(*, ".internal.selfref")=<externalptr>

# %%
require("data.table")

#' @title Deflacta columnas monetarias SOBREESCRIBIENDO las originales
#' @description Modifica las columnas monetarias (ej: 'mrentabilidad')
#'              directamente con su valor deflactado.
#'
#' @param dt El data.table principal (ej: 'dataset') que se modificará.
#' @param dt_indices El data.table que contiene todos los índices (ej: 'indices_externos').
#' @param criterio_deflacion El nombre de la columna a usar (ej: "IPC", "TCRM", "tasa_i").
#' @param incluir_dolarizadas TRUE o FALSE. Si es TRUE, ajusta pesos Y dólares.
#'                            Si es FALSE, ajusta SÓLO pesos.
#' @param mes_base Un integer (YYYYMM). Mes base para normalizar (ej: 201901).
#'
#' @return El data.table 'dt' modificado por referencia (no es necesario reasignarlo).

deflactar_dataset <- function(dt,
                                       dt_indices,
                                       criterio_deflacion,
                                       incluir_dolarizadas = FALSE,
                                       mes_base = 201901) {

  cat(paste0("Iniciando deflación según Criterio: ", criterio_deflacion, "\n"))

  # --- 1. Definir Lógicas y Columnas ---

  # Grupo 1: Variables en PESOS
  columnas_pesos <- c(
    "mrentabilidad", "mrentabilidad_annual", "mcomisiones", "mactivos_margen",
    "mpasivos_margen", "mcuentas_saldo", "mcuenta_corriente", "mcaja_ahorro",
    "mcuenta_corriente_adicional", "mcaja_ahorro_adicional",
    "mprestamos_personales", "mprestamos_prendarios", "mprestamos_hipotecarios",
    "mplazo_fijo_pesos", "minversion1_pesos", "minversion2",
    "mpayroll", "mpayroll2", "mcuenta_debitos_automaticos",
    "mtarjeta_visa_consumo", "mtarjeta_master_consumo",
    "mttarjeta_visa_debitos_automaticos", "mttarjeta_master_debitos_automaticos",
    "mpagodeservicios", "mpagomiscuentas", "mtransferencias_recibidas",
    "mtransferencias_emitidas", "mextraccion_autoservicio", "mcheques_depositados",
    "mcheques_emitidos", "mcheques_depositados_rechazados", "mcheques_emitidos_rechazados",
    "matm", "matm_other", "mautoservicio",
    "mcomisiones_mantenimiento", "mcomisiones_otras", "mforex_buy", "mforex_sell",
    "mcajeros_propios_descuentos", "mtarjeta_visa_descuentos", "mtarjeta_master_descuentos",
    "Master_mfinanciacion_limite", "Master_msaldototal", "Master_msaldopesos",
    "Master_mconsumospesos", "Master_mlimitecompra", "Master_madelantopesos",
    "Master_mpagado", "Master_mpagospesos", "Master_mconsumototal", "Master_mpagominimo",
    "Visa_mfinanciacion_limite", "Visa_msaldototal", "Visa_msaldopesos",
    "Visa_mconsumospesos", "Visa_mlimitecompra", "Visa_madelantopesos",
    "Visa_mpagado", "Visa_mpagospesos", "Visa_mconsumototal", "Visa_mpagominimo"
  )

  # Grupo 2: Variables DOLARIZADAS
  columnas_dolares <- c(
    "mcaja_ahorro_dolares", "mplazo_fijo_dolares", "minversion1_dolares",
    "Master_msaldodolares", "Master_mconsumosdolares", "Master_madelantodolares",
    "Master_mpagosdolares",
    "Visa_msaldodolares", "Visa_mconsumosdolares", "Visa_madelantodolares",
    "Visa_mpagosdolares"
  )

  # Grupos de lógicas (actualizados a tu tabla final)
  grupo_indices <- c("IPC", "IPIM", "UVA", "ripte_indice") # Se fueron CER e indice_salarios
  grupo_tc <- c("TC_BLUE", "TC_OFICIAL", "TCRM") # Se fue TC_MAYORISTA, TC_MINORISTA
  grupo_tasas <- c("tasa_i", "tasa_r") # Nombres actualizados

  # --- 2. Validar Entradas ---
  if (!criterio_deflacion %in% names(dt_indices)) {
     stop(paste("La columna de criterio '", criterio_deflacion, "' NO existe en 'indices_externos'."))
  }

  # --- 3. Preparar el Índice Normalizado ---
  dt_indice_temporal <- dt_indices[, .(foto_mes, INDICE_TEMP = get(criterio_deflacion))]
  setorder(dt_indice_temporal, foto_mes)
  valor_base <- dt_indice_temporal[foto_mes == mes_base, INDICE_TEMP]
  if (length(valor_base) == 0 | is.na(valor_base)) {
    stop(paste("El 'mes_base'", mes_base, "no se encontró o es NA en el índice."))
  }

  if (criterio_deflacion %in% grupo_indices) {
    cat("... Aplicando Lógica de ÍNDICE (Base 1.0)\n")
    dt_indice_temporal[, indice_normalizado := INDICE_TEMP / valor_base]
  } else if (criterio_deflacion %in% grupo_tasas) {
    cat("... Aplicando Lógica de TASA DE INTERÉS\n")
    dt_indice_temporal[, factor := 1 + INDICE_TEMP]
    dt_indice_temporal[, indice_compuesto := cumprod(factor)]
    valor_base_compuesto <- dt_indice_temporal[foto_mes == mes_base, indice_compuesto]
    dt_indice_temporal[, indice_normalizado := indice_compuesto / valor_base_compuesto]
  } else if (criterio_deflacion %in% grupo_tc) {
    cat("... Aplicando Lógica de TIPO DE CAMBIO\n")
    dt_indice_temporal[, indice_normalizado := INDICE_TEMP]
  } else {
    warning(paste("Criterio '", criterio_deflacion, "' no está en un grupo predefinido. Se usará la Lógica de ÍNDICE por defecto."))
    dt_indice_temporal[, indice_normalizado := INDICE_TEMP / valor_base]
  }

  dt_indice_para_merge <- dt_indice_temporal[, .(foto_mes, indice_normalizado)]

  # --- 4. Unir el índice al dataset principal (Modifica 'dt' por referencia) ---
  dt[dt_indice_para_merge, on = "foto_mes", indice_normalizado := i.indice_normalizado]

  # --- 5. Seleccionar columnas a deflactar ---
  cols_a_deflactar_final <- columnas_pesos
  if (incluir_dolarizadas) {
    cols_a_deflactar_final <- c(cols_a_deflactar_final, columnas_dolares)
  }
  cols_a_deflactar_final <- intersect(cols_a_deflactar_final, names(dt))

  if (length(cols_a_deflactar_final) == 0) {
    cat("Advertencia: Ninguna columna a deflactar fue encontrada. No se hizo nada.\n")
    dt[, indice_normalizado := NULL] # Limpiar la columna de índice
    return(dt)
  }

  # --- 6. Aplicar la deflación (SOBRESCRITURA) ---
  #     (ej: mrentabilidad = mrentabilidad / indice_normalizado)
  dt[, (cols_a_deflactar_final) := lapply(.SD, function(x) {
              x / indice_normalizado
            }), .SDcols = cols_a_deflactar_final]

  # --- 7. Limpiar columna de índice ---
  dt[, indice_normalizado := NULL]

  cat("Deflación completada.", length(cols_a_deflactar_final), "columnas fueron SOBREESCRITAS.\n")

  # Limpieza de memoria
  rm(dt_indice_temporal, dt_indice_para_merge, cols_a_deflactar_final,
     columnas_pesos, columnas_dolares, grupo_indices, grupo_tc, grupo_tasas)
  gc()

  return(dt)
}

# %% [markdown]
# #### Aplicamos una metodología

# %%
# (En la celda de Data Drifting)
deflactar_dataset(
  dt = dataset,
  dt_indices = indices_externos,
  criterio_deflacion = deflactor, #IPC , IPIM, UVA, ripte_indice, TC_BLUE, TC_OFICIAL, TCRM, tasa_i, tasa_r
  incluir_dolarizadas = TRUE,  # si es true afecta las columnas en dólares
  mes_base = 201901  #mes al que lleva el valor
)

# %% [markdown]
# ### Variables agregadas

# %%
# #Feature Engineering de Agregación y Ratios Propias ---


# # 2.1. Definición de grupos de columnas (exhaustiva)
# cols_activos_liquidos <- c("mcuenta_corriente_adicional", "mcuenta_corriente", "mcaja_ahorro", "mcaja_ahorro_adicional", "mcaja_ahorro_dolares", "mplazo_fijo_dolares", "mplazo_fijo_pesos", "minversion1_pesos", "minversion1_dolares", "minversion2")
# cols_deuda_tarjetas <- c("Master_msaldototal", "Visa_msaldototal")
# cols_ingresos <- c("mtransferencias_recibidas", "mcheques_depositados")
# cols_gastos <- c("mcomisiones", "mactivos_margen", "mtarjeta_visa_consumo", "mtarjeta_master_consumo", "mcuenta_debitos_automaticos", "mttarjeta_visa_debitos_automaticos", "mttarjeta_master_debitos_automaticos", "mpagodeservicios", "mpagomiscuentas", "mtransferencias_emitidas", "mextraccion_autoservicio", "mcheques_emitidos", "mforex_buy", "Master_madelantopesos", "Master_madelantodolares", "Visa_madelantopesos", "Visa_madelantodolares")

# # 2.2. Creación de variables agregadas
# dataset[, total_activos_liquidos := rowSums(.SD, na.rm = TRUE), .SDcols = cols_activos_liquidos]
# dataset[, total_deuda_tarjetas := rowSums(.SD, na.rm = TRUE), .SDcols = cols_deuda_tarjetas]
# dataset[, total_ingresos := rowSums(.SD, na.rm = TRUE), .SDcols = cols_ingresos]
# dataset[, total_gastos := rowSums(.SD, na.rm = TRUE), .SDcols = cols_gastos]

# # 2.3. Creación de Ratios de Negocio 
# dataset[, ratio_deuda_ingreso := fifelse(total_ingresos > 0, total_deuda_tarjetas / total_ingresos, 0)]
# dataset[, ratio_gasto_ingreso := fifelse(total_ingresos > 0, total_gastos / total_ingresos, 0)]
# dataset[, ratio_uso_visa := fifelse(Visa_mlimitecompra > 0, mtarjeta_visa_consumo / Visa_mlimitecompra, 0)]
# dataset[, ratio_uso_master := fifelse(Master_mlimitecompra > 0, mtarjeta_master_consumo / Master_mlimitecompra, 0)]
# dataset[, ratio_fuga_capital := fifelse(mtransferencias_recibidas > 0, mtransferencias_emitidas / mtransferencias_recibidas, 0)]

# %% [markdown]
# # Rankings

# %%
# require(data.table)

# #' @title Rankea columnas monetarias por mes (SOBREESCRIBIENDO)
# #' @description Normaliza las columnas monetarias en un rango de [-1, 1]
# #'              agrupando por foto_mes y tratando positivos y negativos
# #'              por separado.
# #'
# #' @param p_dataset El data.table a modificar.

# rank_normalizar_por_mes_monetarias <- function(p_dataset) {

#   # 1. Define el vector con los nombres BASE de las columnas monetarias
#   columnas_monetarias_base <- c(
#     "mrentabilidad", "mrentabilidad_annual", "mcomisiones", "mactivos_margen",
#     "mpasivos_margen", "mcuenta_corriente_adicional", "mcuenta_corriente",
#     "mcaja_ahorro", "mcaja_ahorro_adicional", "mcaja_ahorro_dolares",
#     "mcuentas_saldo", "mautoservicio", "mtarjeta_visa_consumo",
#     "mtarjeta_master_consumo", "mprestamos_personales", "mprestamos_prendarios",
#     "mprestamos_hipotecarios", "mplazo_fijo_dolares", "mplazo_fijo_pesos",
#     "minversion1_pesos", "minversion1_dolares", "minversion2", "mpayroll",
#     "mpayroll2", "mcuenta_debitos_automaticos", "mtarjeta_visa_debitos_automaticos",
#     "mttarjeta_master_debitos_automaticos", "mpagodeservicios", "mpagomiscuentas",
#     "mcajeros_propios_descuentos", "mtarjeta_visa_descuentos",
#     "mtarjeta_master_descuentos", "mcomisiones_mantenimiento", "mcomisiones_otras",
#     "mforex_buy", "mforex_sell", "mtransferencias_recibidas", "mtransferencias_emitidas",
#     "mextraccion_autoservicio", "mcheques_depositados", "mcheques_emitidos",
#     "mcheques_depositados_rechazados", "mcheques_emitidos_rechazados", "matm",
#     "matm_other", "Master_mfinanciacion_limite", "Master_msaldototal",
#     "Master_msaldopesos", "Master_msaldodolares", "Master_mconsumospesos",
#     "Master_mconsumosdolares", "Master_mlimitecompra", "Master_madelantopesos",
#     "Master_madelantodolares", "Master_mpagado", "Master_mpagospesos",
#     "Master_mpagosdolares", "Master_mconsumototal", "Master_mpagominimo",
#     "Visa_mfinanciacion_limite", "Visa_msaldototal", "Visa_msaldopesos",
#     "Visa_msaldodolares", "Visa_mconsumospesos", "Visa_mconsumosdolares",
#     "Visa_mlimitecompra", "Visa_madelantopesos", "Visa_madelantodolares",
#     "Visa_mpagado", "Visa_mpagospesos", "Visa_mpagosdolares", "Visa_mconsumototal",
#     "Visa_mpagominimo"
#   )

#   # 2. Selecciona solo las columnas que realmente existen en el dataset
#   columnas_a_rankear <- intersect(columnas_monetarias_base, names(p_dataset))


#   cat("Columnas a rankear por mes (sobrescribiendo):", length(columnas_a_rankear), "\n")
#   if (length(columnas_a_rankear) == 0) {
#     cat("Advertencia: Ninguna de las columnas monetarias especificadas se encontró en el dataset.\n")
#     return(invisible(p_dataset))
#   }

#   for (col in columnas_a_rankear) {

#     p_dataset[, (col) := {
#       v <- .SD[[1]]
#       r <- numeric(length(v))

#       pos_idx <- which(v > 0)
#       neg_idx <- which(v < 0)

#       if (length(pos_idx) > 0) {
#         r[pos_idx] <- frank(v[pos_idx], ties.method = "average") / length(pos_idx)
#       }
#       if (length(neg_idx) > 0) {
#         r[neg_idx] <- -frank(-v[neg_idx], ties.method = "average") / length(neg_idx)
#       }

#       r[v == 0] <- 0

#       # Segunda normalización para asegurar el rango [-1, 1]
#       max_r_pos <- max(r[pos_idx], 0, na.rm = TRUE)
#       min_r_neg <- min(r[neg_idx], 0, na.rm = TRUE)

#       if (max_r_pos > 0) r[pos_idx] <- r[pos_idx] / max_r_pos
#       if (min_r_neg < 0) r[neg_idx] <- r[neg_idx] / abs(min_r_neg)

#       .(r)
#     }, by = foto_mes, .SDcols = col]
#   }



#   cat("Rankeo completado. Las columnas fueron sobrescritas.\n")
#   gc()
#   invisible(p_dataset)
# }

# %%
# # # aplico la función
# rank_normalizar_por_mes_monetarias(dataset)

# %% [markdown]
# ### Feature Engineering Intra-Mes

# %% [markdown]
# Crear variables nuevas a partir de las existentes dentro del mismo registro, **sin** ir a buscar información histórica.
# <br> El siguiente código es un mínimo ejemplo, agregar nuevos features a gusto

# %%
# el mes 1,2, ..12 , podria servir para detectar estacionalidad
dataset[, kmes := foto_mes %% 100]

# creo un ctr_quarter que tenga en cuenta cuando
# los clientes hace 3 menos meses que estan
# ya que seria injusto considerar las transacciones medidas en menor tiempo
dataset[, ctrx_quarter_normalizado := as.numeric(ctrx_quarter) ]
dataset[cliente_antiguedad == 1, ctrx_quarter_normalizado := ctrx_quarter * 5.0]
dataset[cliente_antiguedad == 2, ctrx_quarter_normalizado := ctrx_quarter * 2.0]
dataset[cliente_antiguedad == 3, ctrx_quarter_normalizado := ctrx_quarter * 1.2]

# variable extraida de una tesis de maestria de Irlanda, se perdió el link
dataset[, mpayroll_sobre_edad := mpayroll / cliente_edad]

Sys.time()
# Out:
# [1] "2025-11-30 22:02:45 UTC"

# %% [markdown]
# ### Feature Engineering Historico

# %%
if( !require("Rcpp")) install.packages("Rcpp", repos = "http://cran.us.r-project.org")
require("Rcpp")

# %%
# se calculan para los 6 meses previos el minimo, maximo y
#  tendencia calculada con cuadrados minimos
# la formula de calculo de la tendencia puede verse en
#  https://stats.libretexts.org/Bookshelves/Introductory_Statistics/Book%3A_Introductory_Statistics_(Shafer_and_Zhang)/10%3A_Correlation_and_Regression/10.04%3A_The_Least_Squares_Regression_Line
# para la maxíma velocidad esta funcion esta escrita en lenguaje C,
# y no en la porqueria de R o Python

cppFunction("NumericVector fhistC(NumericVector pcolumna, IntegerVector pdesde )
{
  /* Aqui se cargan los valores para la regresion */
  double  x[100] ;
  double  y[100] ;

  int n = pcolumna.size();
  NumericVector out( 5*n );

  for(int i = 0; i < n; i++)
  {
    //lag
    if( pdesde[i]-1 < i )  out[ i + 4*n ]  =  pcolumna[i-1] ;
    else                   out[ i + 4*n ]  =  NA_REAL ;


    int  libre    = 0 ;
    int  xvalor   = 1 ;

    for( int j= pdesde[i]-1;  j<=i; j++ )
    {
       double a = pcolumna[j] ;

       if( !R_IsNA( a ) )
       {
          y[ libre ]= a ;
          x[ libre ]= xvalor ;
          libre++ ;
       }

       xvalor++ ;
    }

    /* Si hay al menos dos valores */
    if( libre > 1 )
    {
      double  xsum  = x[0] ;
      double  ysum  = y[0] ;
      double  xysum = xsum * ysum ;
      double  xxsum = xsum * xsum ;
      double  vmin  = y[0] ;
      double  vmax  = y[0] ;

      for( int h=1; h<libre; h++)
      {
        xsum  += x[h] ;
        ysum  += y[h] ;
        xysum += x[h]*y[h] ;
        xxsum += x[h]*x[h] ;

        if( y[h] < vmin )  vmin = y[h] ;
        if( y[h] > vmax )  vmax = y[h] ;
      }

      out[ i ]  =  (libre*xysum - xsum*ysum)/(libre*xxsum -xsum*xsum) ;
      out[ i + n ]    =  vmin ;
      out[ i + 2*n ]  =  vmax ;
      out[ i + 3*n ]  =  ysum / libre ;
    }
    else
    {
      out[ i       ]  =  NA_REAL ;
      out[ i + n   ]  =  NA_REAL ;
      out[ i + 2*n ]  =  NA_REAL ;
      out[ i + 3*n ]  =  NA_REAL ;
    }
  }

  return  out;
}")

# %%
# calcula la tendencia de las variables cols de los ultimos 6 meses
# la tendencia es la pendiente de la recta que ajusta por cuadrados minimos
# La funcionalidad de ratioavg es autoria de  Daiana Sparta,  UAustral  2021

TendenciaYmuchomas <- function(
    dataset, cols, ventana = 6, tendencia = TRUE,
    minimo = TRUE, maximo = TRUE, promedio = TRUE,
    ratioavg = FALSE, ratiomax = FALSE) {
  gc(verbose= FALSE)
  # Esta es la cantidad de meses que utilizo para la historia
  ventana_regresion <- ventana

  last <- nrow(dataset)

  # creo el vector_desde que indica cada ventana
  # de esta forma se acelera el procesamiento ya que lo hago una sola vez
  vector_ids <- dataset[ , numero_de_cliente ]

  vector_desde <- seq(
    -ventana_regresion + 2,
    nrow(dataset) - ventana_regresion + 1
  )

  vector_desde[1:ventana_regresion] <- 1

  for (i in 2:last) {
    if (vector_ids[i - 1] != vector_ids[i]) {
      vector_desde[i] <- i
    }
  }
  for (i in 2:last) {
    if (vector_desde[i] < vector_desde[i - 1]) {
      vector_desde[i] <- vector_desde[i - 1]
    }
  }

  for (campo in cols) {
    nueva_col <- fhistC(dataset[, get(campo)], vector_desde)

    if (tendencia) {
      dataset[, paste0(campo, "_tend", ventana) :=
        nueva_col[(0 * last + 1):(1 * last)]]
    }

    if (minimo) {
      dataset[, paste0(campo, "_min", ventana) :=
        nueva_col[(1 * last + 1):(2 * last)]]
    }

    if (maximo) {
      dataset[, paste0(campo, "_max", ventana) :=
        nueva_col[(2 * last + 1):(3 * last)]]
    }

    if (promedio) {
      dataset[, paste0(campo, "_avg", ventana) :=
        nueva_col[(3 * last + 1):(4 * last)]]
    }

    if (ratioavg) {
      dataset[, paste0(campo, "_ratioavg", ventana) :=
        get(campo) / nueva_col[(3 * last + 1):(4 * last)]]
    }

    if (ratiomax) {
      dataset[, paste0(campo, "_ratiomax", ventana) :=
        get(campo) / nueva_col[(2 * last + 1):(3 * last)]]
    }
  }
}

# %%
# Feature Engineering Historico
# Creacion de LAGs
setorder(dataset, numero_de_cliente, foto_mes)

# todo es lagueable, menos la primary key y la clase
cols_lagueables <- copy( setdiff(
  colnames(dataset),
  c("numero_de_cliente", "foto_mes", "clase_ternaria")
))

# https://rdrr.io/cran/data.table/man/shift.html

# lags de orden 1
dataset[,
  paste0(cols_lagueables, "_lag1") := shift(.SD, 1, NA, "lag"),
  by= numero_de_cliente,
  .SDcols= cols_lagueables
]

# lags de orden 2
dataset[,
  paste0(cols_lagueables, "_lag2") := shift(.SD, 2, NA, "lag"),
  by= numero_de_cliente,
  .SDcols= cols_lagueables
]

# lags de orden 3
dataset[,
  paste0(cols_lagueables, "_lag3") := shift(.SD, 3, NA, "lag"),
  by= numero_de_cliente,
  .SDcols= cols_lagueables
]

# lags de orden 6
dataset[,
  paste0(cols_lagueables, "_lag6") := shift(.SD, 6, NA, "lag"),
  by= numero_de_cliente,
  .SDcols= cols_lagueables
]

# lags de orden 12
dataset[,
  paste0(cols_lagueables, "_lag12") := shift(.SD, 12, NA, "lag"),
  by= numero_de_cliente,
  .SDcols= cols_lagueables
]

# agrego los delta lags
for (vcol in cols_lagueables)
{
  dataset[, paste0(vcol, "_delta1") := get(vcol) - get(paste0(vcol, "_lag1"))]
  dataset[, paste0(vcol, "_delta2") := get(vcol) - get(paste0(vcol, "_lag2"))]
  dataset[, paste0(vcol, "_delta3") := get(vcol) - get(paste0(vcol, "_lag3"))]
  dataset[, paste0(vcol, "_delta6") := get(vcol) - get(paste0(vcol, "_lag6"))]
  dataset[, paste0(vcol, "_delta12") := get(vcol) - get(paste0(vcol, "_lag12"))]
}

Sys.time()
# Out:
# [1] "2025-11-30 22:05:33 UTC"

# %%
# parametros de Feature Engineering Historico de Tendencias
PARAM$FE_hist$Tendencias$run <- TRUE
PARAM$FE_hist$Tendencias$ventana <- 6
PARAM$FE_hist$Tendencias$tendencia <- FALSE
PARAM$FE_hist$Tendencias$minimo <- FALSE
PARAM$FE_hist$Tendencias$maximo <- FALSE
PARAM$FE_hist$Tendencias$promedio <- TRUE
PARAM$FE_hist$Tendencias$ratioavg <- FALSE
PARAM$FE_hist$Tendencias$ratiomax <- FALSE

# %%
# aqui se agregan las tendencias de los ultimos 6 meses

cols_lagueables <- intersect(cols_lagueables, colnames(dataset))
setorder(dataset, numero_de_cliente, foto_mes)

if( PARAM$FE_hist$Tendencias$run) {
    TendenciaYmuchomas(dataset,
    cols = cols_lagueables,
    ventana = PARAM$FE_hist$Tendencias$ventana, # 6 meses de historia
    tendencia = PARAM$FE_hist$Tendencias$tendencia,
    minimo = PARAM$FE_hist$Tendencias$minimo,
    maximo = PARAM$FE_hist$Tendencias$maximo,
    promedio = PARAM$FE_hist$Tendencias$promedio,
    ratioavg = PARAM$FE_hist$Tendencias$ratioavg,
    ratiomax = PARAM$FE_hist$Tendencias$ratiomax
  )
}

ncol(dataset)
Sys.time()

# %% [markdown]
# ### Dummies

# %%
# # 1. Inicializar en 0
dataset[, cepo_activo := 0L]
# dataset[, pandemia :=0L]

# # 2. Marcar con 1 desde Noviembre 2019 en adelante
dataset[foto_mes >= 201911, cepo_activo := 1L]
# dataset[foto_mes >= 202003, pandemia := 1L]

# %%
ncol(dataset)
colnames(dataset)
# Out:
# [1] 1074
#    [1] "numero_de_cliente"
#    [2] "foto_mes"
#    [3] "active_quarter"
#    [4] "cliente_vip"
#    [5] "internet"
#    [6] "cliente_edad"
#    [7] "cliente_antiguedad"
#    [8] "mrentabilidad"
#    [9] "mrentabilidad_annual"
#   [10] "mcomisiones"
#   [11] "mactivos_margen"
#   [12] "mpasivos_margen"
#   [13] "cproductos"
#   [14] "tcuentas"
#   [15] "ccuenta_corriente"
#   [16] "mcuenta_corriente_adicional"
#   [17] "mcuenta_corriente"
#   [18] "ccaja_ahorro"
#   [19] "mcaja_ahorro"
#   [20] "mcaja_ahorro_adicional"
#   [21] "mcaja_ahorro_dolares"
#   [22] "cdescubierto_preacordado"
#   [23] "mcuentas_saldo"
#   [24] "ctarjeta_debito"
#   [25] "ctarjeta_debito_transacciones"
#   [26] "mautoservicio"
#   [27] "ctarjeta_visa"
#   [28] "ctarjeta_visa_transacciones"
#   [29] "mtarjeta_visa_consumo"
#   [30] "ctarjeta_master"
#   [31] "ctarjeta_master_transacciones"
#   [32] "mtarjeta_master_consumo"
#   [33] "cprestamos_prendarios"
#   [34] "mprestamos_prendarios"
#   [35] "cprestamos_hipotecarios"
#   [36] "mprestamos_hipotecarios"
#   [37] "cplazo_fijo"
#   [38] "mplazo_fijo_dolares"
#   [39] "mplazo_fijo_pesos"
#   [40] "cinversion1"
#   [41] "minversion1_pesos"
#   [42] "minversion1_dolares"
#   [43] "cinversion2"
#   [44] "minversion2"
#   [45] "cseguro_vida"
#   [46] "cseguro_auto"
#   [47] "cseguro_vivienda"
#   [48] "cseguro_accidentes_personales"
#   [49] "ccaja_seguridad"
#   [50] "cpayroll_trx"
#   [51] "mpayroll"
#   [52] "mpayroll2"
#   [53] "cpayroll2_trx"
#   [54] "ccuenta_debitos_automaticos"
#   [55] "mcuenta_debitos_automaticos"
#   [56] "ctarjeta_visa_debitos_automaticos"
#   [57] "mttarjeta_visa_debitos_automaticos"
#   [58] "ctarjeta_master_debitos_automaticos"
#   [59] "mttarjeta_master_debitos_automaticos"
#   [60] "cpagodeservicios"
#   [61] "mpagodeservicios"
#   [62] "cpagomiscuentas"
#   [63] "mpagomiscuentas"
#   [64] "ccajeros_propios_descuentos"
#   [65] "mcajeros_propios_descuentos"
#   [66] "ctarjeta_visa_descuentos"
#   [67] "mtarjeta_visa_descuentos"
#   [68] "ctarjeta_master_descuentos"
#   [69] "mtarjeta_master_descuentos"
#   [70] "ccomisiones_mantenimiento"
#   [71] "mcomisiones_mantenimiento"
#   [72] "ccomisiones_otras"
#   [73] "mcomisiones_otras"
#   [74] "cforex"
#   [75] "cforex_buy"
#   [76] "mforex_buy"
#   [77] "cforex_sell"
#   [78] "mforex_sell"
#   [79] "ctransferencias_recibidas"
#   [80] "mtransferencias_recibidas"
#   [81] "ctransferencias_emitidas"
#   [82] "mtransferencias_emitidas"
#   [83] "cextraccion_autoservicio"
#   [84] "mextraccion_autoservicio"
#   [85] "ccheques_depositados"
#   [86] "mcheques_depositados"
#   [87] "ccheques_emitidos"
#   [88] "mcheques_emitidos"
#   [89] "ccheques_depositados_rechazados"
#   [90] "mcheques_depositados_rechazados"
#   [91] "ccheques_emitidos_rechazados"
#   [92] "mcheques_emitidos_rechazados"
#   [93] "tcallcenter"
#   [94] "ccallcenter_transacciones"
#   [95] "thomebanking"
#   [96] "chomebanking_transacciones"
#   [97] "ccajas_transacciones"
#   [98] "ccajas_consultas"
#   [99] "ccajas_depositos"
#  [100] "ccajas_extracciones"
#  [101] "ccajas_otras"
#  [102] "catm_trx"
#  [103] "matm"
#  [104] "catm_trx_other"
#  [105] "matm_other"
#  [106] "ctrx_quarter"
#  [107] "tmobile_app"
#  [108] "cmobile_app_trx"
#  [109] "Master_delinquency"
#  [110] "Master_status"
#  [111] "Master_mfinanciacion_limite"
#  [112] "Master_Fvencimiento"
#  [113] "Master_Finiciomora"
#  [114] "Master_msaldototal"
#  [115] "Master_msaldopesos"
#  [116] "Master_msaldodolares"
#  [117] "Master_mconsumospesos"
#  [118] "Master_mconsumosdolares"
#  [119] "Master_mlimitecompra"
#  [120] "Master_madelantopesos"
#  [121] "Master_madelantodolares"
#  [122] "Master_fultimo_cierre"
#  [123] "Master_mpagado"
#  [124] "Master_mpagospesos"
#  [125] "Master_mpagosdolares"
#  [126] "Master_fechaalta"
#  [127] "Master_mconsumototal"
#  [128] "Master_cconsumos"
#  [129] "Master_cadelantosefectivo"
#  [130] "Master_mpagominimo"
#  [131] "Visa_delinquency"
#  [132] "Visa_status"
#  [133] "Visa_mfinanciacion_limite"
#  [134] "Visa_Fvencimiento"
#  [135] "Visa_Finiciomora"
#  [136] "Visa_msaldototal"
#  [137] "Visa_msaldopesos"
#  [138] "Visa_msaldodolares"
#  [139] "Visa_mconsumospesos"
#  [140] "Visa_mconsumosdolares"
#  [141] "Visa_mlimitecompra"
#  [142] "Visa_madelantopesos"
#  [143] "Visa_madelantodolares"
#  [144] "Visa_fultimo_cierre"
#  [145] "Visa_mpagado"
#  [146] "Visa_mpagospesos"
#  [147] "Visa_mpagosdolares"
#  [148] "Visa_fechaalta"
#  [149] "Visa_mconsumototal"
#  [150] "Visa_cconsumos"
#  [151] "Visa_cadelantosefectivo"
#  [152] "Visa_mpagominimo"
#  [153] "clase_ternaria"
#  [154] "kmes"
#  [155] "ctrx_quarter_normalizado"
#  [156] "mpayroll_sobre_edad"
#  [157] "active_quarter_lag1"
#  [158] "cliente_vip_lag1"
#  [159] "internet_lag1"
#  [160] "cliente_edad_lag1"
#  [161] "cliente_antiguedad_lag1"
#  [162] "mrentabilidad_lag1"
#  [163] "mrentabilidad_annual_lag1"
#  [164] "mcomisiones_lag1"
#  [165] "mactivos_margen_lag1"
#  [166] "mpasivos_margen_lag1"
#  [167] "cproductos_lag1"
#  [168] "tcuentas_lag1"
#  [169] "ccuenta_corriente_lag1"
#  [170] "mcuenta_corriente_adicional_lag1"
#  [171] "mcuenta_corriente_lag1"
#  [172] "ccaja_ahorro_lag1"
#  [173] "mcaja_ahorro_lag1"
#  [174] "mcaja_ahorro_adicional_lag1"
#  [175] "mcaja_ahorro_dolares_lag1"
#  [176] "cdescubierto_preacordado_lag1"
#  [177] "mcuentas_saldo_lag1"
#  [178] "ctarjeta_debito_lag1"
#  [179] "ctarjeta_debito_transacciones_lag1"
#  [180] "mautoservicio_lag1"
#  [181] "ctarjeta_visa_lag1"
#  [182] "ctarjeta_visa_transacciones_lag1"
#  [183] "mtarjeta_visa_consumo_lag1"
#  [184] "ctarjeta_master_lag1"
#  [185] "ctarjeta_master_transacciones_lag1"
#  [186] "mtarjeta_master_consumo_lag1"
#  [187] "cprestamos_prendarios_lag1"
#  [188] "mprestamos_prendarios_lag1"
#  [189] "cprestamos_hipotecarios_lag1"
#  [190] "mprestamos_hipotecarios_lag1"
#  [191] "cplazo_fijo_lag1"
#  [192] "mplazo_fijo_dolares_lag1"
#  [193] "mplazo_fijo_pesos_lag1"
#  [194] "cinversion1_lag1"
#  [195] "minversion1_pesos_lag1"
#  [196] "minversion1_dolares_lag1"
#  [197] "cinversion2_lag1"
#  [198] "minversion2_lag1"
#  [199] "cseguro_vida_lag1"
#  [200] "cseguro_auto_lag1"
#  [201] "cseguro_vivienda_lag1"
#  [202] "cseguro_accidentes_personales_lag1"
#  [203] "ccaja_seguridad_lag1"
#  [204] "cpayroll_trx_lag1"
#  [205] "mpayroll_lag1"
#  [206] "mpayroll2_lag1"
#  [207] "cpayroll2_trx_lag1"
#  [208] "ccuenta_debitos_automaticos_lag1"
#  [209] "mcuenta_debitos_automaticos_lag1"
#  [210] "ctarjeta_visa_debitos_automaticos_lag1"
#  [211] "mttarjeta_visa_debitos_automaticos_lag1"
#  [212] "ctarjeta_master_debitos_automaticos_lag1"
#  [213] "mttarjeta_master_debitos_automaticos_lag1"
#  [214] "cpagodeservicios_lag1"
#  [215] "mpagodeservicios_lag1"
#  [216] "cpagomiscuentas_lag1"
#  [217] "mpagomiscuentas_lag1"
#  [218] "ccajeros_propios_descuentos_lag1"
#  [219] "mcajeros_propios_descuentos_lag1"
#  [220] "ctarjeta_visa_descuentos_lag1"
#  [221] "mtarjeta_visa_descuentos_lag1"
#  [222] "ctarjeta_master_descuentos_lag1"
#  [223] "mtarjeta_master_descuentos_lag1"
#  [224] "ccomisiones_mantenimiento_lag1"
#  [225] "mcomisiones_mantenimiento_lag1"
#  [226] "ccomisiones_otras_lag1"
#  [227] "mcomisiones_otras_lag1"
#  [228] "cforex_lag1"
#  [229] "cforex_buy_lag1"
#  [230] "mforex_buy_lag1"
#  [231] "cforex_sell_lag1"
#  [232] "mforex_sell_lag1"
#  [233] "ctransferencias_recibidas_lag1"
#  [234] "mtransferencias_recibidas_lag1"
#  [235] "ctransferencias_emitidas_lag1"
#  [236] "mtransferencias_emitidas_lag1"
#  [237] "cextraccion_autoservicio_lag1"
#  [238] "mextraccion_autoservicio_lag1"
#  [239] "ccheques_depositados_lag1"
#  [240] "mcheques_depositados_lag1"
#  [241] "ccheques_emitidos_lag1"
#  [242] "mcheques_emitidos_lag1"
#  [243] "ccheques_depositados_rechazados_lag1"
#  [244] "mcheques_depositados_rechazados_lag1"
#  [245] "ccheques_emitidos_rechazados_lag1"
#  [246] "mcheques_emitidos_rechazados_lag1"
#  [247] "tcallcenter_lag1"
#  [248] "ccallcenter_transacciones_lag1"
#  [249] "thomebanking_lag1"
#  [250] "chomebanking_transacciones_lag1"
#  [251] "ccajas_transacciones_lag1"
#  [252] "ccajas_consultas_lag1"
#  [253] "ccajas_depositos_lag1"
#  [254] "ccajas_extracciones_lag1"
#  [255] "ccajas_otras_lag1"
#  [256] "catm_trx_lag1"
#  [257] "matm_lag1"
#  [258] "catm_trx_other_lag1"
#  [259] "matm_other_lag1"
#  [260] "ctrx_quarter_lag1"
#  [261] "tmobile_app_lag1"
#  [262] "cmobile_app_trx_lag1"
#  [263] "Master_delinquency_lag1"
#  [264] "Master_status_lag1"
#  [265] "Master_mfinanciacion_limite_lag1"
#  [266] "Master_Fvencimiento_lag1"
#  [267] "Master_Finiciomora_lag1"
#  [268] "Master_msaldototal_lag1"
#  [269] "Master_msaldopesos_lag1"
#  [270] "Master_msaldodolares_lag1"
#  [271] "Master_mconsumospesos_lag1"
#  [272] "Master_mconsumosdolares_lag1"
#  [273] "Master_mlimitecompra_lag1"
#  [274] "Master_madelantopesos_lag1"
#  [275] "Master_madelantodolares_lag1"
#  [276] "Master_fultimo_cierre_lag1"
#  [277] "Master_mpagado_lag1"
#  [278] "Master_mpagospesos_lag1"
#  [279] "Master_mpagosdolares_lag1"
#  [280] "Master_fechaalta_lag1"
#  [281] "Master_mconsumototal_lag1"
#  [282] "Master_cconsumos_lag1"
#  [283] "Master_cadelantosefectivo_lag1"
#  [284] "Master_mpagominimo_lag1"
#  [285] "Visa_delinquency_lag1"
#  [286] "Visa_status_lag1"
#  [287] "Visa_mfinanciacion_limite_lag1"
#  [288] "Visa_Fvencimiento_lag1"
#  [289] "Visa_Finiciomora_lag1"
#  [290] "Visa_msaldototal_lag1"
#  [291] "Visa_msaldopesos_lag1"
#  [292] "Visa_msaldodolares_lag1"
#  [293] "Visa_mconsumospesos_lag1"
#  [294] "Visa_mconsumosdolares_lag1"
#  [295] "Visa_mlimitecompra_lag1"
#  [296] "Visa_madelantopesos_lag1"
#  [297] "Visa_madelantodolares_lag1"
#  [298] "Visa_fultimo_cierre_lag1"
#  [299] "Visa_mpagado_lag1"
#  [300] "Visa_mpagospesos_lag1"
#  [301] "Visa_mpagosdolares_lag1"
#  [302] "Visa_fechaalta_lag1"
#  [303] "Visa_mconsumototal_lag1"
#  [304] "Visa_cconsumos_lag1"
#  [305] "Visa_cadelantosefectivo_lag1"
#  [306] "Visa_mpagominimo_lag1"
#  [307] "kmes_lag1"
#  [308] "ctrx_quarter_normalizado_lag1"
#  [309] "mpayroll_sobre_edad_lag1"
#  [310] "active_quarter_lag2"
#  [311] "cliente_vip_lag2"
#  [312] "internet_lag2"
#  [313] "cliente_edad_lag2"
#  [314] "cliente_antiguedad_lag2"
#  [315] "mrentabilidad_lag2"
#  [316] "mrentabilidad_annual_lag2"
#  [317] "mcomisiones_lag2"
#  [318] "mactivos_margen_lag2"
#  [319] "mpasivos_margen_lag2"
#  [320] "cproductos_lag2"
#  [321] "tcuentas_lag2"
#  [322] "ccuenta_corriente_lag2"
#  [323] "mcuenta_corriente_adicional_lag2"
#  [324] "mcuenta_corriente_lag2"
#  [325] "ccaja_ahorro_lag2"
#  [326] "mcaja_ahorro_lag2"
#  [327] "mcaja_ahorro_adicional_lag2"
#  [328] "mcaja_ahorro_dolares_lag2"
#  [329] "cdescubierto_preacordado_lag2"
#  [330] "mcuentas_saldo_lag2"
#  [331] "ctarjeta_debito_lag2"
#  [332] "ctarjeta_debito_transacciones_lag2"
#  [333] "mautoservicio_lag2"
#  [334] "ctarjeta_visa_lag2"
#  [335] "ctarjeta_visa_transacciones_lag2"
#  [336] "mtarjeta_visa_consumo_lag2"
#  [337] "ctarjeta_master_lag2"
#  [338] "ctarjeta_master_transacciones_lag2"
#  [339] "mtarjeta_master_consumo_lag2"
#  [340] "cprestamos_prendarios_lag2"
#  [341] "mprestamos_prendarios_lag2"
#  [342] "cprestamos_hipotecarios_lag2"
#  [343] "mprestamos_hipotecarios_lag2"
#  [344] "cplazo_fijo_lag2"
#  [345] "mplazo_fijo_dolares_lag2"
#  [346] "mplazo_fijo_pesos_lag2"
#  [347] "cinversion1_lag2"
#  [348] "minversion1_pesos_lag2"
#  [349] "minversion1_dolares_lag2"
#  [350] "cinversion2_lag2"
#  [351] "minversion2_lag2"
#  [352] "cseguro_vida_lag2"
#  [353] "cseguro_auto_lag2"
#  [354] "cseguro_vivienda_lag2"
#  [355] "cseguro_accidentes_personales_lag2"
#  [356] "ccaja_seguridad_lag2"
#  [357] "cpayroll_trx_lag2"
#  [358] "mpayroll_lag2"
#  [359] "mpayroll2_lag2"
#  [360] "cpayroll2_trx_lag2"
#  [361] "ccuenta_debitos_automaticos_lag2"
#  [362] "mcuenta_debitos_automaticos_lag2"
#  [363] "ctarjeta_visa_debitos_automaticos_lag2"
#  [364] "mttarjeta_visa_debitos_automaticos_lag2"
#  [365] "ctarjeta_master_debitos_automaticos_lag2"
#  [366] "mttarjeta_master_debitos_automaticos_lag2"
#  [367] "cpagodeservicios_lag2"
#  [368] "mpagodeservicios_lag2"
#  [369] "cpagomiscuentas_lag2"
#  [370] "mpagomiscuentas_lag2"
#  [371] "ccajeros_propios_descuentos_lag2"
#  [372] "mcajeros_propios_descuentos_lag2"
#  [373] "ctarjeta_visa_descuentos_lag2"
#  [374] "mtarjeta_visa_descuentos_lag2"
#  [375] "ctarjeta_master_descuentos_lag2"
#  [376] "mtarjeta_master_descuentos_lag2"
#  [377] "ccomisiones_mantenimiento_lag2"
#  [378] "mcomisiones_mantenimiento_lag2"
#  [379] "ccomisiones_otras_lag2"
#  [380] "mcomisiones_otras_lag2"
#  [381] "cforex_lag2"
#  [382] "cforex_buy_lag2"
#  [383] "mforex_buy_lag2"
#  [384] "cforex_sell_lag2"
#  [385] "mforex_sell_lag2"
#  [386] "ctransferencias_recibidas_lag2"
#  [387] "mtransferencias_recibidas_lag2"
#  [388] "ctransferencias_emitidas_lag2"
#  [389] "mtransferencias_emitidas_lag2"
#  [390] "cextraccion_autoservicio_lag2"
#  [391] "mextraccion_autoservicio_lag2"
#  [392] "ccheques_depositados_lag2"
#  [393] "mcheques_depositados_lag2"
#  [394] "ccheques_emitidos_lag2"
#  [395] "mcheques_emitidos_lag2"
#  [396] "ccheques_depositados_rechazados_lag2"
#  [397] "mcheques_depositados_rechazados_lag2"
#  [398] "ccheques_emitidos_rechazados_lag2"
#  [399] "mcheques_emitidos_rechazados_lag2"
#  [400] "tcallcenter_lag2"
#  [401] "ccallcenter_transacciones_lag2"
#  [402] "thomebanking_lag2"
#  [403] "chomebanking_transacciones_lag2"
#  [404] "ccajas_transacciones_lag2"
#  [405] "ccajas_consultas_lag2"
#  [406] "ccajas_depositos_lag2"
#  [407] "ccajas_extracciones_lag2"
#  [408] "ccajas_otras_lag2"
#  [409] "catm_trx_lag2"
#  [410] "matm_lag2"
#  [411] "catm_trx_other_lag2"
#  [412] "matm_other_lag2"
#  [413] "ctrx_quarter_lag2"
#  [414] "tmobile_app_lag2"
#  [415] "cmobile_app_trx_lag2"
#  [416] "Master_delinquency_lag2"
#  [417] "Master_status_lag2"
#  [418] "Master_mfinanciacion_limite_lag2"
#  [419] "Master_Fvencimiento_lag2"
#  [420] "Master_Finiciomora_lag2"
#  [421] "Master_msaldototal_lag2"
#  [422] "Master_msaldopesos_lag2"
#  [423] "Master_msaldodolares_lag2"
#  [424] "Master_mconsumospesos_lag2"
#  [425] "Master_mconsumosdolares_lag2"
#  [426] "Master_mlimitecompra_lag2"
#  [427] "Master_madelantopesos_lag2"
#  [428] "Master_madelantodolares_lag2"
#  [429] "Master_fultimo_cierre_lag2"
#  [430] "Master_mpagado_lag2"
#  [431] "Master_mpagospesos_lag2"
#  [432] "Master_mpagosdolares_lag2"
#  [433] "Master_fechaalta_lag2"
#  [434] "Master_mconsumototal_lag2"
#  [435] "Master_cconsumos_lag2"
#  [436] "Master_cadelantosefectivo_lag2"
#  [437] "Master_mpagominimo_lag2"
#  [438] "Visa_delinquency_lag2"
#  [439] "Visa_status_lag2"
#  [440] "Visa_mfinanciacion_limite_lag2"
#  [441] "Visa_Fvencimiento_lag2"
#  [442] "Visa_Finiciomora_lag2"
#  [443] "Visa_msaldototal_lag2"
#  [444] "Visa_msaldopesos_lag2"
#  [445] "Visa_msaldodolares_lag2"
#  [446] "Visa_mconsumospesos_lag2"
#  [447] "Visa_mconsumosdolares_lag2"
#  [448] "Visa_mlimitecompra_lag2"
#  [449] "Visa_madelantopesos_lag2"
#  [450] "Visa_madelantodolares_lag2"
#  [451] "Visa_fultimo_cierre_lag2"
#  [452] "Visa_mpagado_lag2"
#  [453] "Visa_mpagospesos_lag2"
#  [454] "Visa_mpagosdolares_lag2"
#  [455] "Visa_fechaalta_lag2"
#  [456] "Visa_mconsumototal_lag2"
#  [457] "Visa_cconsumos_lag2"
#  [458] "Visa_cadelantosefectivo_lag2"
#  [459] "Visa_mpagominimo_lag2"
#  [460] "kmes_lag2"
#  [461] "ctrx_quarter_normalizado_lag2"
#  [462] "mpayroll_sobre_edad_lag2"
#  [463] "active_quarter_lag3"
#  [464] "cliente_vip_lag3"
#  [465] "internet_lag3"
#  [466] "cliente_edad_lag3"
#  [467] "cliente_antiguedad_lag3"
#  [468] "mrentabilidad_lag3"
#  [469] "mrentabilidad_annual_lag3"
#  [470] "mcomisiones_lag3"
#  [471] "mactivos_margen_lag3"
#  [472] "mpasivos_margen_lag3"
#  [473] "cproductos_lag3"
#  [474] "tcuentas_lag3"
#  [475] "ccuenta_corriente_lag3"
#  [476] "mcuenta_corriente_adicional_lag3"
#  [477] "mcuenta_corriente_lag3"
#  [478] "ccaja_ahorro_lag3"
#  [479] "mcaja_ahorro_lag3"
#  [480] "mcaja_ahorro_adicional_lag3"
#  [481] "mcaja_ahorro_dolares_lag3"
#  [482] "cdescubierto_preacordado_lag3"
#  [483] "mcuentas_saldo_lag3"
#  [484] "ctarjeta_debito_lag3"
#  [485] "ctarjeta_debito_transacciones_lag3"
#  [486] "mautoservicio_lag3"
#  [487] "ctarjeta_visa_lag3"
#  [488] "ctarjeta_visa_transacciones_lag3"
#  [489] "mtarjeta_visa_consumo_lag3"
#  [490] "ctarjeta_master_lag3"
#  [491] "ctarjeta_master_transacciones_lag3"
#  [492] "mtarjeta_master_consumo_lag3"
#  [493] "cprestamos_prendarios_lag3"
#  [494] "mprestamos_prendarios_lag3"
#  [495] "cprestamos_hipotecarios_lag3"
#  [496] "mprestamos_hipotecarios_lag3"
#  [497] "cplazo_fijo_lag3"
#  [498] "mplazo_fijo_dolares_lag3"
#  [499] "mplazo_fijo_pesos_lag3"
#  [500] "cinversion1_lag3"
#  [501] "minversion1_pesos_lag3"
#  [502] "minversion1_dolares_lag3"
#  [503] "cinversion2_lag3"
#  [504] "minversion2_lag3"
#  [505] "cseguro_vida_lag3"
#  [506] "cseguro_auto_lag3"
#  [507] "cseguro_vivienda_lag3"
#  [508] "cseguro_accidentes_personales_lag3"
#  [509] "ccaja_seguridad_lag3"
#  [510] "cpayroll_trx_lag3"
#  [511] "mpayroll_lag3"
#  [512] "mpayroll2_lag3"
#  [513] "cpayroll2_trx_lag3"
#  [514] "ccuenta_debitos_automaticos_lag3"
#  [515] "mcuenta_debitos_automaticos_lag3"
#  [516] "ctarjeta_visa_debitos_automaticos_lag3"
#  [517] "mttarjeta_visa_debitos_automaticos_lag3"
#  [518] "ctarjeta_master_debitos_automaticos_lag3"
#  [519] "mttarjeta_master_debitos_automaticos_lag3"
#  [520] "cpagodeservicios_lag3"
#  [521] "mpagodeservicios_lag3"
#  [522] "cpagomiscuentas_lag3"
#  [523] "mpagomiscuentas_lag3"
#  [524] "ccajeros_propios_descuentos_lag3"
#  [525] "mcajeros_propios_descuentos_lag3"
#  [526] "ctarjeta_visa_descuentos_lag3"
#  [527] "mtarjeta_visa_descuentos_lag3"
#  [528] "ctarjeta_master_descuentos_lag3"
#  [529] "mtarjeta_master_descuentos_lag3"
#  [530] "ccomisiones_mantenimiento_lag3"
#  [531] "mcomisiones_mantenimiento_lag3"
#  [532] "ccomisiones_otras_lag3"
#  [533] "mcomisiones_otras_lag3"
#  [534] "cforex_lag3"
#  [535] "cforex_buy_lag3"
#  [536] "mforex_buy_lag3"
#  [537] "cforex_sell_lag3"
#  [538] "mforex_sell_lag3"
#  [539] "ctransferencias_recibidas_lag3"
#  [540] "mtransferencias_recibidas_lag3"
#  [541] "ctransferencias_emitidas_lag3"
#  [542] "mtransferencias_emitidas_lag3"
#  [543] "cextraccion_autoservicio_lag3"
#  [544] "mextraccion_autoservicio_lag3"
#  [545] "ccheques_depositados_lag3"
#  [546] "mcheques_depositados_lag3"
#  [547] "ccheques_emitidos_lag3"
#  [548] "mcheques_emitidos_lag3"
#  [549] "ccheques_depositados_rechazados_lag3"
#  [550] "mcheques_depositados_rechazados_lag3"
#  [551] "ccheques_emitidos_rechazados_lag3"
#  [552] "mcheques_emitidos_rechazados_lag3"
#  [553] "tcallcenter_lag3"
#  [554] "ccallcenter_transacciones_lag3"
#  [555] "thomebanking_lag3"
#  [556] "chomebanking_transacciones_lag3"
#  [557] "ccajas_transacciones_lag3"
#  [558] "ccajas_consultas_lag3"
#  [559] "ccajas_depositos_lag3"
#  [560] "ccajas_extracciones_lag3"
#  [561] "ccajas_otras_lag3"
#  [562] "catm_trx_lag3"
#  [563] "matm_lag3"
#  [564] "catm_trx_other_lag3"
#  [565] "matm_other_lag3"
#  [566] "ctrx_quarter_lag3"
#  [567] "tmobile_app_lag3"
#  [568] "cmobile_app_trx_lag3"
#  [569] "Master_delinquency_lag3"
#  [570] "Master_status_lag3"
#  [571] "Master_mfinanciacion_limite_lag3"
#  [572] "Master_Fvencimiento_lag3"
#  [573] "Master_Finiciomora_lag3"
#  [574] "Master_msaldototal_lag3"
#  [575] "Master_msaldopesos_lag3"
#  [576] "Master_msaldodolares_lag3"
#  [577] "Master_mconsumospesos_lag3"
#  [578] "Master_mconsumosdolares_lag3"
#  [579] "Master_mlimitecompra_lag3"
#  [580] "Master_madelantopesos_lag3"
#  [581] "Master_madelantodolares_lag3"
#  [582] "Master_fultimo_cierre_lag3"
#  [583] "Master_mpagado_lag3"
#  [584] "Master_mpagospesos_lag3"
#  [585] "Master_mpagosdolares_lag3"
#  [586] "Master_fechaalta_lag3"
#  [587] "Master_mconsumototal_lag3"
#  [588] "Master_cconsumos_lag3"
#  [589] "Master_cadelantosefectivo_lag3"
#  [590] "Master_mpagominimo_lag3"
#  [591] "Visa_delinquency_lag3"
#  [592] "Visa_status_lag3"
#  [593] "Visa_mfinanciacion_limite_lag3"
#  [594] "Visa_Fvencimiento_lag3"
#  [595] "Visa_Finiciomora_lag3"
#  [596] "Visa_msaldototal_lag3"
#  [597] "Visa_msaldopesos_lag3"
#  [598] "Visa_msaldodolares_lag3"
#  [599] "Visa_mconsumospesos_lag3"
#  [600] "Visa_mconsumosdolares_lag3"
#  [601] "Visa_mlimitecompra_lag3"
#  [602] "Visa_madelantopesos_lag3"
#  [603] "Visa_madelantodolares_lag3"
#  [604] "Visa_fultimo_cierre_lag3"
#  [605] "Visa_mpagado_lag3"
#  [606] "Visa_mpagospesos_lag3"
#  [607] "Visa_mpagosdolares_lag3"
#  [608] "Visa_fechaalta_lag3"
#  [609] "Visa_mconsumototal_lag3"
#  [610] "Visa_cconsumos_lag3"
#  [611] "Visa_cadelantosefectivo_lag3"
#  [612] "Visa_mpagominimo_lag3"
#  [613] "kmes_lag3"
#  [614] "ctrx_quarter_normalizado_lag3"
#  [615] "mpayroll_sobre_edad_lag3"
#  [616] "active_quarter_delta1"
#  [617] "active_quarter_delta2"
#  [618] "active_quarter_delta3"
#  [619] "cliente_vip_delta1"
#  [620] "cliente_vip_delta2"
#  [621] "cliente_vip_delta3"
#  [622] "internet_delta1"
#  [623] "internet_delta2"
#  [624] "internet_delta3"
#  [625] "cliente_edad_delta1"
#  [626] "cliente_edad_delta2"
#  [627] "cliente_edad_delta3"
#  [628] "cliente_antiguedad_delta1"
#  [629] "cliente_antiguedad_delta2"
#  [630] "cliente_antiguedad_delta3"
#  [631] "mrentabilidad_delta1"
#  [632] "mrentabilidad_delta2"
#  [633] "mrentabilidad_delta3"
#  [634] "mrentabilidad_annual_delta1"
#  [635] "mrentabilidad_annual_delta2"
#  [636] "mrentabilidad_annual_delta3"
#  [637] "mcomisiones_delta1"
#  [638] "mcomisiones_delta2"
#  [639] "mcomisiones_delta3"
#  [640] "mactivos_margen_delta1"
#  [641] "mactivos_margen_delta2"
#  [642] "mactivos_margen_delta3"
#  [643] "mpasivos_margen_delta1"
#  [644] "mpasivos_margen_delta2"
#  [645] "mpasivos_margen_delta3"
#  [646] "cproductos_delta1"
#  [647] "cproductos_delta2"
#  [648] "cproductos_delta3"
#  [649] "tcuentas_delta1"
#  [650] "tcuentas_delta2"
#  [651] "tcuentas_delta3"
#  [652] "ccuenta_corriente_delta1"
#  [653] "ccuenta_corriente_delta2"
#  [654] "ccuenta_corriente_delta3"
#  [655] "mcuenta_corriente_adicional_delta1"
#  [656] "mcuenta_corriente_adicional_delta2"
#  [657] "mcuenta_corriente_adicional_delta3"
#  [658] "mcuenta_corriente_delta1"
#  [659] "mcuenta_corriente_delta2"
#  [660] "mcuenta_corriente_delta3"
#  [661] "ccaja_ahorro_delta1"
#  [662] "ccaja_ahorro_delta2"
#  [663] "ccaja_ahorro_delta3"
#  [664] "mcaja_ahorro_delta1"
#  [665] "mcaja_ahorro_delta2"
#  [666] "mcaja_ahorro_delta3"
#  [667] "mcaja_ahorro_adicional_delta1"
#  [668] "mcaja_ahorro_adicional_delta2"
#  [669] "mcaja_ahorro_adicional_delta3"
#  [670] "mcaja_ahorro_dolares_delta1"
#  [671] "mcaja_ahorro_dolares_delta2"
#  [672] "mcaja_ahorro_dolares_delta3"
#  [673] "cdescubierto_preacordado_delta1"
#  [674] "cdescubierto_preacordado_delta2"
#  [675] "cdescubierto_preacordado_delta3"
#  [676] "mcuentas_saldo_delta1"
#  [677] "mcuentas_saldo_delta2"
#  [678] "mcuentas_saldo_delta3"
#  [679] "ctarjeta_debito_delta1"
#  [680] "ctarjeta_debito_delta2"
#  [681] "ctarjeta_debito_delta3"
#  [682] "ctarjeta_debito_transacciones_delta1"
#  [683] "ctarjeta_debito_transacciones_delta2"
#  [684] "ctarjeta_debito_transacciones_delta3"
#  [685] "mautoservicio_delta1"
#  [686] "mautoservicio_delta2"
#  [687] "mautoservicio_delta3"
#  [688] "ctarjeta_visa_delta1"
#  [689] "ctarjeta_visa_delta2"
#  [690] "ctarjeta_visa_delta3"
#  [691] "ctarjeta_visa_transacciones_delta1"
#  [692] "ctarjeta_visa_transacciones_delta2"
#  [693] "ctarjeta_visa_transacciones_delta3"
#  [694] "mtarjeta_visa_consumo_delta1"
#  [695] "mtarjeta_visa_consumo_delta2"
#  [696] "mtarjeta_visa_consumo_delta3"
#  [697] "ctarjeta_master_delta1"
#  [698] "ctarjeta_master_delta2"
#  [699] "ctarjeta_master_delta3"
#  [700] "ctarjeta_master_transacciones_delta1"
#  [701] "ctarjeta_master_transacciones_delta2"
#  [702] "ctarjeta_master_transacciones_delta3"
#  [703] "mtarjeta_master_consumo_delta1"
#  [704] "mtarjeta_master_consumo_delta2"
#  [705] "mtarjeta_master_consumo_delta3"
#  [706] "cprestamos_prendarios_delta1"
#  [707] "cprestamos_prendarios_delta2"
#  [708] "cprestamos_prendarios_delta3"
#  [709] "mprestamos_prendarios_delta1"
#  [710] "mprestamos_prendarios_delta2"
#  [711] "mprestamos_prendarios_delta3"
#  [712] "cprestamos_hipotecarios_delta1"
#  [713] "cprestamos_hipotecarios_delta2"
#  [714] "cprestamos_hipotecarios_delta3"
#  [715] "mprestamos_hipotecarios_delta1"
#  [716] "mprestamos_hipotecarios_delta2"
#  [717] "mprestamos_hipotecarios_delta3"
#  [718] "cplazo_fijo_delta1"
#  [719] "cplazo_fijo_delta2"
#  [720] "cplazo_fijo_delta3"
#  [721] "mplazo_fijo_dolares_delta1"
#  [722] "mplazo_fijo_dolares_delta2"
#  [723] "mplazo_fijo_dolares_delta3"
#  [724] "mplazo_fijo_pesos_delta1"
#  [725] "mplazo_fijo_pesos_delta2"
#  [726] "mplazo_fijo_pesos_delta3"
#  [727] "cinversion1_delta1"
#  [728] "cinversion1_delta2"
#  [729] "cinversion1_delta3"
#  [730] "minversion1_pesos_delta1"
#  [731] "minversion1_pesos_delta2"
#  [732] "minversion1_pesos_delta3"
#  [733] "minversion1_dolares_delta1"
#  [734] "minversion1_dolares_delta2"
#  [735] "minversion1_dolares_delta3"
#  [736] "cinversion2_delta1"
#  [737] "cinversion2_delta2"
#  [738] "cinversion2_delta3"
#  [739] "minversion2_delta1"
#  [740] "minversion2_delta2"
#  [741] "minversion2_delta3"
#  [742] "cseguro_vida_delta1"
#  [743] "cseguro_vida_delta2"
#  [744] "cseguro_vida_delta3"
#  [745] "cseguro_auto_delta1"
#  [746] "cseguro_auto_delta2"
#  [747] "cseguro_auto_delta3"
#  [748] "cseguro_vivienda_delta1"
#  [749] "cseguro_vivienda_delta2"
#  [750] "cseguro_vivienda_delta3"
#  [751] "cseguro_accidentes_personales_delta1"
#  [752] "cseguro_accidentes_personales_delta2"
#  [753] "cseguro_accidentes_personales_delta3"
#  [754] "ccaja_seguridad_delta1"
#  [755] "ccaja_seguridad_delta2"
#  [756] "ccaja_seguridad_delta3"
#  [757] "cpayroll_trx_delta1"
#  [758] "cpayroll_trx_delta2"
#  [759] "cpayroll_trx_delta3"
#  [760] "mpayroll_delta1"
#  [761] "mpayroll_delta2"
#  [762] "mpayroll_delta3"
#  [763] "mpayroll2_delta1"
#  [764] "mpayroll2_delta2"
#  [765] "mpayroll2_delta3"
#  [766] "cpayroll2_trx_delta1"
#  [767] "cpayroll2_trx_delta2"
#  [768] "cpayroll2_trx_delta3"
#  [769] "ccuenta_debitos_automaticos_delta1"
#  [770] "ccuenta_debitos_automaticos_delta2"
#  [771] "ccuenta_debitos_automaticos_delta3"
#  [772] "mcuenta_debitos_automaticos_delta1"
#  [773] "mcuenta_debitos_automaticos_delta2"
#  [774] "mcuenta_debitos_automaticos_delta3"
#  [775] "ctarjeta_visa_debitos_automaticos_delta1"
#  [776] "ctarjeta_visa_debitos_automaticos_delta2"
#  [777] "ctarjeta_visa_debitos_automaticos_delta3"
#  [778] "mttarjeta_visa_debitos_automaticos_delta1"
#  [779] "mttarjeta_visa_debitos_automaticos_delta2"
#  [780] "mttarjeta_visa_debitos_automaticos_delta3"
#  [781] "ctarjeta_master_debitos_automaticos_delta1"
#  [782] "ctarjeta_master_debitos_automaticos_delta2"
#  [783] "ctarjeta_master_debitos_automaticos_delta3"
#  [784] "mttarjeta_master_debitos_automaticos_delta1"
#  [785] "mttarjeta_master_debitos_automaticos_delta2"
#  [786] "mttarjeta_master_debitos_automaticos_delta3"
#  [787] "cpagodeservicios_delta1"
#  [788] "cpagodeservicios_delta2"
#  [789] "cpagodeservicios_delta3"
#  [790] "mpagodeservicios_delta1"
#  [791] "mpagodeservicios_delta2"
#  [792] "mpagodeservicios_delta3"
#  [793] "cpagomiscuentas_delta1"
#  [794] "cpagomiscuentas_delta2"
#  [795] "cpagomiscuentas_delta3"
#  [796] "mpagomiscuentas_delta1"
#  [797] "mpagomiscuentas_delta2"
#  [798] "mpagomiscuentas_delta3"
#  [799] "ccajeros_propios_descuentos_delta1"
#  [800] "ccajeros_propios_descuentos_delta2"
#  [801] "ccajeros_propios_descuentos_delta3"
#  [802] "mcajeros_propios_descuentos_delta1"
#  [803] "mcajeros_propios_descuentos_delta2"
#  [804] "mcajeros_propios_descuentos_delta3"
#  [805] "ctarjeta_visa_descuentos_delta1"
#  [806] "ctarjeta_visa_descuentos_delta2"
#  [807] "ctarjeta_visa_descuentos_delta3"
#  [808] "mtarjeta_visa_descuentos_delta1"
#  [809] "mtarjeta_visa_descuentos_delta2"
#  [810] "mtarjeta_visa_descuentos_delta3"
#  [811] "ctarjeta_master_descuentos_delta1"
#  [812] "ctarjeta_master_descuentos_delta2"
#  [813] "ctarjeta_master_descuentos_delta3"
#  [814] "mtarjeta_master_descuentos_delta1"
#  [815] "mtarjeta_master_descuentos_delta2"
#  [816] "mtarjeta_master_descuentos_delta3"
#  [817] "ccomisiones_mantenimiento_delta1"
#  [818] "ccomisiones_mantenimiento_delta2"
#  [819] "ccomisiones_mantenimiento_delta3"
#  [820] "mcomisiones_mantenimiento_delta1"
#  [821] "mcomisiones_mantenimiento_delta2"
#  [822] "mcomisiones_mantenimiento_delta3"
#  [823] "ccomisiones_otras_delta1"
#  [824] "ccomisiones_otras_delta2"
#  [825] "ccomisiones_otras_delta3"
#  [826] "mcomisiones_otras_delta1"
#  [827] "mcomisiones_otras_delta2"
#  [828] "mcomisiones_otras_delta3"
#  [829] "cforex_delta1"
#  [830] "cforex_delta2"
#  [831] "cforex_delta3"
#  [832] "cforex_buy_delta1"
#  [833] "cforex_buy_delta2"
#  [834] "cforex_buy_delta3"
#  [835] "mforex_buy_delta1"
#  [836] "mforex_buy_delta2"
#  [837] "mforex_buy_delta3"
#  [838] "cforex_sell_delta1"
#  [839] "cforex_sell_delta2"
#  [840] "cforex_sell_delta3"
#  [841] "mforex_sell_delta1"
#  [842] "mforex_sell_delta2"
#  [843] "mforex_sell_delta3"
#  [844] "ctransferencias_recibidas_delta1"
#  [845] "ctransferencias_recibidas_delta2"
#  [846] "ctransferencias_recibidas_delta3"
#  [847] "mtransferencias_recibidas_delta1"
#  [848] "mtransferencias_recibidas_delta2"
#  [849] "mtransferencias_recibidas_delta3"
#  [850] "ctransferencias_emitidas_delta1"
#  [851] "ctransferencias_emitidas_delta2"
#  [852] "ctransferencias_emitidas_delta3"
#  [853] "mtransferencias_emitidas_delta1"
#  [854] "mtransferencias_emitidas_delta2"
#  [855] "mtransferencias_emitidas_delta3"
#  [856] "cextraccion_autoservicio_delta1"
#  [857] "cextraccion_autoservicio_delta2"
#  [858] "cextraccion_autoservicio_delta3"
#  [859] "mextraccion_autoservicio_delta1"
#  [860] "mextraccion_autoservicio_delta2"
#  [861] "mextraccion_autoservicio_delta3"
#  [862] "ccheques_depositados_delta1"
#  [863] "ccheques_depositados_delta2"
#  [864] "ccheques_depositados_delta3"
#  [865] "mcheques_depositados_delta1"
#  [866] "mcheques_depositados_delta2"
#  [867] "mcheques_depositados_delta3"
#  [868] "ccheques_emitidos_delta1"
#  [869] "ccheques_emitidos_delta2"
#  [870] "ccheques_emitidos_delta3"
#  [871] "mcheques_emitidos_delta1"
#  [872] "mcheques_emitidos_delta2"
#  [873] "mcheques_emitidos_delta3"
#  [874] "ccheques_depositados_rechazados_delta1"
#  [875] "ccheques_depositados_rechazados_delta2"
#  [876] "ccheques_depositados_rechazados_delta3"
#  [877] "mcheques_depositados_rechazados_delta1"
#  [878] "mcheques_depositados_rechazados_delta2"
#  [879] "mcheques_depositados_rechazados_delta3"
#  [880] "ccheques_emitidos_rechazados_delta1"
#  [881] "ccheques_emitidos_rechazados_delta2"
#  [882] "ccheques_emitidos_rechazados_delta3"
#  [883] "mcheques_emitidos_rechazados_delta1"
#  [884] "mcheques_emitidos_rechazados_delta2"
#  [885] "mcheques_emitidos_rechazados_delta3"
#  [886] "tcallcenter_delta1"
#  [887] "tcallcenter_delta2"
#  [888] "tcallcenter_delta3"
#  [889] "ccallcenter_transacciones_delta1"
#  [890] "ccallcenter_transacciones_delta2"
#  [891] "ccallcenter_transacciones_delta3"
#  [892] "thomebanking_delta1"
#  [893] "thomebanking_delta2"
#  [894] "thomebanking_delta3"
#  [895] "chomebanking_transacciones_delta1"
#  [896] "chomebanking_transacciones_delta2"
#  [897] "chomebanking_transacciones_delta3"
#  [898] "ccajas_transacciones_delta1"
#  [899] "ccajas_transacciones_delta2"
#  [900] "ccajas_transacciones_delta3"
#  [901] "ccajas_consultas_delta1"
#  [902] "ccajas_consultas_delta2"
#  [903] "ccajas_consultas_delta3"
#  [904] "ccajas_depositos_delta1"
#  [905] "ccajas_depositos_delta2"
#  [906] "ccajas_depositos_delta3"
#  [907] "ccajas_extracciones_delta1"
#  [908] "ccajas_extracciones_delta2"
#  [909] "ccajas_extracciones_delta3"
#  [910] "ccajas_otras_delta1"
#  [911] "ccajas_otras_delta2"
#  [912] "ccajas_otras_delta3"
#  [913] "catm_trx_delta1"
#  [914] "catm_trx_delta2"
#  [915] "catm_trx_delta3"
#  [916] "matm_delta1"
#  [917] "matm_delta2"
#  [918] "matm_delta3"
#  [919] "catm_trx_other_delta1"
#  [920] "catm_trx_other_delta2"
#  [921] "catm_trx_other_delta3"
#  [922] "matm_other_delta1"
#  [923] "matm_other_delta2"
#  [924] "matm_other_delta3"
#  [925] "ctrx_quarter_delta1"
#  [926] "ctrx_quarter_delta2"
#  [927] "ctrx_quarter_delta3"
#  [928] "tmobile_app_delta1"
#  [929] "tmobile_app_delta2"
#  [930] "tmobile_app_delta3"
#  [931] "cmobile_app_trx_delta1"
#  [932] "cmobile_app_trx_delta2"
#  [933] "cmobile_app_trx_delta3"
#  [934] "Master_delinquency_delta1"
#  [935] "Master_delinquency_delta2"
#  [936] "Master_delinquency_delta3"
#  [937] "Master_status_delta1"
#  [938] "Master_status_delta2"
#  [939] "Master_status_delta3"
#  [940] "Master_mfinanciacion_limite_delta1"
#  [941] "Master_mfinanciacion_limite_delta2"
#  [942] "Master_mfinanciacion_limite_delta3"
#  [943] "Master_Fvencimiento_delta1"
#  [944] "Master_Fvencimiento_delta2"
#  [945] "Master_Fvencimiento_delta3"
#  [946] "Master_Finiciomora_delta1"
#  [947] "Master_Finiciomora_delta2"
#  [948] "Master_Finiciomora_delta3"
#  [949] "Master_msaldototal_delta1"
#  [950] "Master_msaldototal_delta2"
#  [951] "Master_msaldototal_delta3"
#  [952] "Master_msaldopesos_delta1"
#  [953] "Master_msaldopesos_delta2"
#  [954] "Master_msaldopesos_delta3"
#  [955] "Master_msaldodolares_delta1"
#  [956] "Master_msaldodolares_delta2"
#  [957] "Master_msaldodolares_delta3"
#  [958] "Master_mconsumospesos_delta1"
#  [959] "Master_mconsumospesos_delta2"
#  [960] "Master_mconsumospesos_delta3"
#  [961] "Master_mconsumosdolares_delta1"
#  [962] "Master_mconsumosdolares_delta2"
#  [963] "Master_mconsumosdolares_delta3"
#  [964] "Master_mlimitecompra_delta1"
#  [965] "Master_mlimitecompra_delta2"
#  [966] "Master_mlimitecompra_delta3"
#  [967] "Master_madelantopesos_delta1"
#  [968] "Master_madelantopesos_delta2"
#  [969] "Master_madelantopesos_delta3"
#  [970] "Master_madelantodolares_delta1"
#  [971] "Master_madelantodolares_delta2"
#  [972] "Master_madelantodolares_delta3"
#  [973] "Master_fultimo_cierre_delta1"
#  [974] "Master_fultimo_cierre_delta2"
#  [975] "Master_fultimo_cierre_delta3"
#  [976] "Master_mpagado_delta1"
#  [977] "Master_mpagado_delta2"
#  [978] "Master_mpagado_delta3"
#  [979] "Master_mpagospesos_delta1"
#  [980] "Master_mpagospesos_delta2"
#  [981] "Master_mpagospesos_delta3"
#  [982] "Master_mpagosdolares_delta1"
#  [983] "Master_mpagosdolares_delta2"
#  [984] "Master_mpagosdolares_delta3"
#  [985] "Master_fechaalta_delta1"
#  [986] "Master_fechaalta_delta2"
#  [987] "Master_fechaalta_delta3"
#  [988] "Master_mconsumototal_delta1"
#  [989] "Master_mconsumototal_delta2"
#  [990] "Master_mconsumototal_delta3"
#  [991] "Master_cconsumos_delta1"
#  [992] "Master_cconsumos_delta2"
#  [993] "Master_cconsumos_delta3"
#  [994] "Master_cadelantosefectivo_delta1"
#  [995] "Master_cadelantosefectivo_delta2"
#  [996] "Master_cadelantosefectivo_delta3"
#  [997] "Master_mpagominimo_delta1"
#  [998] "Master_mpagominimo_delta2"
#  [999] "Master_mpagominimo_delta3"
# [1000] "Visa_delinquency_delta1"
# [1001] "Visa_delinquency_delta2"
# [1002] "Visa_delinquency_delta3"
# [1003] "Visa_status_delta1"
# [1004] "Visa_status_delta2"
# [1005] "Visa_status_delta3"
# [1006] "Visa_mfinanciacion_limite_delta1"
# [1007] "Visa_mfinanciacion_limite_delta2"
# [1008] "Visa_mfinanciacion_limite_delta3"
# [1009] "Visa_Fvencimiento_delta1"
# [1010] "Visa_Fvencimiento_delta2"
# [1011] "Visa_Fvencimiento_delta3"
# [1012] "Visa_Finiciomora_delta1"
# [1013] "Visa_Finiciomora_delta2"
# [1014] "Visa_Finiciomora_delta3"
# [1015] "Visa_msaldototal_delta1"
# [1016] "Visa_msaldototal_delta2"
# [1017] "Visa_msaldototal_delta3"
# [1018] "Visa_msaldopesos_delta1"
# [1019] "Visa_msaldopesos_delta2"
# [1020] "Visa_msaldopesos_delta3"
# [1021] "Visa_msaldodolares_delta1"
# [1022] "Visa_msaldodolares_delta2"
# [1023] "Visa_msaldodolares_delta3"
# [1024] "Visa_mconsumospesos_delta1"
# [1025] "Visa_mconsumospesos_delta2"
# [1026] "Visa_mconsumospesos_delta3"
# [1027] "Visa_mconsumosdolares_delta1"
# [1028] "Visa_mconsumosdolares_delta2"
# [1029] "Visa_mconsumosdolares_delta3"
# [1030] "Visa_mlimitecompra_delta1"
# [1031] "Visa_mlimitecompra_delta2"
# [1032] "Visa_mlimitecompra_delta3"
# [1033] "Visa_madelantopesos_delta1"
# [1034] "Visa_madelantopesos_delta2"
# [1035] "Visa_madelantopesos_delta3"
# [1036] "Visa_madelantodolares_delta1"
# [1037] "Visa_madelantodolares_delta2"
# [1038] "Visa_madelantodolares_delta3"
# [1039] "Visa_fultimo_cierre_delta1"
# [1040] "Visa_fultimo_cierre_delta2"
# [1041] "Visa_fultimo_cierre_delta3"
# [1042] "Visa_mpagado_delta1"
# [1043] "Visa_mpagado_delta2"
# [1044] "Visa_mpagado_delta3"
# [1045] "Visa_mpagospesos_delta1"
# [1046] "Visa_mpagospesos_delta2"
# [1047] "Visa_mpagospesos_delta3"
# [1048] "Visa_mpagosdolares_delta1"
# [1049] "Visa_mpagosdolares_delta2"
# [1050] "Visa_mpagosdolares_delta3"
# [1051] "Visa_fechaalta_delta1"
# [1052] "Visa_fechaalta_delta2"
# [1053] "Visa_fechaalta_delta3"
# [1054] "Visa_mconsumototal_delta1"
# [1055] "Visa_mconsumototal_delta2"
# [1056] "Visa_mconsumototal_delta3"
# [1057] "Visa_cconsumos_delta1"
# [1058] "Visa_cconsumos_delta2"
# [1059] "Visa_cconsumos_delta3"
# [1060] "Visa_cadelantosefectivo_delta1"
# [1061] "Visa_cadelantosefectivo_delta2"
# [1062] "Visa_cadelantosefectivo_delta3"
# [1063] "Visa_mpagominimo_delta1"
# [1064] "Visa_mpagominimo_delta2"
# [1065] "Visa_mpagominimo_delta3"
# [1066] "kmes_delta1"
# [1067] "kmes_delta2"
# [1068] "kmes_delta3"
# [1069] "ctrx_quarter_normalizado_delta1"
# [1070] "ctrx_quarter_normalizado_delta2"
# [1071] "ctrx_quarter_normalizado_delta3"
# [1072] "mpayroll_sobre_edad_delta1"
# [1073] "mpayroll_sobre_edad_delta2"
# [1074] "mpayroll_sobre_edad_delta3"

# %% [markdown]
# ## Modelado

# %% [markdown]
# No hay modelado, no se hace optimizacion de hiperparametros.

# %% [markdown]
# ## Produccion

# %% [markdown]
# Las decisiones que se toman para la construccion del modelo final son:
# * Los positvos son  POS={"BAJA+1", "BAJA+2"}, esta es una meticulosa decisión.
# * Se entrena en los treinta meses del intervalo [201901, 202104]
# * Se realiza undersampling al 5%
# * Se utilizan los hiperparámetros optimos encontrados en la Bayesian Optimization
#    * Se escala min_data_in_leaf

# %% [markdown]
# ### Final Training Strategy

# %%
PARAM$train_final$future <- c(202109)

PARAM$train_final$training <- c(
  201901, 201902, 201903, 201904, 201905, 201906,
  201907, 201908, 201909, 201910, 201911, 201912,
  202001, 202002, 202003, 202004, 202005,
  202007, 202008, 202009, 202010, 202011, 202012,
  202101, 202102, 202103, 202104, 202105, 202106, 202107
)

PARAM$train_final$undersampling <- 0.25

# %%
# se filtran los meses donde se entrena el modelo final
dataset_train_final <- dataset[foto_mes %in% PARAM$train_final$training]

# %% [markdown]
# Weight

# %%
# Función auxiliar para convertir foto_mes (YYYYMM) a periodo entero (P)
to_periodo <- function(fm) as.integer(fm / 100) * 12 + fm %% 100 # 

# 1. Identificar el periodo máximo de entrenamiento (el mes más reciente)
ultimo_mes_train <- max(PARAM$train_final$training) 
periodo_max <- to_periodo(ultimo_mes_train)

# 2. Calcular la antiguedad (0 para el mes actual, 1 para el anterior, etc.)
decaimiento <- plocal$decaimiento
dataset_train_final[, periodo_actual := to_periodo(foto_mes)]
dataset_train_final[, antiguedad := periodo_max - periodo_actual]
dataset_train_final[, row_weight := decaimiento^antiguedad] # <--- El peso decae exponencialmente
dataset_train_final[, c("periodo_actual", "antiguedad") := NULL]

# %%
# canaritos
PARAM$train_final$lgbm$qcanaritos <- plocal$qcanaritos

cols0 <- copy(colnames(dataset_train_final))
filas <- nrow(dataset_train_final)

# 1. Fijar la semilla justo antes de generar canaritos
set.seed( PARAM$semilla_primigenia ) 

# 2. Creación de canaritos (Ahora reproducible)
if( PARAM$train_final$lgbm$qcanaritos > 0 ) {
  for( i in seq(PARAM$train_final$lgbm$qcanaritos) ){
    dataset_train_final[, paste0("canarito_",i) := runif( filas) ]
  }

  # las columnas canaritos mandatoriamente van al comienzo del dataset
  cols_canaritos <- copy( setdiff( colnames(dataset_train_final), cols0 ) )
  setcolorder( dataset_train_final, c( cols_canaritos, cols0 ) )
}

Sys.time()
# Out:
# [1] "2025-11-30 22:05:41 UTC"

# %% [markdown]
# #### Registros cambio las proporciones de POS/NEG

# %%
# Undersampling, van todos los "BAJA+1" y "BAJA+2" y solo algunos "CONTINIA"

set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset_train_final[, azar := runif(nrow(dataset_train_final))]
dataset_train_final[, training := 0L]

dataset_train_final[
  (azar <= PARAM$train_final$undersampling | clase_ternaria %in% c("BAJA+1", "BAJA+2")),
  training := 1L
]

dataset_train_final[, azar:= NULL] # elimino la columna azar

# %% [markdown]
# ### Target Engineering

# %%
# paso la clase a binaria que tome valores {0,1}  enteros
#  BAJA+1 y BAJA+2  son  1,   CONTINUA es 0
#  a partir de ahora ya NO puedo cortar  por prob(BAJA+2) > 1/40

dataset_train_final[,
  clase01 := ifelse(clase_ternaria %in% c("BAJA+2","BAJA+1"), 1L, 0L)
]

# %% [markdown]
# ### Final Models

# %% [markdown]
# Aqui SIEMPRE voy a hacer un semillerio, independientemente de si en la Bayesian Optimization calculé un semillerio en cada iteración.
# <br> Entreno un LightGBM para cada semilla,  y guardo el modelo dentro de la carpeta  **modelitos**
# <br> Intencionalmente en una primera etapá se generan los modelos y graban, y en una segunda etapa se leen eso modelos y se aplican a los datos del futuro

# %% [markdown]
# APO controla cuantas veces se repite el modelo, que se usa para promediar ganancias y reportar en la Pseudo Competencia algo razonable
# <br> El modelo puede ser un LightGBM simple (ksemillerio==1)  o un Ensemble Semillerio( ksemillerio > 1 )
# <br> Lamentablmente APO necesita utilizar muchas semillas, y eso demanda TIEMPO de corrida

# %%
PARAM$train_final$lgbm$param_completo <-  list(
  boosting= "gbdt",
  objective= "binary",
  metric= "custom",
  first_metric_only= FALSE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  force_row_wise= TRUE,
  verbosity= -100,

  seed= PARAM$semilla_primigenia,

  max_bin= 31L,
  min_data_in_leaf= plocal$min_data_in_leaf,  #este ya es el valor default de LightGBM

  num_iterations= 64L, # dejo libre la cantidad de arboles, zLightGBM se detiene solo
  num_leaves= 9999L, # dejo libre la cantidad de hojas, zLightGBM sabe cuando no hacer un split
  learning_rate= plocal$learning_rate,  # se lo deja en 1.0 para que si el score esta por debajo de gradient_bound no se lo escale

  feature_fraction= 0.50, # un valor equilibrado, habra que probar alternativas ...

  canaritos= PARAM$train_final$lgbm$qcanaritos, # fundamental en zLightGBM, aqui esta el control del overfitting
  gradient_bound= plocal$gradient_bound   # default de zLightGBM
)

Sys.time()
# Out:
# [1] "2025-11-30 22:05:42 UTC"

# %%
# Semillerio Final
PARAM$train_final$APO <- plocal$APO
PARAM$train_final$ksemillerio  <- plocal$ksemillerio

PARAM$train_final$cortes <- c(8000, 8500, 9000, 9500, 10000, 10500, 11000, 11500, 12000)

# %%
# detach("package:lightgbm", unload= TRUE)

# %%
if( !require("zlightgbm") ) install.packages("https://storage.googleapis.com/open-courses/dmeyf2025-e4a2/zlightgbm_4.6.0.99.tar.gz", repos= NULL, type= "source")
require("zlightgbm")
# Out:
# Loading required package: zlightgbm

# %%
if(!require("primes")) install.packages("primes")
require("primes")
# Out:
# Loading required package: primes

# %%
primos <- generate_primes(min = 100000, max = 1000000)
set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
PARAM$train_final$semillas <- sample(primos)[seq( PARAM$train_final$APO*PARAM$train_final$ksemillerio )]
PARAM$train_final$semillas
# Out:
#   [1] 696323 757751 538397 735733 585019 278819 571381 121063 143357 503233
#  [11] 261523 607363 250643 941099 908419 231947 442979 229423 320329 252173
#  [21] 420569 389029 202667 842419 393103 326063 582299 517277 861797 402487
#  [31] 703499 982117 175781 619687 815671 835909 918647 280541 641101 167627
#  [41] 621871 262543 210131 280939 811123 555257 575651 629341 595201 316493
#  [51] 923599 853211 285629 522569 533543 854149 733189 196991 794741 647963
#  [61] 198977 750917 769789 240319 307669 787187 467063 947707 919769 340369
#  [71] 268123 811897 503543 136559 887533 199151 464003 131543 330661 888361
#  [81] 754973 567569 511289 845921 831167 599629 106013 536423 370883 140221
#  [91] 682511 207517 481417 956569 786061 511591 881351 327251 163193 253907
# [101] 782443 678451 880687 736051 447323 923543 813269 223429 574061 758731
# [111] 288649 510121 715237 308761 979273 732101 426737 677107 359633 223049
# [121] 184409 603529 374789 416659 798569 187373 602309 816887 719753 450641
# [131] 525947 171481 599941 156719 196073 419603 713599 305471 788569 745973
# [141] 692147 314129 596933 963847 907183 376501 206933 288053 375563 373621

# %%
# Excluimos la columna 'row_weight' para que no sea usada como feature
campos_buenos <- setdiff( colnames(dataset_train_final), c( "clase_ternaria", "clase01", "training", "azar", "row_weight") )

# %%
# Extraemos el vector de pesos antes de crear el dataset
vector_pesos <- dataset_train_final[training == 1L, row_weight]
# Out:
# Error in `[.data.table`(dataset_train_final, training == 1L, row_weight): j (the 2nd argument inside [...]) is a single symbol but column name 'row_weight' is not found. If you intended to select columns using a variable in calling scope, please try DT[, ..row_weight]. The .. prefix conveys one-level-up similar to a file system path.
# Traceback:
#
# 1. `[.data.table`(dataset_train_final, training == 1L, row_weight)
# 2. stopf("j (the 2nd argument inside [...]) is a single symbol but column name '%1$s' is not found. If you intended to select columns using a variable in calling scope, please try DT[, ..%1$s]. The .. prefix conveys one-level-up similar to a file system path.",
#  .     jsubChar)
# 3. raise_condition(stop, gettextf(fmt, ..., domain = domain), c(class,
#  .     "simpleError", "error", "condition"))
# 4. signal(obj)

# %%
# dejo los datos en formato LightGBM
dtrain_final <- lgb.Dataset(
  data= data.matrix(dataset_train_final[training == 1L, campos_buenos, with= FALSE]),
  label= dataset_train_final[training == 1L, clase01],
  weight= vector_pesos, # <-- Aplicación del weight
  free_raw_data= FALSE
)
dataset_train_final[, row_weight := NULL] # <-- Limpieza de la columna weight

cat("filas", nrow(dtrain_final), "columnas", ncol(dtrain_final), "\n")
Sys.time()
# Out:
# filas 246412 columnas 1078
# [1] "2025-11-30 22:10:44 UTC"

# %%
# genero los modelitos
dir.create( "modelitos", showWarnings= FALSE)

param_completo <- copy( PARAM$train_final$lgbm$param_completo)

for( sem in PARAM$train_final$semillas ) {

  arch_modelo <- paste0("./modelitos/mod_", sem, ".txt")
  if( !file.exists( arch_modelo ) )
  {
    param_completo$seed <- sem

    modelito <- lgb.train(
      data= dtrain_final,
      param= param_completo
    )

    lgb.save( modelito, filename= arch_modelo)
    rm(modelito)
    gc()
  }
}

Sys.time()
# Out:
# [1] "2025-12-01 00:11:13 UTC"

# %% [markdown]
# ### Scoring

# %% [markdown]
# Se hace el predict() del modelo en los datos del futuro

# %%
dfuture <- dataset[foto_mes %in% PARAM$train_final$future ]

cols0 <- copy(colnames(dfuture))
filas <- nrow(dfuture)

if( PARAM$train_final$lgbm$qcanaritos > 0 ) {
  for( i in seq(PARAM$train_final$lgbm$qcanaritos) ){
    dfuture[, paste0("canarito_",i) := runif( filas) ]
  }

  # las columnas canaritos mandatoriamente van al comienzo del dataset
  cols_canaritos <- copy( setdiff( colnames(dfuture), cols0 ) )
  setcolorder( dfuture, c( cols_canaritos, cols0 ) )
}

# %%
# dataset de future, donde en este caso estoy haciendo testing

mfuture <- data.matrix(dfuture[, campos_buenos, with= FALSE])

dfuture[, ganancia := ifelse(clase_ternaria=="BAJA+2", 780000, -20000)]

# %%
mganancias <- matrix( nrow=PARAM$train_final$APO, ncol= length(PARAM$train_final$cortes) )

if( file.exists("prediccion.txt") )
  file.remove("prediccion.txt")

# %%
# aplico el modelo a los datos del future

for( vapo in seq(PARAM$train_final$APO) ) {
  # inicializacion en CERO
  vpred_acum <- rep(0.0, nrow(dfuture))
  qacumulados <- 0

  desde <- 1 + (vapo-1)*PARAM$train_final$ksemillerio
  hasta <- desde + PARAM$train_final$ksemillerio - 1
  semillas <- PARAM$train_final$semillas[desde:hasta]

  for( sem in semillas ) {

    arch_modelo <- paste0("./modelitos/mod_", sem, ".txt")
    if( file.exists( arch_modelo ) )
    {
      modelo_final <- lgb.load(arch_modelo) # leo del disco
      # hago el predict() y acumulo
      vpred_acum <- vpred_acum + predict(modelo_final, mfuture)
      qacumulados <- qacumulados + 1
      rm(modelo_final)
      gc()
    }
  }

  if( qacumulados > 0 ) {
    vpred_acum <- vpred_acum / qacumulados  # paso a probabildiad
    # tabla de prediccion, puede ser util para futuros ensembles
    #  ya que le modelo ganador va a ser un ensemble de LightGBMs

    tb_prediccion <- dfuture[, list(numero_de_cliente, foto_mes, ganancia)]
    tb_prediccion[, meta_modelo := vapo]
    tb_prediccion[, prob := vpred_acum ]
    setorder( tb_prediccion, -prob )
    # tb_prediccion[, gan_acum := cumsum(ganancia)]
    # tb_prediccion[, ganancia := NULL ]

    # # acumulo las ganancias
    # for( icor in seq(length(PARAM$train_final$cortes)) ){
    #   mganancias[ vapo, icor ] <- tb_prediccion[ PARAM$train_final$cortes[icor], gan_acum ]
    # }

    # grabo las probabilidades del modelo
    fwrite(tb_prediccion,
      file= "prediccion.txt",
      sep= "\t",
      append= TRUE
    )

    rm(tb_prediccion)
    gc()
  }
}

Sys.time()
# Out:
# [1] "2025-12-01 00:16:57 UTC"

# %%
# mganancias
# Out:
#      [,1]      [,2]      [,3]      [,4]      [,5]      [,6]      [,7]
# [1,] 403200000 411600000 413600000 416400000 419200000 422800000 420800000
# [2,] 404800000 406000000 414400000 416400000 418400000 416400000 416800000
# [3,] 408800000 416400000 421600000 420400000 416000000 419600000 416800000
#      [,8]      [,9]
# [1,] 421200000 421600000
# [2,] 414800000 418400000
# [3,] 417200000 420800000

# %% [markdown]
# ### Clasificacion

# %% [markdown]
# Se tomó la decisión de enviar a los 11000 registros con mayor probabilidad de POS={"BAJA+1","BAJA+"}
# <br> esto se determinó en forma artesanal analizando meses anterior
# <br> esta es una muy importante decisión

# %%
# # genero archivos con los  "envios" mejores
# dir.create("kaggle", showWarnings=FALSE)

# tb_prediccion <- fread("prediccion.txt")

# %%
# # genero archivos de fantasia, que NO son el que voy a subir a la Pseudo Competencia Kaggle
# envios <- 11000

# for( vapo in seq(PARAM$train_final$APO) ) {
#   if( tb_prediccion[meta_modelo==vapo, .N] > 0 ) {
#     tb_pred <- tb_prediccion[meta_modelo==vapo]
#     setorder( tb_pred, -prob )
#     tb_pred[, Predicted := 0L] # seteo inicial a 0
#     tb_pred[1:envios, Predicted := 1L] # marco los primeros

#     archivo_kaggle <- paste0("./kaggle/KA", PARAM$experimento, "_", vapo, "_", envios, ".csv")

#     # grabo el archivo
#     fwrite(tb_pred[, list(numero_de_cliente, Predicted)],
#       file= archivo_kaggle,
#       sep= ","
#     )

#     rm( tb_pred )
#     gc()
#   }
# }

# Sys.time()
# Out:
# [1] "2025-12-01 00:17:00 UTC"

# %% [markdown]
# ### Subida a Pseudo Kaggle

# %% [markdown]
# Aqui viene la verdadera magia de  APO = A Prueba Overfiteres
# <br>Se sube un submit a la Pseudo Competencia Kaggle cuya ganancia coincide casi exactamente con la ganancia MEDIA , promediada  APO veces

# %%
# colmedias <- colMeans( mganancias, na.rm=TRUE )
# mcorte_mejor <- max(colmedias, na.rm=TRUE)
# icorte_mejor <- which.max( colmedias )
# corte_mejor <- PARAM$train_final$cortes[icorte_mejor]

# %%
# tbl <- as.data.table( as.list( colmedias ) )
# colnames(tbl) <- paste0( "e", PARAM$train_final$cortes )
# tbl[, experimento := PARAM$experimento ]

# exp_gral <- "/content/buckets/b1/exp/apo-gral"
# dir.create(exp_gral, showWarnings=FALSE)
# fwrite( tbl,
#   file= paste0( exp_gral, "/tb_experimentos.txt"),
#   sep= "\t",
#   append= TRUE
# )

# %%
# colnames( mganancias ) <- paste0( "e", PARAM$train_final$cortes )
# tbl_local <- as.data.table( mganancias )

# fwrite( tbl_local,
#   file= "tb_apo.txt",
#   sep= "\t"
# )

# %%
# icerca <- which.min(  abs( tb_prediccion$gan_acum - mcorte_mejor ) )
# vmodelo <- tb_prediccion[ icerca, meta_modelo ]
# tb_pred <- tb_prediccion[meta_modelo==vmodelo]

# mcorte_mejor
# icerca
# tb_prediccion[ icerca]
# Out:
# [1] 420266667
# [1] 10827
#   numero_de_cliente foto_mes meta_modelo prob      gan_acum
# 1 1162258032        202107   1           0.3323151 420260000

# %%
# icerca <- which.min(  abs( tb_pred$gan_acum - mcorte_mejor ) )
# icerca
# Out:
# [1] 10827

# %%
# icerca <- which.min(  abs( tb_prediccion$gan_acum - mcorte_mejor ) )
# vmodelo <- tb_prediccion[ icerca, meta_modelo ]
# tb_pred <- tb_prediccion[meta_modelo==vmodelo]

# icerca <- which.min(  abs( tb_pred$gan_acum - mcorte_mejor ) )
# tb_pred[, Predicted := 0L] # seteo inicial a 0
# tb_pred[1:icerca, Predicted := 1L] # marco los primeros

# archivo_pseudo_kaggle <- paste0("./kaggle/KA", PARAM$experimento, "_",  icerca, ".csv")

# # grabo el archivo
# fwrite(tb_pred[, list(numero_de_cliente, Predicted)],
#   file= archivo_pseudo_kaggle,
#   sep= ","
# )

# %%
# Sys.time()
